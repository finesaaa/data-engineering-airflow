# %% [markdown]
# **Coursebook: Fetch Data Youtube API**
#
# - Part of Data Engineering Airflow Specialization
# - Course Length: 3 Hours
# - Last Updated: May 2024
#
# ---
#
#
# - Developed by [Algoritma](https://algorit.ma/)'s product division and instructors team

# %% [markdown]
# # Background

# %% [markdown]
# ## Top-Down Approach
#
# The coursebook is part of the **Data Engineering Airflow Specialization** offered by [Algoritma](https://algorit.ma). It takes a more accessible approach compared to Algoritma's core educational products, by getting participants to overcome the "how" barrier first, rather than a detailed breakdown of the "why".
#
# This translates to an overall easier learning curve, one where the reader is prompted to write short snippets of code in frequent intervals, before being offered an explanation on the underlying theoretical frameworks. Instead of mastering the syntactic design of the Python programming language, then moving into data structures, and then the `pandas` library, and then the mathematical details in an imputation algorithm, and its code implementation; we would do the opposite: Implement the imputation, then a succinct explanation of why it works and applicational considerations (what to look out for, what are assumptions it made, when _not_ to use it, etc).
#
# The coursebook is intended for a restricted audience only, i.e. the individuals and organizations having received this coursebook directly from the training organization. It may not be reproduced, distributed, translated or adapted in any form outside these individuals and organizations without permission.
#
# Algoritma is a data science education center based in Jakarta. We organize workshops and training programs to help working professionals and students gain mastery in various data science sub-fields: data visualization, machine learning, data modeling, statistical inference, etc.

# %% [markdown]
# ## Training Objectives
#
# This coursebook is intended to perform how to fetch data from REST API, cleansing it and restore it in new file. In this coursebook we will use Youtube API to fetch trending videos, cleansing and store it to JSON file. No prior programming knowledge is assumed.
#
# This coursebook focused on:
#
# - Importance of Data Fetching
# - Fetching Videos Youtube API
# - Data Preprocessing or Cleaning Data
# - Store Data to JSON file

# %% [markdown]
# ## Importance of Data Fetching
#
# ### Importance of Data Fetching
#
# In today's data-driven world, access to timely and relevant data is crucial for businesses, researchers, and individuals alike. Data fetching refers to the process of retrieving information from various sources, enabling analysis, insights, and informed decision-making. The significance of data fetching lies in:
#
# 1. **Informed Decision-Making**: Data fetching provides access to real-time and historical data, empowering organizations to make informed decisions based on accurate information and trends.
#
# 2. **Business Intelligence**: Fetching data from diverse sources enables businesses to gain insights into market trends, customer behavior, and competitor activities, aiding in strategic planning and performance evaluation.
#
# 3. **Research and Innovation**: Researchers rely on data fetching to gather empirical evidence, conduct analyses, and validate hypotheses across various domains, fostering innovation and scientific discovery.
#
# 4. **Personalization**: Data fetching facilitates the delivery of personalized experiences in sectors such as e-commerce, entertainment, and healthcare, enhancing customer satisfaction and engagement.
#
# ## Methods of Data Fetching
# There are several methods to fetch data from different sources, each suited to specific requirements and use cases:
#
# 1. **Web Scraping**: This involves extracting data directly from web pages using automated scripts or tools. While effective for accessing publicly available information, web scraping may face challenges related to website structure and legality.
#
# 2. **File Transfer**: Data can be fetched by transferring files from one system to another using protocols like FTP (File Transfer Protocol) or SFTP (Secure File Transfer Protocol). This method is commonly used for batch data transfers.
#
# 3. **Database Queries**: Fetching data from databases involves executing queries using SQL (Structured Query Language) or NoSQL (Not Only SQL) languages to retrieve specific information from structured datasets stored in relational or non-relational databases.
#
# 4. **API (Application Programming Interface)**: APIs provide a standardized way for different software applications to communicate and exchange data. They offer a structured interface for accessing specific functionalities and datasets, making them a powerful and versatile method for data fetching.

# %% [markdown]
# ### Example: YouTube API
#
# The YouTube API is a specific API provided by Google that allows developers to access and interact with YouTube's features and data programmatically. With the YouTube API, developers can perform tasks such as retrieving video information, uploading videos, managing playlists, and accessing analytics data.
#
# In the context of our project, we will focus on learning how to fetch data from YouTube using its API. By leveraging the YouTube API, we can programmatically retrieve trending videos, access metadata such as titles, descriptions, and view counts, and incorporate this data into our analytics pipelines or applications. Understanding how to interact with the YouTube API opens up opportunities for data-driven insights and innovation in various domains, including marketing, content creation, and audience engagement.

# %% [markdown]
# ### Introduction to API
# An API, or Application Programming Interface, is a set of rules, protocols, and tools that allows different software applications to communicate with each other. APIs define the methods and data formats that applications can use to request and exchange information.
#
# **Key Characteristics of APIs:**
# - **Standardization**: APIs provide a standardized way for applications to interact, ensuring compatibility and interoperability across different systems.
# - **Abstraction**: APIs abstract the underlying complexities of systems, allowing developers to access functionality or data without needing to understand the internal workings.
# - **Security**: APIs often incorporate authentication and authorization mechanisms to control access to sensitive data and resources.
# - **Scalability**: APIs are designed to handle large volumes of requests efficiently, enabling scalability and performance optimization.

# %% [markdown]
# # Obtaining a YouTube API Key and Creating a YouTube API Client
#
# **1. Sign in to Google Developer Console**
# - Go to the [Google Developer Console](https://console.developers.google.com/).
# - Sign in with your Google account or create one if you don't have it already.
#
# **2. Create a New Project**
# - Once signed in, create a new project by clicking on the "Select a project" dropdown menu at the top of the page and then clicking on the "+ New Project" button.
# - Enter a name for your project and click "Create".
#
# **3. Enable the YouTube Data API v3**
# - In the Google Developer Console, navigate to the "Library" section from the left sidebar.
# - Search for "YouTube Data API v3" and click on it.
# - Click the "Enable" button to enable the API for your project.
#
# **4. Create API Key**
# - After enabling the YouTube Data API v3, navigate to the "Credentials" section from the left sidebar.
# - Click on the "Create credentials" dropdown menu and select "API key".
# - A dialog will appear displaying your API key. Copy this API key and store it securely.
#
# **5. Secure Your API Key**
# - It's essential to keep your API key secure to prevent unauthorized access and usage. Consider restricting the API key to only allow requests from specific websites or applications.
#
# **6. Integrate API Key into Your Application**
# - In your Python script, import the necessary libraries (`dotenv` for managing environment variables, `os` for interacting with the operating system).
# - Use the `load_dotenv` function to load environment variables from a `.env` file. Ensure that you have the `python-dotenv` library installed (`pip install python-dotenv`).
# - Set your YouTube API key as an environment variable in the `.env` file. For example:
#   ```
#   YOUTUBE_API_KEY=YOUR_API_KEY_HERE
#   ```

# %% [markdown]
# ## Library Preparation

# %%
import os
from dotenv import load_dotenv

from datetime import datetime, timezone
import json # handling json file
import isodate # handling datetime
from googleapiclient.discovery import build

# %%
# load API key from .env file
load_dotenv("dags/.env") # path only for trial
api_key = os.environ.get("YOUTUBE_API_KEY")

# %% [markdown]
# **Note**: Later, use `"/opt/airflow/dags/..."` for docker purpose

# %% [markdown]
# ## Access the API in Your Script
#
# - Within your Python script, import the `dotenv` and `os` libraries to access the API key.
# - Use the `os.environ.get()` function to retrieve the API key from the environment variables.
# - With the API key obtained, you can now create a YouTube API client using the `build` function from the `googleapiclient.discovery` module.

# %%
# create YouTube API client
youtube = build("youtube", "v3", developerKey=api_key)

# %% [markdown]
# By following these steps, you can obtain a YouTube API key and create a YouTube API client in your Python script. This allows you to programmatically interact with the YouTube Data API, fetching data such as trending videos, video metadata, and analytics information for further processing or analysis in your applications or workflows. Remember to keep your API key secure and adhere to Google's usage policies to avoid any potential issues or restrictions.

# %% [markdown]
# # Fetching Videos Using YouTube API

# %% [markdown]
# ## 1. Make a Single API Request for Videos
# Let's begin by taking our first step into accessing YouTube's vast video data through its API. We'll make a single request tailored to our criteria, fetching videos based on specific parameters.
#
# This initial action lays the foundation for our journey, offering a fundamental understanding of how to engage with the API and retrieve essential data.

# %%
region_code='ID'

# %%
# make API request for videos
request = youtube.videos().list(

    # define the parts of the video data to retrieve
    part="snippet,contentDetails,statistics",  

    # specify the type of chart to fetch videos from
    chart="mostPopular",  

    # specify the region based on ISO 3166-1 alpha-2 country code
    regionCode=region_code,  

    # define the maximum number of videos to retrieve in a single request (1-50)
    maxResults=50  
)

# %% [markdown]
# Certainly, let's break down the purpose of each parameter in the API request for a clearer understanding:
#
# - `part`: This parameter specifies which parts of the video resource to include in the API response. In this case, we're requesting the `snippet` (basic details like title, description), `contentDetails` (information about the video content like duration), and `statistics` (metrics like view counts, likes, comments) parts.
#
# - `chart`: The `chart` parameter determines the type of chart to retrieve videos from.
#
# - `regionCode`: This parameter specifies the region for which to fetch videos. It uses the ISO 3166-1 alpha-2 country code format to identify the desired region.
#
# - `maxResults`: The `maxResults` parameter sets the maximum number of videos to retrieve in a single API request. In this case, we're fetching up to 50 videos at a time, which is the maximum allowed by the YouTube API.
#
# **Note:** Detail documentation about `youtube.video.list()` parameters, you can check [here](https://developers.google.com/youtube/v3/docs/videos/list).
#
# By providing these parameters in our API request, we define the scope and criteria for fetching videos from YouTube, tailoring the data retrieval process to our specific needs and objectives.

# %% [markdown]
# ## 2. Execute a Single API Requests for Videos

# %% [markdown]
# After that, let's execute the requests using `execute()` function. This function is like pressing the "send" button on an email. It's what actually sends our request to YouTube's servers, asking for the videos we want. Once we hit "send" (or call `execute()`), YouTube gets our request, processes it, and sends back the information we asked for in a response. This response contains the videos we requested, along with their details like titles, views, and more.

# %%
response = request.execute()
response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'VztUde9rJ5agADJsrNY60gJ4OFM',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'ELrQJuz8aLr0qnwwmOqOL3Ndbi8',
#    'id': '4ofJpOEXrZs',
#    'snippet': {'publishedAt': '2024-05-03T22:00:08Z',
#     'channelId': 'UCn_FAXem2-e3HQvmK-mOH4g',
#     'title': 'THE AMAZING DIGITAL CIRCUS - Ep 2: Candy Carrier Chaos!',
#     'description': 'The gang are BACK for a WAaAaAaACKY candy filled adventure! They also discover that their lives literally have no meaning. Woohoo! So waaccky!!!!! \n\nALSOOO we just dropped the entire main Digital Circus characters as PLUSHIES!!!: https://digitalcircus.store/ Consider getting one to help support the production of more episodes. No pressure though! Have a great day ❤️',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'GLITCH',
#     'tags': ['meta runner',
#      'glitch productions',
#      'funny',
#      'video game',
#      'webtoon',
#      'cartoon',
#      '3d animation',
#      'animation',
#      '2d animation',
#      '3d art',
#      'animated web series',
#      'web series',
#      'online animation',
#      'newgrounds',
#      'nintendo',
#      'fortnite',
#      'minecraft',
#      'smg4',
#      'mario',
#      'supermarioglitchy4',
#      'anime',
#      'western shounen',
#      'naruto',
#      'my hero academia',
#      'zelda',
#      'glitch'],
#     'categoryId': '1',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'THE AMAZING DIGITAL CIRCUS - Ep 2: Candy Carrier Chaos!',
#      'description': 'The gang are BACK for a WAaAaAaACKY candy filled adventure! They also discover that their lives literally have no meaning. Woohoo! So waaccky!!!!! \n\nALSOOO we just dropped the entire main Digital Circus characters as PLUSHIES!!!: https://digitalcircus.store/ Consider getting one to help support the production of more episodes. No pressure though! Have a great day ❤️'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT25M14S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '37702723',
#     'likeCount': '2532340',
#     'favoriteCount': '0',
#     'commentCount': '234462'}},
#   {'kind': 'youtube#video',
#    'etag': 'bNJsDzfSwKIcEGVY7GRVyOiiY7M',
#    'id': 'exNL0QTdhWg',
#    'snippet': {'publishedAt': '2024-05-04T11:30:16Z',
#     'channelId': 'UCaTnE9YXQ-re5774VD_ck3A',
#     'title': 'NGE-RATING SEMUA ROBOSEN TRANSFORMERS YANG PERNAH DIBUAT!',
#     'description': 'Di video ini gue bakal rating semua Robot Transformer keluaran Robosen Licensed by Hasbro mulai dari Optimus Prime, Grimlock, Bumblebee sampe ke Megatron! Kira-kira, seperti apa penilaian gue dari semua robot yang pernah diproduksi Robosen ini? Saksikan hanya di channel review mainan terbaik abad ini!\n- MR\n\nBELI ROBOSEN TRANSFORMERS:\nhttps://www.robosen.com\n\nSUBSCRIBE 2ND CHANNEL GUE:\nhttps://www.youtube.com/channel/UC6N8-HIEvJtXP6ASqdH13Ag\n\nFOLLOW INSTAGRAM GUE BUAT BOCORAN MAINAN YANG BAKAL DIREVIEW:\nInstagram: http://instagram.com/medyrenaldy/\n\nMainan bekas gue review biasa dijual disini:\nhttps://invol.co/cl3h15c\n\nLink beli mainan yang lain\nhttps://linktr.ee/medyrenaldy\n\nBusiness Inquiries:\ninq.medyrenaldy@gmail.com\n\n#robosen #transformers',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Medy Renaldy',
#     'tags': ['transformers optimus prime',
#      'hasbro',
#      'OPTIMUS PRIME',
#      'TRANSFORMERS',
#      'robosen',
#      'robosen optimus prime',
#      'optimus prime robosen',
#      'unboxing robosen optimus prime',
#      'robosen optimus prime g1',
#      'robosen hasbro',
#      'auto-converting',
#      'auto-transforming optimus prime',
#      'megatron',
#      'megatron g1',
#      'megatron robosen',
#      'robosen megatron',
#      'review robosen megatron',
#      'unboxing robosen megatron',
#      'robosen g1',
#      'auto converting robot',
#      'g1',
#      'robosen grimlock',
#      'robosen bumblebee',
#      'grimlock',
#      'bumblebee',
#      'grimlock robosen',
#      'bumblebee robosen'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'NGE-RATING SEMUA ROBOSEN TRANSFORMERS YANG PERNAH DIBUAT!',
#      'description': 'Di video ini gue bakal rating semua Robot Transformer keluaran Robosen Licensed by Hasbro mulai dari Optimus Prime, Grimlock, Bumblebee sampe ke Megatron! Kira-kira, seperti apa penilaian gue dari semua robot yang pernah diproduksi Robosen ini? Saksikan hanya di channel review mainan terbaik abad ini!\n- MR\n\nBELI ROBOSEN TRANSFORMERS:\nhttps://www.robosen.com\n\nSUBSCRIBE 2ND CHANNEL GUE:\nhttps://www.youtube.com/channel/UC6N8-HIEvJtXP6ASqdH13Ag\n\nFOLLOW INSTAGRAM GUE BUAT BOCORAN MAINAN YANG BAKAL DIREVIEW:\nInstagram: http://instagram.com/medyrenaldy/\n\nMainan bekas gue review biasa dijual disini:\nhttps://invol.co/cl3h15c\n\nLink beli mainan yang lain\nhttps://linktr.ee/medyrenaldy\n\nBusiness Inquiries:\ninq.medyrenaldy@gmail.com\n\n#robosen #transformers'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT18M10S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '766791',
#     'likeCount': '23009',
#     'favoriteCount': '0',
#     'commentCount': '3467'}},
#   {'kind': 'youtube#video',
#    'etag': 'J5P3h22fppg0manon31VYWf5wxA',
#    'id': 'zUVcKpUnfq0',
#    'snippet': {'publishedAt': '2024-05-04T12:00:55Z',
#     'channelId': 'UCxgTbIHzT8TxZh9L4s5QKxA',
#     'title': 'ARAFAH NGAKU SIAPA PACARNYA SEKARANG! - OMWEN',
#     'description': '#KOMEDI #WENDICAGUR \n==========================\nFind Me\n\n@wendicagur\nhttps://www.instagram.com/wendicagur/\n\n@wendicagurofficial\nhttps://www.instagram.com/woyproject/\n\n\n\n=================================\n\nFor Business/Endorse :\nCP : +62877 880 218 15 (INDRI)\n\n\nMakasih buat kalian semua yang udah nyempetin nonton video kita ya. Jangan lupa like, comment jika kalian ada ide untuk kita, share untuk membagikan keseruan kami dan subscribe supaya kalian selalu update kegiatan kita :)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'WENDI CAGUR',
#     'tags': ['wctv',
#      'wendi cagur televisi',
#      'wendi',
#      'wendy',
#      'wendi cagur',
#      'wendy cagur',
#      'keluarga artis',
#      'video lucu',
#      'lucu',
#      'anak artis',
#      'jakarta',
#      'indonesia',
#      'hits',
#      'tranding',
#      'sitcom',
#      'komedi',
#      'DEGDEGZIER',
#      'PARENTEN',
#      'FAKEINKSHIT',
#      'GAREM',
#      'PODCAST',
#      'DEDDY CORBUZIER',
#      'BTS',
#      'LAPOR PAK',
#      'latah',
#      'anak buah wendi',
#      'wendi latah'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'ARAFAH NGAKU SIAPA PACARNYA SEKARANG! - OMWEN',
#      'description': '#KOMEDI #WENDICAGUR \n==========================\nFind Me\n\n@wendicagur\nhttps://www.instagram.com/wendicagur/\n\n@wendicagurofficial\nhttps://www.instagram.com/woyproject/\n\n\n\n=================================\n\nFor Business/Endorse :\nCP : +62877 880 218 15 (INDRI)\n\n\nMakasih buat kalian semua yang udah nyempetin nonton video kita ya. Jangan lupa like, comment jika kalian ada ide untuk kita, share untuk membagikan keseruan kami dan subscribe supaya kalian selalu update kegiatan kita :)'}},
#    'contentDetails': {'duration': 'PT44M13S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '207703',
#     'likeCount': '4991',
#     'favoriteCount': '0',
#     'commentCount': '262'}},
#   {'kind': 'youtube#video',
#    'etag': 'yrL2V7zzbUv74cImhHVQFf99Hg8',
#    'id': 'AfPbJeTE8dQ',
#    'snippet': {'publishedAt': '2024-05-04T11:12:35Z',
#     'channelId': 'UCA_fIuIBkjjO5IfK50Iqs7w',
#     'title': 'KELUARGA BARU KU PART 5 (TAMAT) - Animasi Sekolah',
#     'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Dhot Design',
#     'tags': ['dhot design',
#      'dhokona',
#      'animasi sekolah',
#      'animasi tentang sekolahan',
#      'animasi lucu sekolah',
#      'animasi tentang anak sekolah',
#      'animasi sekolah sma',
#      'animasi kocak bikin ngakak',
#      'animasi lucu anak sma',
#      'animasi sekolah indonesia',
#      'anime school',
#      'anime sekolahan',
#      'kartun lucu sekolah'],
#     'categoryId': '1',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'id',
#     'localized': {'title': 'KELUARGA BARU KU PART 5 (TAMAT) - Animasi Sekolah',
#      'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT11M1S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '4198713',
#     'likeCount': '202320',
#     'favoriteCount': '0',
#     'commentCount': '19570'}},
#   {'kind': 'youtube#video',
#    'etag': '-5UwaKsFj9rKVgO1cJ9lnn5JOIk',
#    'id': 'LCEhBBk080I',
#    'snippet': {'publishedAt': '2024-05-03T03:00:06Z',
#     'channelId': 'UCsSsgPaZ2GSmO6il8Cb5iGA',
#     'title': 'skibidi toilet 73 (part 2)',
#     'description': 'titans confront g-toilet\n\nfull-screen version\n\nRespectful assets used in the video:\nsuits - https://steamcommunity.com/sharedfiles/filedetails/?id=2849230339\nspeakers models by ivip -https://steamcommunity.com/sharedfiles/filedetails/?id=2680336465\nhttps://steamcommunity.com/sharedfiles/filedetails/?id=2684729253\nmap - https://steamcommunity.com/sharedfiles/filedetails/?id=1958007290\nadditional particles by @HoovyTube \n\nContact me:\ninstagram.com/dafuqboomtv\nblugrayguy@gmail.com',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LCEhBBk080I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LCEhBBk080I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LCEhBBk080I/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/LCEhBBk080I/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'DaFuq!?Boom!',
#     'tags': ['sfm animation',
#      'skibidi toilet vs cameramen',
#      'skibidi toilet',
#      'scientist skibidi',
#      'tv woman',
#      'titan cameraman',
#      'titan speakerman',
#      'skibidi toilet all episodes',
#      'titan tv man',
#      'g-toilet',
#      'gman toilet'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'skibidi toilet 73 (part 2)',
#      'description': 'titans confront g-toilet\n\nfull-screen version\n\nRespectful assets used in the video:\nsuits - https://steamcommunity.com/sharedfiles/filedetails/?id=2849230339\nspeakers models by ivip -https://steamcommunity.com/sharedfiles/filedetails/?id=2680336465\nhttps://steamcommunity.com/sharedfiles/filedetails/?id=2684729253\nmap - https://steamcommunity.com/sharedfiles/filedetails/?id=1958007290\nadditional particles by @HoovyTube \n\nContact me:\ninstagram.com/dafuqboomtv\nblugrayguy@gmail.com'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT4M15S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '22953193',
#     'likeCount': '988124',
#     'favoriteCount': '0',
#     'commentCount': '123212'}},
#   {'kind': 'youtube#video',
#    'etag': 'gwJEBqQ0XH5aAudmlluJr5Fx6nM',
#    'id': 'U0zidX2JZWk',
#    'snippet': {'publishedAt': '2024-05-02T17:18:07Z',
#     'channelId': 'UCZ_CFW8uD1g8RTVaJzEc-0w',
#     'title': '[LIVE] INDONESIA VS IRAK | KUALIFIKASI PIALA DUNIA LEG 1',
#     'description': 'Timnas Indonesia tandang ke markas Irak di Basra Sport City Stadium, dan yah, sayangnya, malam itu tidak berjalan mulus bagi Garuda Muda. Mereka harus menelan kekalahan telak 5-1 dari Irak. Irak mulai dengan percaya diri dan berhasil membobol gawang Indonesia lima kali. Gol pertama datang dari Bashar Rasan yang memenangkan duel dengan Asnawi sebelum melepaskan tendangan keras. Tidak berhenti di situ, Jordi Amat, dengan kesialan, membuat gol bunuh diri yang meningkatkan keunggulan Irak. Dan gol-gol terus berdatangan dari Irak, dengan Osama Rashid, Youssef Amyn, dan Ali Al Zubaidi turut serta dalam pesta gol tersebut.\nPelatih Shin Tae-yong tidak tinggal diam melihat timnya tertinggal, dia melakukan beberapa perubahan strategis, memasukkan Rafael Struick dan membuat perubahan lain di babak kedua. Sayangnya, upaya ini tidak cukup untuk menghentikan dominasi Irak malam itu.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'RCTI Sports',
#     'categoryId': '17',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': '[LIVE] INDONESIA VS IRAK | KUALIFIKASI PIALA DUNIA LEG 1',
#      'description': 'Timnas Indonesia tandang ke markas Irak di Basra Sport City Stadium, dan yah, sayangnya, malam itu tidak berjalan mulus bagi Garuda Muda. Mereka harus menelan kekalahan telak 5-1 dari Irak. Irak mulai dengan percaya diri dan berhasil membobol gawang Indonesia lima kali. Gol pertama datang dari Bashar Rasan yang memenangkan duel dengan Asnawi sebelum melepaskan tendangan keras. Tidak berhenti di situ, Jordi Amat, dengan kesialan, membuat gol bunuh diri yang meningkatkan keunggulan Irak. Dan gol-gol terus berdatangan dari Irak, dengan Osama Rashid, Youssef Amyn, dan Ali Al Zubaidi turut serta dalam pesta gol tersebut.\nPelatih Shin Tae-yong tidak tinggal diam melihat timnya tertinggal, dia melakukan beberapa perubahan strategis, memasukkan Rafael Struick dan membuat perubahan lain di babak kedua. Sayangnya, upaya ini tidak cukup untuk menghentikan dominasi Irak malam itu.'}},
#    'contentDetails': {'duration': 'PT2H7M51S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'regionRestriction': {'allowed': ['ID']},
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '6478917',
#     'likeCount': '20060',
#     'favoriteCount': '0',
#     'commentCount': '377'}},
#   {'kind': 'youtube#video',
#    'etag': 'J_g-qxDXNVx-uEtQshYr_BZKsuY',
#    'id': 'VIC3fww3v94',
#    'snippet': {'publishedAt': '2024-05-05T01:49:22Z',
#     'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'title': 'MESSI MAKES HISTORY 🙌 Inter Miami vs. New York Red Bulls | MLS Highlights',
#     'description': 'Watch highlights of Inter Miami’s 6-2 win over New York Red Bulls that featured Lionel Messi recording a goal and five assists in the second half and Luis Suarez netting a hat trick. Messi is the first player in MLS history to have 5 assists in a single match.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'ESPN FC',
#     'tags': ['lionel messi',
#      'messi',
#      'lionel messi five assists',
#      'lionel messi 6 points',
#      'lionel messi nyrb',
#      'lionel messi mls record',
#      'luis suarez',
#      'luis suraez hat trick',
#      'inter miami',
#      'inter miami highlights',
#      'espn fc',
#      'soccer on espn',
#      'espn soccer',
#      'ESPNFC',
#      '#ESPNFC',
#      'ESPN FC',
#      'espn fc tv',
#      'soccer',
#      'espn fc highlights',
#      'football highlights',
#      'soccer highlights',
#      'mls highlights',
#      'major league soccer highlights',
#      'mls',
#      '2024 mls highlights',
#      'highlights',
#      'futbol highlights',
#      'futbol',
#      'inter miami vs new york red bulls'],
#     'categoryId': '17',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'MESSI MAKES HISTORY 🙌 Inter Miami vs. New York Red Bulls | MLS Highlights',
#      'description': 'Watch highlights of Inter Miami’s 6-2 win over New York Red Bulls that featured Lionel Messi recording a goal and five assists in the second half and Luis Suarez netting a hat trick. Messi is the first player in MLS history to have 5 assists in a single match.'}},
#    'contentDetails': {'duration': 'PT5M16S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '751071',
#     'likeCount': '18373',
#     'favoriteCount': '0',
#     'commentCount': '1793'}},
#   {'kind': 'youtube#video',
#    'etag': 'VU92YEb4tKIILlOUcW-GEwQDTZs',
#    'id': '6Hncz7ZK-q0',
#    'snippet': {'publishedAt': '2024-05-04T01:00:03Z',
#     'channelId': 'UC7J5Aaa2VxR3YNsewikrrqg',
#     'title': 'Diva Hani - LDR ( Langgeng Dayaning Rasa ) | Sagita Assololley | Dangdut (Official Music Video)',
#     'description': "Diva Hani - LDR ( Langgeng Dayaning Rasa ) | Sagita Djandhut Assololley | Dangdut (Official Music Video)\nhttps://youtu.be/6Hncz7ZK-q0\n\nTitle : LDR ( Langgeng Dayaning Rasa )\nArtis : Diva Hani\nSongwritter : Denny Caknan\nMusic : Sagita Djandhut Assololey\nSound & Stage : STUDIO ENY'S PRODUCTION\n\nProduksi : Eny's Production\nKontak Job SAGITA : 0822 3005 9699\n\nYouTube channel managed by \nMusicYes Digital Distribution\nFully YouTube Certified\nJoin MusicYes\nhttps://musicyess.com/Account/Register\n\n#Dangdut  #DivaHani #LDR #LanggengDayaningRasa",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': "ENY'S PRODUCTION",
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Diva Hani - LDR ( Langgeng Dayaning Rasa ) | Sagita Assololley | Dangdut (Official Music Video)',
#      'description': "Diva Hani - LDR ( Langgeng Dayaning Rasa ) | Sagita Djandhut Assololley | Dangdut (Official Music Video)\nhttps://youtu.be/6Hncz7ZK-q0\n\nTitle : LDR ( Langgeng Dayaning Rasa )\nArtis : Diva Hani\nSongwritter : Denny Caknan\nMusic : Sagita Djandhut Assololey\nSound & Stage : STUDIO ENY'S PRODUCTION\n\nProduksi : Eny's Production\nKontak Job SAGITA : 0822 3005 9699\n\nYouTube channel managed by \nMusicYes Digital Distribution\nFully YouTube Certified\nJoin MusicYes\nhttps://musicyess.com/Account/Register\n\n#Dangdut  #DivaHani #LDR #LanggengDayaningRasa"},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT6M22S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '137009',
#     'likeCount': '2354',
#     'favoriteCount': '0',
#     'commentCount': '265'}},
#   {'kind': 'youtube#video',
#    'etag': 'DisxFVnMPKlAm62Wvdql6inccm4',
#    'id': 'h7IZOgU1LD4',
#    'snippet': {'publishedAt': '2024-05-03T12:00:47Z',
#     'channelId': 'UCgYmNAhjfv5GYWBOfzp831Q',
#     'title': 'PREMAN JUALAN ONLINE',
#     'description': 'Setelah Djenggo membeli baju bekas dari LIVE, Maell tertarik untuk memulai berjualan baju bekas di sebuah aplikasi.\n\n#bajubekas  #onlineshop  #live\n\nhttps://www.instagram.com/maell_lee/\nhttps://www.tiktok.com/@maellleeofficial\nhttps://www.facebook.com/maellleeofficial\n-----------------\nhttps://www.instagram.com/putjeck/\nhttps://www.instagram.com/danielnestagoek/\nhttps://www.instagram.com/harrybaik_/\nhttps://www.instagram.com/firmanali_akbar/\nhttps://www.instagram.com/muhammadarba/\n\nBUSINESS INQUIRIES\nEmail : maelllee.management@gmail.com\nCp: 0821-2410-5592 (Hanan)',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Maell Lee',
#     'tags': ['maelllee',
#      'maellers',
#      'preman terkuat dibumi',
#      'video baru maell lee',
#      'bukankalengkaleng',
#      'djarbi',
#      'putjeck',
#      'ojekterkuatdibumi',
#      'ojek',
#      'preman',
#      'cabe',
#      'anggitaoktaviani',
#      'comedy',
#      'shortfilm',
#      'komedi',
#      'meme',
#      'film',
#      'lucu',
#      'cinematography',
#      'filmmakers',
#      'shortmovie'],
#     'categoryId': '23',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'id',
#     'localized': {'title': 'PREMAN JUALAN ONLINE',
#      'description': 'Setelah Djenggo membeli baju bekas dari LIVE, Maell tertarik untuk memulai berjualan baju bekas di sebuah aplikasi.\n\n#bajubekas  #onlineshop  #live\n\nhttps://www.instagram.com/maell_lee/\nhttps://www.tiktok.com/@maellleeofficial\nhttps://www.facebook.com/maellleeofficial\n-----------------\nhttps://www.instagram.com/putjeck/\nhttps://www.instagram.com/danielnestagoek/\nhttps://www.instagram.com/harrybaik_/\nhttps://www.instagram.com/firmanali_akbar/\nhttps://www.instagram.com/muhammadarba/\n\nBUSINESS INQUIRIES\nEmail : maelllee.management@gmail.com\nCp: 0821-2410-5592 (Hanan)'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT13M17S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '426635',
#     'likeCount': '12394',
#     'favoriteCount': '0',
#     'commentCount': '758'}},
#   {'kind': 'youtube#video',
#    'etag': 'NDO9RMtHaXfM0T05D494KxNEHXM',
#    'id': 'eIVMHwKVG-w',
#    'snippet': {'publishedAt': '2024-05-04T10:00:37Z',
#     'channelId': 'UCp-mzZc1U7JxRHlk-HIkP9Q',
#     'title': 'PASUKAN SENYAP Vs GENG SELATAN Part 1 - DRAMA ANIMASI',
#     'description': '#sie_em\n__________________________________________________\n\nThanks for watching\n\nSUBSCRIBE :\xa0\n\nhttps://youtube.com/@Sie_EM\n\nAkun sosial media kami :\n\nFacebook FANSPAGE :\n\nhttps://www.facebook.com/profile.php?id=100092250417361&mibextid=ZbWKwL\n\nInstagram :\xa0\nhttps://instagram.com/sieem81?igshid=MzRlODBiNWFlZA==\n\nTiktok :\nhttps://www.tiktok.com/@sie.em72?_t=8m45TGMw8Ep&_r=1\n__________________________________________________\n__________________________________________________\nTittle:\nPASUKAN SENYAP Vs GENG SELATAN PART 1 - DRAMA ANIMASI\n__________________________________________________\n__________________________________________________\nDrama animasi, film animasi si em, animasi si em, animasi si m, animasi, cerita animasi, animasi kocak, animasi lucu, kartun kocak, kartun lucu, animasi seru, cerita kartun, drama kartun, film kartun, film kartun viral, animasi viral, animasi trending, animasi menceritakan kehipan sehari hari, animasi keren, si em, si m, drama animasi sie em, pegaton, jojo, mex,genk kobra, sije, katai merah.\n_________________________________________________\n\nSIE EM',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eIVMHwKVG-w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eIVMHwKVG-w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eIVMHwKVG-w/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/eIVMHwKVG-w/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Sie EM',
#     'tags': ['Pasukan senyap', 'Geng selatan'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'id',
#     'localized': {'title': 'PASUKAN SENYAP Vs GENG SELATAN Part 1 - DRAMA ANIMASI',
#      'description': '#sie_em\n__________________________________________________\n\nThanks for watching\n\nSUBSCRIBE :\xa0\n\nhttps://youtube.com/@Sie_EM\n\nAkun sosial media kami :\n\nFacebook FANSPAGE :\n\nhttps://www.facebook.com/profile.php?id=100092250417361&mibextid=ZbWKwL\n\nInstagram :\xa0\nhttps://instagram.com/sieem81?igshid=MzRlODBiNWFlZA==\n\nTiktok :\nhttps://www.tiktok.com/@sie.em72?_t=8m45TGMw8Ep&_r=1\n__________________________________________________\n__________________________________________________\nTittle:\nPASUKAN SENYAP Vs GENG SELATAN PART 1 - DRAMA ANIMASI\n__________________________________________________\n__________________________________________________\nDrama animasi, film animasi si em, animasi si em, animasi si m, animasi, cerita animasi, animasi kocak, animasi lucu, kartun kocak, kartun lucu, animasi seru, cerita kartun, drama kartun, film kartun, film kartun viral, animasi viral, animasi trending, animasi menceritakan kehipan sehari hari, animasi keren, si em, si m, drama animasi sie em, pegaton, jojo, mex,genk kobra, sije, katai merah.\n_________________________________________________\n\nSIE EM'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT5M29S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '521305',
#     'likeCount': '29523',
#     'favoriteCount': '0',
#     'commentCount': '1796'}},
#   {'kind': 'youtube#video',
#    'etag': '9j3nXyvn_lSRr0LbOKLqi4LUKDM',
#    'id': 'PGGnOnPSHUg',
#    'snippet': {'publishedAt': '2024-05-04T16:41:31Z',
#     'channelId': 'UCTv-XvfzLX3i4IGWAm4sbmA',
#     'title': 'REAL MADRID 3 - 0 CÁDIZ CF | RESUMEN LALIGA EA SPORTS',
#     'description': 'El Real Madrid es el nuevo campeón de LALIGA EA Sports 2023/2024 tras vencer contundentemente al Cádiz CF con un golazo de Brahim Díaz y los tantos de Bellingham y Joselu #realmadrid #cadizcf #brahimdiaz J34 LALIGA EA Sports 2023/2024\n\nSuscríbete al canal de LALIGA EA SPORTS: http://goo.gl/Cp0tC',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'LALIGA EA SPORTS',
#     'tags': ['liga',
#      'laliga',
#      'football',
#      'resumen',
#      'goles',
#      'highlights',
#      'goal',
#      'gol',
#      'ea sports',
#      'ea',
#      'laliga ea sports',
#      'Resumen LALIGA',
#      'LALIGA Resumen',
#      'Highlights Real Madrid - Cadiz CF',
#      'Real Madrid - Cadiz CF Highlights',
#      'Resumen Real Madrid - Cadiz CF',
#      'Real Madrid - Cadiz CF resumen',
#      'Resumen Real Madrid',
#      'Resumen Cadiz CF',
#      'Resumen Cádiz CF',
#      'Cádiz CF',
#      'Cadiz CF',
#      'Cadiz',
#      'Real Madrid',
#      'lider',
#      'líder',
#      'leaders',
#      'champion',
#      'campeon',
#      'campeón',
#      'campeones',
#      'champions',
#      'Resumen de Real Madrid 3 - 0 Cadiz CF',
#      'Brahim goal',
#      'Brahim Diaz goal'],
#     'categoryId': '17',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'es',
#     'localized': {'title': 'REAL MADRID 3 - 0 CÁDIZ CF | RESUMEN LALIGA EA SPORTS',
#      'description': 'El Real Madrid es el nuevo campeón de LALIGA EA Sports 2023/2024 tras vencer contundentemente al Cádiz CF con un golazo de Brahim Díaz y los tantos de Bellingham y Joselu #realmadrid #cadizcf #brahimdiaz J34 LALIGA EA Sports 2023/2024\n\nSuscríbete al canal de LALIGA EA SPORTS: http://goo.gl/Cp0tC'},
#     'defaultAudioLanguage': 'es'},
#    'contentDetails': {'duration': 'PT3M2S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '2557519',
#     'likeCount': '58585',
#     'favoriteCount': '0',
#     'commentCount': '1211'}},
#   {'kind': 'youtube#video',
#    'etag': 'NansqV_vHQO4HorjqXMHYRsOPOs',
#    'id': 'Ahy-oFk5zb8',
#    'snippet': {'publishedAt': '2024-05-04T07:44:07Z',
#     'channelId': 'UCe52oeb7Xv_KaJsEzcKXJJg',
#     'title': 'SEVENTEEN (세븐틴) - MAESTRO | Show! MusicCore | MBC240504방송',
#     'description': 'SEVENTEEN (세븐틴) - MAESTRO | Show! MusicCore | MBC240504방송\n\n#SEVENTEEN #MAESTRO #MBCKPOP\n\n★★★More clips are available★★★\n\niMBC\nhttps://program.iMBC.com/musiccore\n\nWAVVE\nhttps://www.wavve.com/player/vod?programid=M_1000788100000100000\n\nⓒ MBC&iMBC 무단 전재, 재배포 및 이용(AI학습 포함) 금지',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'MBCkpop',
#     'tags': ['mbc',
#      'KPOP',
#      'dance',
#      'song',
#      'korea',
#      'korean',
#      'show',
#      'music core',
#      'live',
#      'stage',
#      'girl',
#      'boy',
#      'idol',
#      '한류',
#      'korean wave',
#      'ingigayo',
#      'show champion',
#      'mnet',
#      '엠넷',
#      'music bank',
#      '쇼 음악중심',
#      '쇼음악중심',
#      '쇼음중',
#      '음중',
#      '예능 연구소 세븐틴',
#      '세븐틴',
#      'SEVENTEEN',
#      'MAESTRO',
#      'SEVENTEEN Fancam',
#      'MAESTRO Fancam',
#      '세븐틴 직캠',
#      'SEVENTEEN MAESTRO',
#      '에스쿱스',
#      '정한',
#      '조슈아',
#      '준',
#      '호시',
#      '원우',
#      '도겸',
#      '민규',
#      '디에잇',
#      '승관',
#      '버논',
#      'JUN'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'ko',
#     'localized': {'title': 'SEVENTEEN (세븐틴) - MAESTRO | Show! MusicCore | MBC240504방송',
#      'description': 'SEVENTEEN (세븐틴) - MAESTRO | Show! MusicCore | MBC240504방송\n\n#SEVENTEEN #MAESTRO #MBCKPOP\n\n★★★More clips are available★★★\n\niMBC\nhttps://program.iMBC.com/musiccore\n\nWAVVE\nhttps://www.wavve.com/player/vod?programid=M_1000788100000100000\n\nⓒ MBC&iMBC 무단 전재, 재배포 및 이용(AI학습 포함) 금지'},
#     'defaultAudioLanguage': 'ko'},
#    'contentDetails': {'duration': 'PT3M19S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'regionRestriction': {'blocked': ['JP']},
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '430885',
#     'likeCount': '44832',
#     'favoriteCount': '0',
#     'commentCount': '1104'}},
#   {'kind': 'youtube#video',
#    'etag': 'd4X2l4ewoYHpK5UExh1ste1vSGA',
#    'id': 'feXJQ71Xl7A',
#    'snippet': {'publishedAt': '2024-05-04T15:00:10Z',
#     'channelId': 'UC6YMr57knEIYXOOKMmYAFXQ',
#     'title': "BADVILLAIN - 'Hurricane' Performance Video",
#     'description': "BADVILLAIN - 'Hurricane' Performance Video\n\nBADVILLAIN Official\nYoutube : https://www.youtube.com/channel/UCh0KpQuSJ9m0DaENZmnYwzw\nInstagram : https://www.instagram.com/BADVILLAIN_BPM\nX : https://twitter.com/BADVILLAIN_BPM\nTikTok : https://www.tiktok.com/@BADVILLAIN_BPM\n\nBig Planet Made Official\nInstagram : https://www.instagram.com/bpm_ent_official/\nTwitter : https://twitter.com/bpmentofficial\nFacebook : https://www.facebook.com/BigPlanetMade\nYoutube : https://www.youtube.com/channel/UC6YMr57knEIYXOOKMmYAFXQ\n\n#BADVILLAIN #배드빌런\n#Hurricane\n#BPM #BigPlanetMade",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'BPM Entertainment',
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': "BADVILLAIN - 'Hurricane' Performance Video",
#      'description': "BADVILLAIN - 'Hurricane' Performance Video\n\nBADVILLAIN Official\nYoutube : https://www.youtube.com/channel/UCh0KpQuSJ9m0DaENZmnYwzw\nInstagram : https://www.instagram.com/BADVILLAIN_BPM\nX : https://twitter.com/BADVILLAIN_BPM\nTikTok : https://www.tiktok.com/@BADVILLAIN_BPM\n\nBig Planet Made Official\nInstagram : https://www.instagram.com/bpm_ent_official/\nTwitter : https://twitter.com/bpmentofficial\nFacebook : https://www.facebook.com/BigPlanetMade\nYoutube : https://www.youtube.com/channel/UC6YMr57knEIYXOOKMmYAFXQ\n\n#BADVILLAIN #배드빌런\n#Hurricane\n#BPM #BigPlanetMade"},
#     'defaultAudioLanguage': 'ko'},
#    'contentDetails': {'duration': 'PT1M25S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '909666',
#     'likeCount': '29803',
#     'favoriteCount': '0',
#     'commentCount': '1801'}},
#   {'kind': 'youtube#video',
#    'etag': 'UK-e7NJhGj7Nx_BX3dHMe9Ra1RY',
#    'id': 'XIdG3zsQPvU',
#    'snippet': {'publishedAt': '2024-05-02T17:00:07Z',
#     'channelId': 'UCPtG3brN-UNv8G0B-iYaLyQ',
#     'title': 'Nabila Taqiyyah – Hanya Lolongan (Official Music Video)',
#     'description': 'Nabila Taqiyyah’s official music video for single ‘Hanya Lolongan’\nDownload and Stream: https://lnk.to/NabilaHanyaLolongan \n#NabilaTaqiyyah #HanyaLolongan\n\nAudio:\nSong written by Nabila Taqiyyah & Abenk\nProduced & Arranged by Lafa Pratomo\nDrum Prog: Lafa Pratomo\nPercussion: Lafa Pratomo\nBass: Lafa Pratomo\nPiano & Synth: Otta Tarrega\nGuitar: Lafa Pratomo\nStrings arrangement: Otta Tarrega\nStrings player: Alexey Zavgorodniy (violin 1 & Viola), Anastasiia Boiko (Violin 2), Kateryna Mytrofanova (Cello)\nMixing by Aldi Nada Permana @ Ruang Waktu Music\nMastered by Dimas Pradipta @ Summit Studios\n\nMusic Video:\nProduced by Kolmar Films\nStarring by: Nabila Taqiyyah\nProducer: Valencia Margarita\nLine Producer: Ilhamgaff\nDirector & Cam: Idho Aruan\nLighting: Risky Erge\nArt: Risky Gedhe, Ayik\nWardrobe: Fiqih Ma’alhunah\nMUA: Natalia Desiandra\nPost: grtscpe studio\nPU: Elok\nLocation: Kukuh \nBTS: Aji Pemana\n\nFollow Nabila Taqiyyah: \nInstagram: https://www.instagram.com/nabilataqiyyah/\nYouTube: https://www.youtube.com/c/NabilaTaqiyyah \nTikTok: https://www.tiktok.com/@nabilataqiyyah_ \nTwitter: https://twitter.com/Nabilataqiyyah_ \n \nLyrics:\nverse1\nKu berjalan sendirian bagaikan hilang arah tujuan\nLangit mendung, riuh angin hujan pun seakan tak berteman\n\nHilang sudah semua harapan yang di depan \nMampukah aku tetap bertahan\nHanya ingin rasakan sedikit kesenangan\n Walau kunikmati dalam diam\n \nreff:\nKau boleh menangis, tapi kembali berdiri\nKau boleh terluka, tapi hanya sementara\nJangan kau terlalu lama tenggelam\nIngatlah masih ada masa depan\nOmongan mereka hanya lolongan\nYang hilang di telan malam\n\nverse 2:\nWajar bila manusia berpura pura untuk bahagia\nPersis dalam cerita yang di tulis sempurna\nAtaukah kisah yang realita\nBerjuta sandiwara ada di depan mata\nJadilah kau pemeran utama\n\nbridge:\nUdep lam donya le cobaan, bek putoh asa..\nBek tanyoe wueh hate geutanyoe beu kong\n\nOfficial Music Video by Nabila Taqiyyah performing Hanya Lolongan © 2024 Universal Music Indonesia',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Nabila Taqiyyah',
#     'tags': ['nabila',
#      'nabila taqiyyah',
#      'thenablovers',
#      'idol',
#      'indonesian idol',
#      'hanya lolongan'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Nabila Taqiyyah – Hanya Lolongan (Official Music Video)',
#      'description': 'Nabila Taqiyyah’s official music video for single ‘Hanya Lolongan’\nDownload and Stream: https://lnk.to/NabilaHanyaLolongan \n#NabilaTaqiyyah #HanyaLolongan\n\nAudio:\nSong written by Nabila Taqiyyah & Abenk\nProduced & Arranged by Lafa Pratomo\nDrum Prog: Lafa Pratomo\nPercussion: Lafa Pratomo\nBass: Lafa Pratomo\nPiano & Synth: Otta Tarrega\nGuitar: Lafa Pratomo\nStrings arrangement: Otta Tarrega\nStrings player: Alexey Zavgorodniy (violin 1 & Viola), Anastasiia Boiko (Violin 2), Kateryna Mytrofanova (Cello)\nMixing by Aldi Nada Permana @ Ruang Waktu Music\nMastered by Dimas Pradipta @ Summit Studios\n\nMusic Video:\nProduced by Kolmar Films\nStarring by: Nabila Taqiyyah\nProducer: Valencia Margarita\nLine Producer: Ilhamgaff\nDirector & Cam: Idho Aruan\nLighting: Risky Erge\nArt: Risky Gedhe, Ayik\nWardrobe: Fiqih Ma’alhunah\nMUA: Natalia Desiandra\nPost: grtscpe studio\nPU: Elok\nLocation: Kukuh \nBTS: Aji Pemana\n\nFollow Nabila Taqiyyah: \nInstagram: https://www.instagram.com/nabilataqiyyah/\nYouTube: https://www.youtube.com/c/NabilaTaqiyyah \nTikTok: https://www.tiktok.com/@nabilataqiyyah_ \nTwitter: https://twitter.com/Nabilataqiyyah_ \n \nLyrics:\nverse1\nKu berjalan sendirian bagaikan hilang arah tujuan\nLangit mendung, riuh angin hujan pun seakan tak berteman\n\nHilang sudah semua harapan yang di depan \nMampukah aku tetap bertahan\nHanya ingin rasakan sedikit kesenangan\n Walau kunikmati dalam diam\n \nreff:\nKau boleh menangis, tapi kembali berdiri\nKau boleh terluka, tapi hanya sementara\nJangan kau terlalu lama tenggelam\nIngatlah masih ada masa depan\nOmongan mereka hanya lolongan\nYang hilang di telan malam\n\nverse 2:\nWajar bila manusia berpura pura untuk bahagia\nPersis dalam cerita yang di tulis sempurna\nAtaukah kisah yang realita\nBerjuta sandiwara ada di depan mata\nJadilah kau pemeran utama\n\nbridge:\nUdep lam donya le cobaan, bek putoh asa..\nBek tanyoe wueh hate geutanyoe beu kong\n\nOfficial Music Video by Nabila Taqiyyah performing Hanya Lolongan © 2024 Universal Music Indonesia'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT3M50S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': False,
#     'regionRestriction': {'blocked': ['BY', 'RU']},
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1375058',
#     'likeCount': '45556',
#     'favoriteCount': '0',
#     'commentCount': '20295'}},
#   {'kind': 'youtube#video',
#    'etag': 'aHp9GQDOZ7qmeSWfjiFc8KTROxc',
#    'id': 'QQL5qRmTAiw',
#    'snippet': {'publishedAt': '2024-05-03T14:18:22Z',
#     'channelId': 'UCJSF2J8Gt5OsuFI59K5eA3A',
#     'title': 'Unboxing kado wedding ikke razor - PART 1',
#     'description': 'Hai guys, sekarang kami (ikke&razor) akan aktif di akun youtube ini, karena akun youtube razor udah lama gak bisa di loginin, di urus belom bisa balik lagi akun nya 🥰',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QQL5qRmTAiw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QQL5qRmTAiw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QQL5qRmTAiw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/QQL5qRmTAiw/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'ikke jenner',
#     'categoryId': '19',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Unboxing kado wedding ikke razor - PART 1',
#      'description': 'Hai guys, sekarang kami (ikke&razor) akan aktif di akun youtube ini, karena akun youtube razor udah lama gak bisa di loginin, di urus belom bisa balik lagi akun nya 🥰'}},
#    'contentDetails': {'duration': 'PT21M13S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '139781',
#     'likeCount': '10869',
#     'favoriteCount': '0',
#     'commentCount': '628'}},
#   {'kind': 'youtube#video',
#    'etag': 'OZyfNW9c1DP2BMYBcL8V3sXH7Ps',
#    'id': '8e55e07--bQ',
#    'snippet': {'publishedAt': '2024-05-03T09:00:11Z',
#     'channelId': 'UCi3G0zvUbTE8wGKytSg-wmw',
#     'title': 'Indonesia Kalah Dari Iraq, Guinea Menunggu Di Paris | R66 Sports',
# ...
#      'lombok',
#      'surfer',
#      'istri jepang',
#      'cara taklukin cewe jepang',
#      'cara dapetin istri jepang',
#      'family vlog',
#      'kehidupan di jepang',
#      'keluarga bahagia',
#      'goal couple',
#      'keluarga lombok',
#      'kuta lombok mandalika',
#      'kisah hidup',
#      'motivasi hidup',
#      'perjuangan hidup',
#      'pernikahan beda budaya',
#      'nikah beda negara',
#      'international marriage',
#      'suami tangguh'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'BAWA ANAK PULANG DARI JEPANG KE INDONESIA ! GK NGAJAK MAMA NYA ! DIA SEDIH !',
#      'description': '.................\nSEDEKAH BERAS nya om/tante!\nhttps://trakteer.id/neojapan\n..........................................\nchannel PODCAST NEOJAPAN SOON ! https://www.youtube.com/channel/UCN4WWwEz1QMDg1Ua1tz7MEg\n\ninstagram NEOJAPAN_;  https://www.instagram.com/neojapan_/?hl=en\ninstagram Yusufkun ; https://www.instagram.com/yuu.kun21/?hl=en'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT17M12S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '340331',
#     'likeCount': '11401',
#     'favoriteCount': '0',
#     'commentCount': '537'}},
#   {'kind': 'youtube#video',
#    'etag': 'GFd7ek60aXzDwbl-PFUSOj2PtTE',
#    'id': '29twGV9khBY',
#    'snippet': {'publishedAt': '2024-04-28T05:43:06Z',
#     'channelId': 'UCUJ0K_e0ac1vBBqss99wudQ',
#     'title': '100 Hari Minecraft Jungle Apocalypse Hardcore',
#     'description': 'Aku dan Kapten @Nyashel  Harus menyelamatkan Sahabatku yang tersesat di Hutan yang penuh Zombie Apocalypse selama 100 Hari.\n\nKASIH AKU KEKUATAN 15.000 LIKE++ Dan AKU AKAN LANJUTKAN EPISODENYA❗️❗️\n\n🔴Subscribe Channel PaYuDan :\nhttps://www.youtube.com/payudan\n\n🔴Join Memberships Channel PaYuDan! dan aku jadikan kalian Jenderal Terbaik di Channel ini.\n\n🔴Playlist 100 Hari Ocean Only :\nhttps://youtube.com/playlist?list=PLidLJnGRJz0RF4IApP9aLFS6cvYyyyELX\n\n🔴Playlist 100 Hari PaYuDan :\nhttps://youtube.com/playlist?list=PLidLJnGRJz0QDUSsOvFi_uibwnMSz_Xbj\n\n🔴Jangan lupa juga untuk ikutin Sosial Media Aku yaa :\nInstragram ► https://www.instagram.com/mzahirpayudan\n\n🔴Join Discord PaYuDan SKWAD :\nhttps://discord.gg/pJtnHBE58d\n\n🔴Untuk Email Bisnis kalian bisa masukan di\nEmail ► zpayudan@gmail.com\n\n#apocalypse #minecraft #100hariminecraft',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'PaYuDan',
#     'tags': ['100 hari di minecraft tapi desert only',
#      '200 Hari di Minecraft tapi Desert Only',
#      '100 hari minecraft',
#      '100 hari di minecraft one block',
#      '100 hari di minecraft indonesia',
#      '100 hari di minecraft pe',
#      'minecraft survival',
#      'Minecraft Java',
#      'Minecraft pocket edition',
#      'Minecraft Addon',
#      'minecraft',
#      '100 hari di dalam lingkaran',
#      'minecraft 100 hari dalam lingkaran',
#      '100 hari minecraft zombie apocalypse',
#      '100 hari minecraft parasite apocalypse',
#      '100 hari minecraft parasite',
#      'parasite minecraft'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': '100 Hari Minecraft Jungle Apocalypse Hardcore',
#      'description': 'Aku dan Kapten @Nyashel  Harus menyelamatkan Sahabatku yang tersesat di Hutan yang penuh Zombie Apocalypse selama 100 Hari.\n\nKASIH AKU KEKUATAN 15.000 LIKE++ Dan AKU AKAN LANJUTKAN EPISODENYA❗️❗️\n\n🔴Subscribe Channel PaYuDan :\nhttps://www.youtube.com/payudan\n\n🔴Join Memberships Channel PaYuDan! dan aku jadikan kalian Jenderal Terbaik di Channel ini.\n\n🔴Playlist 100 Hari Ocean Only :\nhttps://youtube.com/playlist?list=PLidLJnGRJz0RF4IApP9aLFS6cvYyyyELX\n\n🔴Playlist 100 Hari PaYuDan :\nhttps://youtube.com/playlist?list=PLidLJnGRJz0QDUSsOvFi_uibwnMSz_Xbj\n\n🔴Jangan lupa juga untuk ikutin Sosial Media Aku yaa :\nInstragram ► https://www.instagram.com/mzahirpayudan\n\n🔴Join Discord PaYuDan SKWAD :\nhttps://discord.gg/pJtnHBE58d\n\n🔴Untuk Email Bisnis kalian bisa masukan di\nEmail ► zpayudan@gmail.com\n\n#apocalypse #minecraft #100hariminecraft'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT22M7S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '353194',
#     'likeCount': '8794',
#     'favoriteCount': '0',
#     'commentCount': '635'}},
#   {'kind': 'youtube#video',
#    'etag': 'zkfaZRx2CaKJsIwsipC_kKu4Ld4',
#    'id': 'Hi3_T300wWU',
#    'snippet': {'publishedAt': '2024-04-28T22:15:00Z',
#     'channelId': 'UCnKdt3zQHbCY_jdOu6QbAjg',
#     'title': 'ALHAMDULILAH OPERASI SELESAI DAN LANCAR ( JADI NGELANTUR KARENA BERJAM2 DI RUANG OPERASI) SEMANGAT',
#     'description': 'klinic yang aku percaya \n\nInstagram beautique korea:\nhttps://www.instagram.com/beautiquekorea?igshid=YmMyMTA2M2Y%3D\n\nInstagram view:\nhttps://www.instagram.com/view_plastic_surgery?igshid=YmMyMTA2M2Y%3D\nhttps://www.instagram.com/viewplasticsurgery_indo?igshid=YmMyMTA2M2Y%3D\n\nhappy banget dengan hasilnya 🥰🥰',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Hi3_T300wWU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Hi3_T300wWU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Hi3_T300wWU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Hi3_T300wWU/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Yanti Guixe family',
#     'tags': ['suami bule',
#      'keluarga bahagia',
#      'istri bule',
#      'yanti guixe family',
#      'mertua bule',
#      'keluarga bahagia di barcelona',
#      'liburan',
#      'ketemu dian bara',
#      'dian bara',
#      'ke korea',
#      'bersama dian bara',
#      'makeover',
#      'operasi selesai'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'ALHAMDULILAH OPERASI SELESAI DAN LANCAR ( JADI NGELANTUR KARENA BERJAM2 DI RUANG OPERASI) SEMANGAT',
#      'description': 'klinic yang aku percaya \n\nInstagram beautique korea:\nhttps://www.instagram.com/beautiquekorea?igshid=YmMyMTA2M2Y%3D\n\nInstagram view:\nhttps://www.instagram.com/view_plastic_surgery?igshid=YmMyMTA2M2Y%3D\nhttps://www.instagram.com/viewplasticsurgery_indo?igshid=YmMyMTA2M2Y%3D\n\nhappy banget dengan hasilnya 🥰🥰'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT23M21S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '370481',
#     'likeCount': '14570',
#     'favoriteCount': '0',
#     'commentCount': '1977'}},
#   {'kind': 'youtube#video',
#    'etag': '4ORLK0Q4B5weWZuVz4rrDrslh1U',
#    'id': 'nOJCGHAHwG0',
#    'snippet': {'publishedAt': '2024-04-25T14:00:43Z',
#     'channelId': 'UCKFC1LYWw1fbe9LNfm2vEPg',
#     'title': 'JURNALRISA X BADARAWUHI #Jurnalrisa',
#     'description': 'Geng gabung Youtube Membernya disini ya !!\nhttps://www.youtube.com/channel/UCKFC1LYWw1fbe9LNfm2vEPg/join\n\nJurnalrisa x Badarawuhi\n\nAmbil yang baik-baiknya \nBuang yang buruk-buruknya\n\nDengerin Podcasttery Jurnalrisa di Spotify \nhttps://open.spotify.com/show/6rDe63cP5fc0n8Jjv7ThTu\n\nFacebook Fans Page \n______________________________________________________\nhttps://www.facebook.com/timjurnalrisa\n______________________________________________________\n\nFollow Instagram for updates!\n______________________________________________________ \nJurnalrisa : https://www.instagram.com/tim_jurnalrisa/\nRisa Saraswati : https://www.instagram.com/risa_saraswati/\nDimasta : https://www.instagram.com/dimasta_/\nRiri : https://www.instagram.com/rianarizki/\nA Angga : https://www.instagram.com/ranggana.purwana/\nIndy : https://www.instagram.com/indyratnap/\nKakang : https://www.instagram.com/abimanyu_______/\nNicko : https://www.instagram.com/nickoirham__/\nKang Jeffry  : https://www.instagram.com/kangjeffman/\nRai : https://www.instagram.com/raisekar/\nFahrul : https://www.instagram.com/fahrulrochman_/\n\n______________________________________________________\n\nFollow Twitter\n______________________________________________________ \nhttps://twitter.com/risa_saraswati?la\n\n______________________________________________________\n\nMusic by :\n______________________________________________________\nhttps://www.instagram.com/kevinrinaldi_/',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Jurnal Risa',
#     'tags': ['jurnalrisa',
#      'risa saraswati',
#      'danur',
#      'asih',
#      'penelusuran',
#      'GhostCarTours',
#      'JurnalCeritaSejarah',
#      'TanyaRisa',
#      'peter cs',
#      'peter cs jurnalrisa',
#      'penelusuran jurnalrisa',
#      'ghostbustour',
#      'ghostcartour',
#      'jurnalrisa ghostbustour',
#      'jurnalrisa ghostcartour',
#      'kisah mistis',
#      'cerita horor',
#      'ghost house tour',
#      'live jurnalrisa',
#      'Jurnalrisa x badarawuhi',
#      'jurnalrisa terbaru',
#      'Badarawuhi'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'id',
#     'localized': {'title': 'JURNALRISA X BADARAWUHI #Jurnalrisa',
#      'description': 'Geng gabung Youtube Membernya disini ya !!\nhttps://www.youtube.com/channel/UCKFC1LYWw1fbe9LNfm2vEPg/join\n\nJurnalrisa x Badarawuhi\n\nAmbil yang baik-baiknya \nBuang yang buruk-buruknya\n\nDengerin Podcasttery Jurnalrisa di Spotify \nhttps://open.spotify.com/show/6rDe63cP5fc0n8Jjv7ThTu\n\nFacebook Fans Page \n______________________________________________________\nhttps://www.facebook.com/timjurnalrisa\n______________________________________________________\n\nFollow Instagram for updates!\n______________________________________________________ \nJurnalrisa : https://www.instagram.com/tim_jurnalrisa/\nRisa Saraswati : https://www.instagram.com/risa_saraswati/\nDimasta : https://www.instagram.com/dimasta_/\nRiri : https://www.instagram.com/rianarizki/\nA Angga : https://www.instagram.com/ranggana.purwana/\nIndy : https://www.instagram.com/indyratnap/\nKakang : https://www.instagram.com/abimanyu_______/\nNicko : https://www.instagram.com/nickoirham__/\nKang Jeffry  : https://www.instagram.com/kangjeffman/\nRai : https://www.instagram.com/raisekar/\nFahrul : https://www.instagram.com/fahrulrochman_/\n\n______________________________________________________\n\nFollow Twitter\n______________________________________________________ \nhttps://twitter.com/risa_saraswati?la\n\n______________________________________________________\n\nMusic by :\n______________________________________________________\nhttps://www.instagram.com/kevinrinaldi_/'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT48M31S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '2046372',
#     'likeCount': '97985',
#     'favoriteCount': '0',
#     'commentCount': '3170'}},
#   {'kind': 'youtube#video',
#    'etag': '64OZWPtIDNa6Ri7FDckaP5uI0Yo',
#    'id': 'Pv0iVoSZzN8',
#    'snippet': {'publishedAt': '2024-04-27T16:00:00Z',
#     'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'title': '10 Minutes To Escape Or This Room Explodes!',
#     'description': 'I didn’t expect that to happen…\nThere’s no jumping through hoops (or plate glass windows) with T-Mobile. Customers can get Magenta Status from day one, including hotel discounts on select brands, deals on rental cars, discounts on select concert tickets nationwide, and so much more. See how at https://t-mobile.com/status\n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'MrBeast',
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': '10 Minutes To Escape Or This Room Explodes!',
#      'description': 'I didn’t expect that to happen…\nThere’s no jumping through hoops (or plate glass windows) with T-Mobile. Customers can get Magenta Status from day one, including hotel discounts on select brands, deals on rental cars, discounts on select concert tickets nationwide, and so much more. See how at https://t-mobile.com/status\n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT10M',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '73883004',
#     'likeCount': '3284509',
#     'favoriteCount': '0',
#     'commentCount': '79415'}}],
#  'nextPageToken': 'CDIQAA',
#  'pageInfo': {'totalResults': 200, 'resultsPerPage': 50}}

# %% [markdown]
# If successful, this method returns a response body with the following structure:
# ```
# {
#   'kind': 'youtube#videoListResponse',
#   'etag': etag,
#   'items': [
#     video Resource
#   ],
#   'nextPageToken': string,
#   'pageInfo': {'totalResults': integer, 'resultsPerPage': integer},
# }
# ```

# %% [markdown]
# ## 3. Extract Videos from API Response
#
# Once we've sent our request, the next step is to get the videos from the response sent back by the API. This allows us to access all the important information about each video returned by the API, such as titles, descriptions, and view counts. This step is essential because it's how we actually get the data we're interested in from the API's response.

# %%
videos = response.get("items", [])
videos
# Out:
# [{'kind': 'youtube#video',
#   'etag': 'ELrQJuz8aLr0qnwwmOqOL3Ndbi8',
#   'id': '4ofJpOEXrZs',
#   'snippet': {'publishedAt': '2024-05-03T22:00:08Z',
#    'channelId': 'UCn_FAXem2-e3HQvmK-mOH4g',
#    'title': 'THE AMAZING DIGITAL CIRCUS - Ep 2: Candy Carrier Chaos!',
#    'description': 'The gang are BACK for a WAaAaAaACKY candy filled adventure! They also discover that their lives literally have no meaning. Woohoo! So waaccky!!!!! \n\nALSOOO we just dropped the entire main Digital Circus characters as PLUSHIES!!!: https://digitalcircus.store/ Consider getting one to help support the production of more episodes. No pressure though! Have a great day ❤️',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'GLITCH',
#    'tags': ['meta runner',
#     'glitch productions',
#     'funny',
#     'video game',
#     'webtoon',
#     'cartoon',
#     '3d animation',
#     'animation',
#     '2d animation',
#     '3d art',
#     'animated web series',
#     'web series',
#     'online animation',
#     'newgrounds',
#     'nintendo',
#     'fortnite',
#     'minecraft',
#     'smg4',
#     'mario',
#     'supermarioglitchy4',
#     'anime',
#     'western shounen',
#     'naruto',
#     'my hero academia',
#     'zelda',
#     'glitch'],
#    'categoryId': '1',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'THE AMAZING DIGITAL CIRCUS - Ep 2: Candy Carrier Chaos!',
#     'description': 'The gang are BACK for a WAaAaAaACKY candy filled adventure! They also discover that their lives literally have no meaning. Woohoo! So waaccky!!!!! \n\nALSOOO we just dropped the entire main Digital Circus characters as PLUSHIES!!!: https://digitalcircus.store/ Consider getting one to help support the production of more episodes. No pressure though! Have a great day ❤️'},
#    'defaultAudioLanguage': 'en'},
#   'contentDetails': {'duration': 'PT25M14S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'true',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '37702723',
#    'likeCount': '2532340',
#    'favoriteCount': '0',
#    'commentCount': '234462'}},
#  {'kind': 'youtube#video',
#   'etag': 'bNJsDzfSwKIcEGVY7GRVyOiiY7M',
#   'id': 'exNL0QTdhWg',
#   'snippet': {'publishedAt': '2024-05-04T11:30:16Z',
#    'channelId': 'UCaTnE9YXQ-re5774VD_ck3A',
#    'title': 'NGE-RATING SEMUA ROBOSEN TRANSFORMERS YANG PERNAH DIBUAT!',
#    'description': 'Di video ini gue bakal rating semua Robot Transformer keluaran Robosen Licensed by Hasbro mulai dari Optimus Prime, Grimlock, Bumblebee sampe ke Megatron! Kira-kira, seperti apa penilaian gue dari semua robot yang pernah diproduksi Robosen ini? Saksikan hanya di channel review mainan terbaik abad ini!\n- MR\n\nBELI ROBOSEN TRANSFORMERS:\nhttps://www.robosen.com\n\nSUBSCRIBE 2ND CHANNEL GUE:\nhttps://www.youtube.com/channel/UC6N8-HIEvJtXP6ASqdH13Ag\n\nFOLLOW INSTAGRAM GUE BUAT BOCORAN MAINAN YANG BAKAL DIREVIEW:\nInstagram: http://instagram.com/medyrenaldy/\n\nMainan bekas gue review biasa dijual disini:\nhttps://invol.co/cl3h15c\n\nLink beli mainan yang lain\nhttps://linktr.ee/medyrenaldy\n\nBusiness Inquiries:\ninq.medyrenaldy@gmail.com\n\n#robosen #transformers',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Medy Renaldy',
#    'tags': ['transformers optimus prime',
#     'hasbro',
#     'OPTIMUS PRIME',
#     'TRANSFORMERS',
#     'robosen',
#     'robosen optimus prime',
#     'optimus prime robosen',
#     'unboxing robosen optimus prime',
#     'robosen optimus prime g1',
#     'robosen hasbro',
#     'auto-converting',
#     'auto-transforming optimus prime',
#     'megatron',
#     'megatron g1',
#     'megatron robosen',
#     'robosen megatron',
#     'review robosen megatron',
#     'unboxing robosen megatron',
#     'robosen g1',
#     'auto converting robot',
#     'g1',
#     'robosen grimlock',
#     'robosen bumblebee',
#     'grimlock',
#     'bumblebee',
#     'grimlock robosen',
#     'bumblebee robosen'],
#    'categoryId': '24',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'NGE-RATING SEMUA ROBOSEN TRANSFORMERS YANG PERNAH DIBUAT!',
#     'description': 'Di video ini gue bakal rating semua Robot Transformer keluaran Robosen Licensed by Hasbro mulai dari Optimus Prime, Grimlock, Bumblebee sampe ke Megatron! Kira-kira, seperti apa penilaian gue dari semua robot yang pernah diproduksi Robosen ini? Saksikan hanya di channel review mainan terbaik abad ini!\n- MR\n\nBELI ROBOSEN TRANSFORMERS:\nhttps://www.robosen.com\n\nSUBSCRIBE 2ND CHANNEL GUE:\nhttps://www.youtube.com/channel/UC6N8-HIEvJtXP6ASqdH13Ag\n\nFOLLOW INSTAGRAM GUE BUAT BOCORAN MAINAN YANG BAKAL DIREVIEW:\nInstagram: http://instagram.com/medyrenaldy/\n\nMainan bekas gue review biasa dijual disini:\nhttps://invol.co/cl3h15c\n\nLink beli mainan yang lain\nhttps://linktr.ee/medyrenaldy\n\nBusiness Inquiries:\ninq.medyrenaldy@gmail.com\n\n#robosen #transformers'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT18M10S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'true',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '766791',
#    'likeCount': '23009',
#    'favoriteCount': '0',
#    'commentCount': '3467'}},
#  {'kind': 'youtube#video',
#   'etag': 'J5P3h22fppg0manon31VYWf5wxA',
#   'id': 'zUVcKpUnfq0',
#   'snippet': {'publishedAt': '2024-05-04T12:00:55Z',
#    'channelId': 'UCxgTbIHzT8TxZh9L4s5QKxA',
#    'title': 'ARAFAH NGAKU SIAPA PACARNYA SEKARANG! - OMWEN',
#    'description': '#KOMEDI #WENDICAGUR \n==========================\nFind Me\n\n@wendicagur\nhttps://www.instagram.com/wendicagur/\n\n@wendicagurofficial\nhttps://www.instagram.com/woyproject/\n\n\n\n=================================\n\nFor Business/Endorse :\nCP : +62877 880 218 15 (INDRI)\n\n\nMakasih buat kalian semua yang udah nyempetin nonton video kita ya. Jangan lupa like, comment jika kalian ada ide untuk kita, share untuk membagikan keseruan kami dan subscribe supaya kalian selalu update kegiatan kita :)',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'WENDI CAGUR',
#    'tags': ['wctv',
#     'wendi cagur televisi',
#     'wendi',
#     'wendy',
#     'wendi cagur',
#     'wendy cagur',
#     'keluarga artis',
#     'video lucu',
#     'lucu',
#     'anak artis',
#     'jakarta',
#     'indonesia',
#     'hits',
#     'tranding',
#     'sitcom',
#     'komedi',
#     'DEGDEGZIER',
#     'PARENTEN',
#     'FAKEINKSHIT',
#     'GAREM',
#     'PODCAST',
#     'DEDDY CORBUZIER',
#     'BTS',
#     'LAPOR PAK',
#     'latah',
#     'anak buah wendi',
#     'wendi latah'],
#    'categoryId': '24',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'ARAFAH NGAKU SIAPA PACARNYA SEKARANG! - OMWEN',
#     'description': '#KOMEDI #WENDICAGUR \n==========================\nFind Me\n\n@wendicagur\nhttps://www.instagram.com/wendicagur/\n\n@wendicagurofficial\nhttps://www.instagram.com/woyproject/\n\n\n\n=================================\n\nFor Business/Endorse :\nCP : +62877 880 218 15 (INDRI)\n\n\nMakasih buat kalian semua yang udah nyempetin nonton video kita ya. Jangan lupa like, comment jika kalian ada ide untuk kita, share untuk membagikan keseruan kami dan subscribe supaya kalian selalu update kegiatan kita :)'}},
#   'contentDetails': {'duration': 'PT44M13S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '207703',
#    'likeCount': '4991',
#    'favoriteCount': '0',
#    'commentCount': '262'}},
#  {'kind': 'youtube#video',
#   'etag': 'yrL2V7zzbUv74cImhHVQFf99Hg8',
#   'id': 'AfPbJeTE8dQ',
#   'snippet': {'publishedAt': '2024-05-04T11:12:35Z',
#    'channelId': 'UCA_fIuIBkjjO5IfK50Iqs7w',
#    'title': 'KELUARGA BARU KU PART 5 (TAMAT) - Animasi Sekolah',
#    'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Dhot Design',
#    'tags': ['dhot design',
#     'dhokona',
#     'animasi sekolah',
#     'animasi tentang sekolahan',
#     'animasi lucu sekolah',
#     'animasi tentang anak sekolah',
#     'animasi sekolah sma',
#     'animasi kocak bikin ngakak',
#     'animasi lucu anak sma',
#     'animasi sekolah indonesia',
#     'anime school',
#     'anime sekolahan',
#     'kartun lucu sekolah'],
#    'categoryId': '1',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'id',
#    'localized': {'title': 'KELUARGA BARU KU PART 5 (TAMAT) - Animasi Sekolah',
#     'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT11M1S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '4198713',
#    'likeCount': '202320',
#    'favoriteCount': '0',
#    'commentCount': '19570'}},
#  {'kind': 'youtube#video',
#   'etag': '-5UwaKsFj9rKVgO1cJ9lnn5JOIk',
#   'id': 'LCEhBBk080I',
#   'snippet': {'publishedAt': '2024-05-03T03:00:06Z',
#    'channelId': 'UCsSsgPaZ2GSmO6il8Cb5iGA',
#    'title': 'skibidi toilet 73 (part 2)',
#    'description': 'titans confront g-toilet\n\nfull-screen version\n\nRespectful assets used in the video:\nsuits - https://steamcommunity.com/sharedfiles/filedetails/?id=2849230339\nspeakers models by ivip -https://steamcommunity.com/sharedfiles/filedetails/?id=2680336465\nhttps://steamcommunity.com/sharedfiles/filedetails/?id=2684729253\nmap - https://steamcommunity.com/sharedfiles/filedetails/?id=1958007290\nadditional particles by @HoovyTube \n\nContact me:\ninstagram.com/dafuqboomtv\nblugrayguy@gmail.com',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LCEhBBk080I/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/LCEhBBk080I/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/LCEhBBk080I/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/LCEhBBk080I/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'DaFuq!?Boom!',
#    'tags': ['sfm animation',
#     'skibidi toilet vs cameramen',
#     'skibidi toilet',
#     'scientist skibidi',
#     'tv woman',
#     'titan cameraman',
#     'titan speakerman',
#     'skibidi toilet all episodes',
#     'titan tv man',
#     'g-toilet',
#     'gman toilet'],
#    'categoryId': '24',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'skibidi toilet 73 (part 2)',
#     'description': 'titans confront g-toilet\n\nfull-screen version\n\nRespectful assets used in the video:\nsuits - https://steamcommunity.com/sharedfiles/filedetails/?id=2849230339\nspeakers models by ivip -https://steamcommunity.com/sharedfiles/filedetails/?id=2680336465\nhttps://steamcommunity.com/sharedfiles/filedetails/?id=2684729253\nmap - https://steamcommunity.com/sharedfiles/filedetails/?id=1958007290\nadditional particles by @HoovyTube \n\nContact me:\ninstagram.com/dafuqboomtv\nblugrayguy@gmail.com'},
#    'defaultAudioLanguage': 'en'},
#   'contentDetails': {'duration': 'PT4M15S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'true',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '22953193',
#    'likeCount': '988124',
#    'favoriteCount': '0',
#    'commentCount': '123212'}},
#  {'kind': 'youtube#video',
#   'etag': 'gwJEBqQ0XH5aAudmlluJr5Fx6nM',
#   'id': 'U0zidX2JZWk',
#   'snippet': {'publishedAt': '2024-05-02T17:18:07Z',
#    'channelId': 'UCZ_CFW8uD1g8RTVaJzEc-0w',
#    'title': '[LIVE] INDONESIA VS IRAK | KUALIFIKASI PIALA DUNIA LEG 1',
#    'description': 'Timnas Indonesia tandang ke markas Irak di Basra Sport City Stadium, dan yah, sayangnya, malam itu tidak berjalan mulus bagi Garuda Muda. Mereka harus menelan kekalahan telak 5-1 dari Irak. Irak mulai dengan percaya diri dan berhasil membobol gawang Indonesia lima kali. Gol pertama datang dari Bashar Rasan yang memenangkan duel dengan Asnawi sebelum melepaskan tendangan keras. Tidak berhenti di situ, Jordi Amat, dengan kesialan, membuat gol bunuh diri yang meningkatkan keunggulan Irak. Dan gol-gol terus berdatangan dari Irak, dengan Osama Rashid, Youssef Amyn, dan Ali Al Zubaidi turut serta dalam pesta gol tersebut.\nPelatih Shin Tae-yong tidak tinggal diam melihat timnya tertinggal, dia melakukan beberapa perubahan strategis, memasukkan Rafael Struick dan membuat perubahan lain di babak kedua. Sayangnya, upaya ini tidak cukup untuk menghentikan dominasi Irak malam itu.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'RCTI Sports',
#    'categoryId': '17',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': '[LIVE] INDONESIA VS IRAK | KUALIFIKASI PIALA DUNIA LEG 1',
#     'description': 'Timnas Indonesia tandang ke markas Irak di Basra Sport City Stadium, dan yah, sayangnya, malam itu tidak berjalan mulus bagi Garuda Muda. Mereka harus menelan kekalahan telak 5-1 dari Irak. Irak mulai dengan percaya diri dan berhasil membobol gawang Indonesia lima kali. Gol pertama datang dari Bashar Rasan yang memenangkan duel dengan Asnawi sebelum melepaskan tendangan keras. Tidak berhenti di situ, Jordi Amat, dengan kesialan, membuat gol bunuh diri yang meningkatkan keunggulan Irak. Dan gol-gol terus berdatangan dari Irak, dengan Osama Rashid, Youssef Amyn, dan Ali Al Zubaidi turut serta dalam pesta gol tersebut.\nPelatih Shin Tae-yong tidak tinggal diam melihat timnya tertinggal, dia melakukan beberapa perubahan strategis, memasukkan Rafael Struick dan membuat perubahan lain di babak kedua. Sayangnya, upaya ini tidak cukup untuk menghentikan dominasi Irak malam itu.'}},
#   'contentDetails': {'duration': 'PT2H7M51S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'regionRestriction': {'allowed': ['ID']},
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '6478917',
#    'likeCount': '20060',
#    'favoriteCount': '0',
#    'commentCount': '377'}},
#  {'kind': 'youtube#video',
#   'etag': 'J_g-qxDXNVx-uEtQshYr_BZKsuY',
#   'id': 'VIC3fww3v94',
#   'snippet': {'publishedAt': '2024-05-05T01:49:22Z',
#    'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#    'title': 'MESSI MAKES HISTORY 🙌 Inter Miami vs. New York Red Bulls | MLS Highlights',
#    'description': 'Watch highlights of Inter Miami’s 6-2 win over New York Red Bulls that featured Lionel Messi recording a goal and five assists in the second half and Luis Suarez netting a hat trick. Messi is the first player in MLS history to have 5 assists in a single match.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'ESPN FC',
#    'tags': ['lionel messi',
#     'messi',
#     'lionel messi five assists',
#     'lionel messi 6 points',
#     'lionel messi nyrb',
#     'lionel messi mls record',
#     'luis suarez',
#     'luis suraez hat trick',
#     'inter miami',
#     'inter miami highlights',
#     'espn fc',
#     'soccer on espn',
#     'espn soccer',
#     'ESPNFC',
#     '#ESPNFC',
#     'ESPN FC',
#     'espn fc tv',
#     'soccer',
#     'espn fc highlights',
#     'football highlights',
#     'soccer highlights',
#     'mls highlights',
#     'major league soccer highlights',
#     'mls',
#     '2024 mls highlights',
#     'highlights',
#     'futbol highlights',
#     'futbol',
#     'inter miami vs new york red bulls'],
#    'categoryId': '17',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'MESSI MAKES HISTORY 🙌 Inter Miami vs. New York Red Bulls | MLS Highlights',
#     'description': 'Watch highlights of Inter Miami’s 6-2 win over New York Red Bulls that featured Lionel Messi recording a goal and five assists in the second half and Luis Suarez netting a hat trick. Messi is the first player in MLS history to have 5 assists in a single match.'}},
#   'contentDetails': {'duration': 'PT5M16S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '751071',
#    'likeCount': '18373',
#    'favoriteCount': '0',
#    'commentCount': '1793'}},
#  {'kind': 'youtube#video',
#   'etag': 'VU92YEb4tKIILlOUcW-GEwQDTZs',
#   'id': '6Hncz7ZK-q0',
#   'snippet': {'publishedAt': '2024-05-04T01:00:03Z',
#    'channelId': 'UC7J5Aaa2VxR3YNsewikrrqg',
#    'title': 'Diva Hani - LDR ( Langgeng Dayaning Rasa ) | Sagita Assololley | Dangdut (Official Music Video)',
#    'description': "Diva Hani - LDR ( Langgeng Dayaning Rasa ) | Sagita Djandhut Assololley | Dangdut (Official Music Video)\nhttps://youtu.be/6Hncz7ZK-q0\n\nTitle : LDR ( Langgeng Dayaning Rasa )\nArtis : Diva Hani\nSongwritter : Denny Caknan\nMusic : Sagita Djandhut Assololey\nSound & Stage : STUDIO ENY'S PRODUCTION\n\nProduksi : Eny's Production\nKontak Job SAGITA : 0822 3005 9699\n\nYouTube channel managed by \nMusicYes Digital Distribution\nFully YouTube Certified\nJoin MusicYes\nhttps://musicyess.com/Account/Register\n\n#Dangdut  #DivaHani #LDR #LanggengDayaningRasa",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': "ENY'S PRODUCTION",
#    'categoryId': '10',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'Diva Hani - LDR ( Langgeng Dayaning Rasa ) | Sagita Assololley | Dangdut (Official Music Video)',
#     'description': "Diva Hani - LDR ( Langgeng Dayaning Rasa ) | Sagita Djandhut Assololley | Dangdut (Official Music Video)\nhttps://youtu.be/6Hncz7ZK-q0\n\nTitle : LDR ( Langgeng Dayaning Rasa )\nArtis : Diva Hani\nSongwritter : Denny Caknan\nMusic : Sagita Djandhut Assololey\nSound & Stage : STUDIO ENY'S PRODUCTION\n\nProduksi : Eny's Production\nKontak Job SAGITA : 0822 3005 9699\n\nYouTube channel managed by \nMusicYes Digital Distribution\nFully YouTube Certified\nJoin MusicYes\nhttps://musicyess.com/Account/Register\n\n#Dangdut  #DivaHani #LDR #LanggengDayaningRasa"},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT6M22S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '137009',
#    'likeCount': '2354',
#    'favoriteCount': '0',
#    'commentCount': '265'}},
#  {'kind': 'youtube#video',
#   'etag': 'DisxFVnMPKlAm62Wvdql6inccm4',
#   'id': 'h7IZOgU1LD4',
#   'snippet': {'publishedAt': '2024-05-03T12:00:47Z',
#    'channelId': 'UCgYmNAhjfv5GYWBOfzp831Q',
#    'title': 'PREMAN JUALAN ONLINE',
#    'description': 'Setelah Djenggo membeli baju bekas dari LIVE, Maell tertarik untuk memulai berjualan baju bekas di sebuah aplikasi.\n\n#bajubekas  #onlineshop  #live\n\nhttps://www.instagram.com/maell_lee/\nhttps://www.tiktok.com/@maellleeofficial\nhttps://www.facebook.com/maellleeofficial\n-----------------\nhttps://www.instagram.com/putjeck/\nhttps://www.instagram.com/danielnestagoek/\nhttps://www.instagram.com/harrybaik_/\nhttps://www.instagram.com/firmanali_akbar/\nhttps://www.instagram.com/muhammadarba/\n\nBUSINESS INQUIRIES\nEmail : maelllee.management@gmail.com\nCp: 0821-2410-5592 (Hanan)',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Maell Lee',
#    'tags': ['maelllee',
#     'maellers',
#     'preman terkuat dibumi',
#     'video baru maell lee',
#     'bukankalengkaleng',
#     'djarbi',
#     'putjeck',
#     'ojekterkuatdibumi',
#     'ojek',
#     'preman',
#     'cabe',
#     'anggitaoktaviani',
#     'comedy',
#     'shortfilm',
#     'komedi',
#     'meme',
#     'film',
#     'lucu',
#     'cinematography',
#     'filmmakers',
#     'shortmovie'],
#    'categoryId': '23',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'id',
#    'localized': {'title': 'PREMAN JUALAN ONLINE',
#     'description': 'Setelah Djenggo membeli baju bekas dari LIVE, Maell tertarik untuk memulai berjualan baju bekas di sebuah aplikasi.\n\n#bajubekas  #onlineshop  #live\n\nhttps://www.instagram.com/maell_lee/\nhttps://www.tiktok.com/@maellleeofficial\nhttps://www.facebook.com/maellleeofficial\n-----------------\nhttps://www.instagram.com/putjeck/\nhttps://www.instagram.com/danielnestagoek/\nhttps://www.instagram.com/harrybaik_/\nhttps://www.instagram.com/firmanali_akbar/\nhttps://www.instagram.com/muhammadarba/\n\nBUSINESS INQUIRIES\nEmail : maelllee.management@gmail.com\nCp: 0821-2410-5592 (Hanan)'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT13M17S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '426635',
#    'likeCount': '12394',
#    'favoriteCount': '0',
#    'commentCount': '758'}},
#  {'kind': 'youtube#video',
#   'etag': 'NDO9RMtHaXfM0T05D494KxNEHXM',
#   'id': 'eIVMHwKVG-w',
#   'snippet': {'publishedAt': '2024-05-04T10:00:37Z',
#    'channelId': 'UCp-mzZc1U7JxRHlk-HIkP9Q',
#    'title': 'PASUKAN SENYAP Vs GENG SELATAN Part 1 - DRAMA ANIMASI',
#    'description': '#sie_em\n__________________________________________________\n\nThanks for watching\n\nSUBSCRIBE :\xa0\n\nhttps://youtube.com/@Sie_EM\n\nAkun sosial media kami :\n\nFacebook FANSPAGE :\n\nhttps://www.facebook.com/profile.php?id=100092250417361&mibextid=ZbWKwL\n\nInstagram :\xa0\nhttps://instagram.com/sieem81?igshid=MzRlODBiNWFlZA==\n\nTiktok :\nhttps://www.tiktok.com/@sie.em72?_t=8m45TGMw8Ep&_r=1\n__________________________________________________\n__________________________________________________\nTittle:\nPASUKAN SENYAP Vs GENG SELATAN PART 1 - DRAMA ANIMASI\n__________________________________________________\n__________________________________________________\nDrama animasi, film animasi si em, animasi si em, animasi si m, animasi, cerita animasi, animasi kocak, animasi lucu, kartun kocak, kartun lucu, animasi seru, cerita kartun, drama kartun, film kartun, film kartun viral, animasi viral, animasi trending, animasi menceritakan kehipan sehari hari, animasi keren, si em, si m, drama animasi sie em, pegaton, jojo, mex,genk kobra, sije, katai merah.\n_________________________________________________\n\nSIE EM',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eIVMHwKVG-w/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/eIVMHwKVG-w/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/eIVMHwKVG-w/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/eIVMHwKVG-w/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Sie EM',
#    'tags': ['Pasukan senyap', 'Geng selatan'],
#    'categoryId': '22',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'id',
#    'localized': {'title': 'PASUKAN SENYAP Vs GENG SELATAN Part 1 - DRAMA ANIMASI',
#     'description': '#sie_em\n__________________________________________________\n\nThanks for watching\n\nSUBSCRIBE :\xa0\n\nhttps://youtube.com/@Sie_EM\n\nAkun sosial media kami :\n\nFacebook FANSPAGE :\n\nhttps://www.facebook.com/profile.php?id=100092250417361&mibextid=ZbWKwL\n\nInstagram :\xa0\nhttps://instagram.com/sieem81?igshid=MzRlODBiNWFlZA==\n\nTiktok :\nhttps://www.tiktok.com/@sie.em72?_t=8m45TGMw8Ep&_r=1\n__________________________________________________\n__________________________________________________\nTittle:\nPASUKAN SENYAP Vs GENG SELATAN PART 1 - DRAMA ANIMASI\n__________________________________________________\n__________________________________________________\nDrama animasi, film animasi si em, animasi si em, animasi si m, animasi, cerita animasi, animasi kocak, animasi lucu, kartun kocak, kartun lucu, animasi seru, cerita kartun, drama kartun, film kartun, film kartun viral, animasi viral, animasi trending, animasi menceritakan kehipan sehari hari, animasi keren, si em, si m, drama animasi sie em, pegaton, jojo, mex,genk kobra, sije, katai merah.\n_________________________________________________\n\nSIE EM'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT5M29S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '521305',
#    'likeCount': '29523',
#    'favoriteCount': '0',
#    'commentCount': '1796'}},
#  {'kind': 'youtube#video',
#   'etag': '9j3nXyvn_lSRr0LbOKLqi4LUKDM',
#   'id': 'PGGnOnPSHUg',
#   'snippet': {'publishedAt': '2024-05-04T16:41:31Z',
#    'channelId': 'UCTv-XvfzLX3i4IGWAm4sbmA',
#    'title': 'REAL MADRID 3 - 0 CÁDIZ CF | RESUMEN LALIGA EA SPORTS',
#    'description': 'El Real Madrid es el nuevo campeón de LALIGA EA Sports 2023/2024 tras vencer contundentemente al Cádiz CF con un golazo de Brahim Díaz y los tantos de Bellingham y Joselu #realmadrid #cadizcf #brahimdiaz J34 LALIGA EA Sports 2023/2024\n\nSuscríbete al canal de LALIGA EA SPORTS: http://goo.gl/Cp0tC',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'LALIGA EA SPORTS',
#    'tags': ['liga',
#     'laliga',
#     'football',
#     'resumen',
#     'goles',
#     'highlights',
#     'goal',
#     'gol',
#     'ea sports',
#     'ea',
#     'laliga ea sports',
#     'Resumen LALIGA',
#     'LALIGA Resumen',
#     'Highlights Real Madrid - Cadiz CF',
#     'Real Madrid - Cadiz CF Highlights',
#     'Resumen Real Madrid - Cadiz CF',
#     'Real Madrid - Cadiz CF resumen',
#     'Resumen Real Madrid',
#     'Resumen Cadiz CF',
#     'Resumen Cádiz CF',
#     'Cádiz CF',
#     'Cadiz CF',
#     'Cadiz',
#     'Real Madrid',
#     'lider',
#     'líder',
#     'leaders',
#     'champion',
#     'campeon',
#     'campeón',
#     'campeones',
#     'champions',
#     'Resumen de Real Madrid 3 - 0 Cadiz CF',
#     'Brahim goal',
#     'Brahim Diaz goal'],
#    'categoryId': '17',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'es',
#    'localized': {'title': 'REAL MADRID 3 - 0 CÁDIZ CF | RESUMEN LALIGA EA SPORTS',
#     'description': 'El Real Madrid es el nuevo campeón de LALIGA EA Sports 2023/2024 tras vencer contundentemente al Cádiz CF con un golazo de Brahim Díaz y los tantos de Bellingham y Joselu #realmadrid #cadizcf #brahimdiaz J34 LALIGA EA Sports 2023/2024\n\nSuscríbete al canal de LALIGA EA SPORTS: http://goo.gl/Cp0tC'},
#    'defaultAudioLanguage': 'es'},
#   'contentDetails': {'duration': 'PT3M2S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '2557519',
#    'likeCount': '58585',
#    'favoriteCount': '0',
#    'commentCount': '1211'}},
#  {'kind': 'youtube#video',
#   'etag': 'NansqV_vHQO4HorjqXMHYRsOPOs',
#   'id': 'Ahy-oFk5zb8',
#   'snippet': {'publishedAt': '2024-05-04T07:44:07Z',
#    'channelId': 'UCe52oeb7Xv_KaJsEzcKXJJg',
#    'title': 'SEVENTEEN (세븐틴) - MAESTRO | Show! MusicCore | MBC240504방송',
#    'description': 'SEVENTEEN (세븐틴) - MAESTRO | Show! MusicCore | MBC240504방송\n\n#SEVENTEEN #MAESTRO #MBCKPOP\n\n★★★More clips are available★★★\n\niMBC\nhttps://program.iMBC.com/musiccore\n\nWAVVE\nhttps://www.wavve.com/player/vod?programid=M_1000788100000100000\n\nⓒ MBC&iMBC 무단 전재, 재배포 및 이용(AI학습 포함) 금지',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'MBCkpop',
#    'tags': ['mbc',
#     'KPOP',
#     'dance',
#     'song',
#     'korea',
#     'korean',
#     'show',
#     'music core',
#     'live',
#     'stage',
#     'girl',
#     'boy',
#     'idol',
#     '한류',
#     'korean wave',
#     'ingigayo',
#     'show champion',
#     'mnet',
#     '엠넷',
#     'music bank',
#     '쇼 음악중심',
#     '쇼음악중심',
#     '쇼음중',
#     '음중',
#     '예능 연구소 세븐틴',
#     '세븐틴',
#     'SEVENTEEN',
#     'MAESTRO',
#     'SEVENTEEN Fancam',
#     'MAESTRO Fancam',
#     '세븐틴 직캠',
#     'SEVENTEEN MAESTRO',
#     '에스쿱스',
#     '정한',
#     '조슈아',
#     '준',
#     '호시',
#     '원우',
#     '도겸',
#     '민규',
#     '디에잇',
#     '승관',
#     '버논',
#     'JUN'],
#    'categoryId': '10',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'ko',
#    'localized': {'title': 'SEVENTEEN (세븐틴) - MAESTRO | Show! MusicCore | MBC240504방송',
#     'description': 'SEVENTEEN (세븐틴) - MAESTRO | Show! MusicCore | MBC240504방송\n\n#SEVENTEEN #MAESTRO #MBCKPOP\n\n★★★More clips are available★★★\n\niMBC\nhttps://program.iMBC.com/musiccore\n\nWAVVE\nhttps://www.wavve.com/player/vod?programid=M_1000788100000100000\n\nⓒ MBC&iMBC 무단 전재, 재배포 및 이용(AI학습 포함) 금지'},
#    'defaultAudioLanguage': 'ko'},
#   'contentDetails': {'duration': 'PT3M19S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'regionRestriction': {'blocked': ['JP']},
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '430885',
#    'likeCount': '44832',
#    'favoriteCount': '0',
#    'commentCount': '1104'}},
#  {'kind': 'youtube#video',
#   'etag': 'd4X2l4ewoYHpK5UExh1ste1vSGA',
#   'id': 'feXJQ71Xl7A',
#   'snippet': {'publishedAt': '2024-05-04T15:00:10Z',
#    'channelId': 'UC6YMr57knEIYXOOKMmYAFXQ',
#    'title': "BADVILLAIN - 'Hurricane' Performance Video",
#    'description': "BADVILLAIN - 'Hurricane' Performance Video\n\nBADVILLAIN Official\nYoutube : https://www.youtube.com/channel/UCh0KpQuSJ9m0DaENZmnYwzw\nInstagram : https://www.instagram.com/BADVILLAIN_BPM\nX : https://twitter.com/BADVILLAIN_BPM\nTikTok : https://www.tiktok.com/@BADVILLAIN_BPM\n\nBig Planet Made Official\nInstagram : https://www.instagram.com/bpm_ent_official/\nTwitter : https://twitter.com/bpmentofficial\nFacebook : https://www.facebook.com/BigPlanetMade\nYoutube : https://www.youtube.com/channel/UC6YMr57knEIYXOOKMmYAFXQ\n\n#BADVILLAIN #배드빌런\n#Hurricane\n#BPM #BigPlanetMade",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'BPM Entertainment',
#    'categoryId': '10',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': "BADVILLAIN - 'Hurricane' Performance Video",
#     'description': "BADVILLAIN - 'Hurricane' Performance Video\n\nBADVILLAIN Official\nYoutube : https://www.youtube.com/channel/UCh0KpQuSJ9m0DaENZmnYwzw\nInstagram : https://www.instagram.com/BADVILLAIN_BPM\nX : https://twitter.com/BADVILLAIN_BPM\nTikTok : https://www.tiktok.com/@BADVILLAIN_BPM\n\nBig Planet Made Official\nInstagram : https://www.instagram.com/bpm_ent_official/\nTwitter : https://twitter.com/bpmentofficial\nFacebook : https://www.facebook.com/BigPlanetMade\nYoutube : https://www.youtube.com/channel/UC6YMr57knEIYXOOKMmYAFXQ\n\n#BADVILLAIN #배드빌런\n#Hurricane\n#BPM #BigPlanetMade"},
#    'defaultAudioLanguage': 'ko'},
#   'contentDetails': {'duration': 'PT1M25S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '909666',
#    'likeCount': '29803',
#    'favoriteCount': '0',
#    'commentCount': '1801'}},
#  {'kind': 'youtube#video',
#   'etag': 'UK-e7NJhGj7Nx_BX3dHMe9Ra1RY',
#   'id': 'XIdG3zsQPvU',
#   'snippet': {'publishedAt': '2024-05-02T17:00:07Z',
#    'channelId': 'UCPtG3brN-UNv8G0B-iYaLyQ',
#    'title': 'Nabila Taqiyyah – Hanya Lolongan (Official Music Video)',
#    'description': 'Nabila Taqiyyah’s official music video for single ‘Hanya Lolongan’\nDownload and Stream: https://lnk.to/NabilaHanyaLolongan \n#NabilaTaqiyyah #HanyaLolongan\n\nAudio:\nSong written by Nabila Taqiyyah & Abenk\nProduced & Arranged by Lafa Pratomo\nDrum Prog: Lafa Pratomo\nPercussion: Lafa Pratomo\nBass: Lafa Pratomo\nPiano & Synth: Otta Tarrega\nGuitar: Lafa Pratomo\nStrings arrangement: Otta Tarrega\nStrings player: Alexey Zavgorodniy (violin 1 & Viola), Anastasiia Boiko (Violin 2), Kateryna Mytrofanova (Cello)\nMixing by Aldi Nada Permana @ Ruang Waktu Music\nMastered by Dimas Pradipta @ Summit Studios\n\nMusic Video:\nProduced by Kolmar Films\nStarring by: Nabila Taqiyyah\nProducer: Valencia Margarita\nLine Producer: Ilhamgaff\nDirector & Cam: Idho Aruan\nLighting: Risky Erge\nArt: Risky Gedhe, Ayik\nWardrobe: Fiqih Ma’alhunah\nMUA: Natalia Desiandra\nPost: grtscpe studio\nPU: Elok\nLocation: Kukuh \nBTS: Aji Pemana\n\nFollow Nabila Taqiyyah: \nInstagram: https://www.instagram.com/nabilataqiyyah/\nYouTube: https://www.youtube.com/c/NabilaTaqiyyah \nTikTok: https://www.tiktok.com/@nabilataqiyyah_ \nTwitter: https://twitter.com/Nabilataqiyyah_ \n \nLyrics:\nverse1\nKu berjalan sendirian bagaikan hilang arah tujuan\nLangit mendung, riuh angin hujan pun seakan tak berteman\n\nHilang sudah semua harapan yang di depan \nMampukah aku tetap bertahan\nHanya ingin rasakan sedikit kesenangan\n Walau kunikmati dalam diam\n \nreff:\nKau boleh menangis, tapi kembali berdiri\nKau boleh terluka, tapi hanya sementara\nJangan kau terlalu lama tenggelam\nIngatlah masih ada masa depan\nOmongan mereka hanya lolongan\nYang hilang di telan malam\n\nverse 2:\nWajar bila manusia berpura pura untuk bahagia\nPersis dalam cerita yang di tulis sempurna\nAtaukah kisah yang realita\nBerjuta sandiwara ada di depan mata\nJadilah kau pemeran utama\n\nbridge:\nUdep lam donya le cobaan, bek putoh asa..\nBek tanyoe wueh hate geutanyoe beu kong\n\nOfficial Music Video by Nabila Taqiyyah performing Hanya Lolongan © 2024 Universal Music Indonesia',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Nabila Taqiyyah',
#    'tags': ['nabila',
#     'nabila taqiyyah',
#     'thenablovers',
#     'idol',
#     'indonesian idol',
#     'hanya lolongan'],
#    'categoryId': '10',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'Nabila Taqiyyah – Hanya Lolongan (Official Music Video)',
#     'description': 'Nabila Taqiyyah’s official music video for single ‘Hanya Lolongan’\nDownload and Stream: https://lnk.to/NabilaHanyaLolongan \n#NabilaTaqiyyah #HanyaLolongan\n\nAudio:\nSong written by Nabila Taqiyyah & Abenk\nProduced & Arranged by Lafa Pratomo\nDrum Prog: Lafa Pratomo\nPercussion: Lafa Pratomo\nBass: Lafa Pratomo\nPiano & Synth: Otta Tarrega\nGuitar: Lafa Pratomo\nStrings arrangement: Otta Tarrega\nStrings player: Alexey Zavgorodniy (violin 1 & Viola), Anastasiia Boiko (Violin 2), Kateryna Mytrofanova (Cello)\nMixing by Aldi Nada Permana @ Ruang Waktu Music\nMastered by Dimas Pradipta @ Summit Studios\n\nMusic Video:\nProduced by Kolmar Films\nStarring by: Nabila Taqiyyah\nProducer: Valencia Margarita\nLine Producer: Ilhamgaff\nDirector & Cam: Idho Aruan\nLighting: Risky Erge\nArt: Risky Gedhe, Ayik\nWardrobe: Fiqih Ma’alhunah\nMUA: Natalia Desiandra\nPost: grtscpe studio\nPU: Elok\nLocation: Kukuh \nBTS: Aji Pemana\n\nFollow Nabila Taqiyyah: \nInstagram: https://www.instagram.com/nabilataqiyyah/\nYouTube: https://www.youtube.com/c/NabilaTaqiyyah \nTikTok: https://www.tiktok.com/@nabilataqiyyah_ \nTwitter: https://twitter.com/Nabilataqiyyah_ \n \nLyrics:\nverse1\nKu berjalan sendirian bagaikan hilang arah tujuan\nLangit mendung, riuh angin hujan pun seakan tak berteman\n\nHilang sudah semua harapan yang di depan \nMampukah aku tetap bertahan\nHanya ingin rasakan sedikit kesenangan\n Walau kunikmati dalam diam\n \nreff:\nKau boleh menangis, tapi kembali berdiri\nKau boleh terluka, tapi hanya sementara\nJangan kau terlalu lama tenggelam\nIngatlah masih ada masa depan\nOmongan mereka hanya lolongan\nYang hilang di telan malam\n\nverse 2:\nWajar bila manusia berpura pura untuk bahagia\nPersis dalam cerita yang di tulis sempurna\nAtaukah kisah yang realita\nBerjuta sandiwara ada di depan mata\nJadilah kau pemeran utama\n\nbridge:\nUdep lam donya le cobaan, bek putoh asa..\nBek tanyoe wueh hate geutanyoe beu kong\n\nOfficial Music Video by Nabila Taqiyyah performing Hanya Lolongan © 2024 Universal Music Indonesia'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT3M50S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'true',
#    'licensedContent': False,
#    'regionRestriction': {'blocked': ['BY', 'RU']},
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '1375058',
#    'likeCount': '45556',
#    'favoriteCount': '0',
#    'commentCount': '20295'}},
#  {'kind': 'youtube#video',
#   'etag': 'aHp9GQDOZ7qmeSWfjiFc8KTROxc',
#   'id': 'QQL5qRmTAiw',
#   'snippet': {'publishedAt': '2024-05-03T14:18:22Z',
#    'channelId': 'UCJSF2J8Gt5OsuFI59K5eA3A',
#    'title': 'Unboxing kado wedding ikke razor - PART 1',
#    'description': 'Hai guys, sekarang kami (ikke&razor) akan aktif di akun youtube ini, karena akun youtube razor udah lama gak bisa di loginin, di urus belom bisa balik lagi akun nya 🥰',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QQL5qRmTAiw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/QQL5qRmTAiw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/QQL5qRmTAiw/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/QQL5qRmTAiw/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'ikke jenner',
#    'categoryId': '19',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'Unboxing kado wedding ikke razor - PART 1',
#     'description': 'Hai guys, sekarang kami (ikke&razor) akan aktif di akun youtube ini, karena akun youtube razor udah lama gak bisa di loginin, di urus belom bisa balik lagi akun nya 🥰'}},
#   'contentDetails': {'duration': 'PT21M13S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '139781',
#    'likeCount': '10869',
#    'favoriteCount': '0',
#    'commentCount': '628'}},
#  {'kind': 'youtube#video',
#   'etag': 'OZyfNW9c1DP2BMYBcL8V3sXH7Ps',
#   'id': '8e55e07--bQ',
#   'snippet': {'publishedAt': '2024-05-03T09:00:11Z',
#    'channelId': 'UCi3G0zvUbTE8wGKytSg-wmw',
#    'title': 'Indonesia Kalah Dari Iraq, Guinea Menunggu Di Paris | R66 Sports',
#    'description': "Hola Sportizen!!! Timnas Indonesia hanya mampu meraih posisi 4 di Piala Asia U23, dengan hasil ini Indonesia harus melalui babak playoff di Paris melawan Guinea. Namun, pencapaian ini sendiri sejatinya sudah melebihi ekspektasi PSSI yang menargetkan lolos 4 Besar Piala Asia U23 5 tahun mendatang. Bagi Koci dan Bung Helmy hasil ini sudah membanggakan!!!!\n\nSelain pembahasan mengenai timnas Indonesia di Piala Asia, ada pertandingan yang menurut Coach Justin membosankan karena Leg pertama UCL selalu begitu, pada episode ini Koci & Bung HY juga membagikan alasan Barcelona dan Xavi melanjutkan kerjasama, sedangkan MU ingin bebersih skuad. Simak video selengkapnya!!!!\n\n---------------------------------------------------------------------------------------------------------------------\n\nWelcome to R66 Sports YouTube Channel! Don't forget to Like, Subscribe and Share our channel to keep you update!\n\nPlease follow our Social Media :\n\nInstagram : https://www.instagram.com/r66sports\nTwitter  :  https://twitter.com/r66sports\nWebsite : https://www.linkedin.com/company/r66-media/\n                  https://r66media.com/\n\nAkun ini dikelola oleh PT. Rute Enam Puluh Enam Indonesia (R66 Media),\nUntuk info kerja sama dapat menghubungi :\n\nEmail : Partnership@R66media.com\nHP :  +62 881-0116-33866\n\n#timnasindonesia #shintaeyong #pialaasia",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8e55e07--bQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/8e55e07--bQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/8e55e07--bQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/8e55e07--bQ/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/8e55e07--bQ/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'R66 Sports',
#    'tags': ['R66 Media',
#     'r66 media',
#     'justhy',
# ...
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Neo Japan',
#    'tags': ['Neo Japan',
#     'cewe jepang',
#     'cewek jepang',
#     'reaksi orang jepang',
#     'reaksi cewe jepang',
#     'reaksi cewek jepang',
#     'kimochi',
#     'dedek jepang gemes',
#     'cewe jepang malu-malu',
#     'lombok',
#     'surfer',
#     'istri jepang',
#     'cara taklukin cewe jepang',
#     'cara dapetin istri jepang',
#     'family vlog',
#     'kehidupan di jepang',
#     'keluarga bahagia',
#     'goal couple',
#     'keluarga lombok',
#     'kuta lombok mandalika',
#     'kisah hidup',
#     'motivasi hidup',
#     'perjuangan hidup',
#     'pernikahan beda budaya',
#     'nikah beda negara',
#     'international marriage',
#     'suami tangguh'],
#    'categoryId': '22',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'BAWA ANAK PULANG DARI JEPANG KE INDONESIA ! GK NGAJAK MAMA NYA ! DIA SEDIH !',
#     'description': '.................\nSEDEKAH BERAS nya om/tante!\nhttps://trakteer.id/neojapan\n..........................................\nchannel PODCAST NEOJAPAN SOON ! https://www.youtube.com/channel/UCN4WWwEz1QMDg1Ua1tz7MEg\n\ninstagram NEOJAPAN_;  https://www.instagram.com/neojapan_/?hl=en\ninstagram Yusufkun ; https://www.instagram.com/yuu.kun21/?hl=en'},
#    'defaultAudioLanguage': 'en'},
#   'contentDetails': {'duration': 'PT17M12S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '340331',
#    'likeCount': '11401',
#    'favoriteCount': '0',
#    'commentCount': '537'}},
#  {'kind': 'youtube#video',
#   'etag': 'GFd7ek60aXzDwbl-PFUSOj2PtTE',
#   'id': '29twGV9khBY',
#   'snippet': {'publishedAt': '2024-04-28T05:43:06Z',
#    'channelId': 'UCUJ0K_e0ac1vBBqss99wudQ',
#    'title': '100 Hari Minecraft Jungle Apocalypse Hardcore',
#    'description': 'Aku dan Kapten @Nyashel  Harus menyelamatkan Sahabatku yang tersesat di Hutan yang penuh Zombie Apocalypse selama 100 Hari.\n\nKASIH AKU KEKUATAN 15.000 LIKE++ Dan AKU AKAN LANJUTKAN EPISODENYA❗️❗️\n\n🔴Subscribe Channel PaYuDan :\nhttps://www.youtube.com/payudan\n\n🔴Join Memberships Channel PaYuDan! dan aku jadikan kalian Jenderal Terbaik di Channel ini.\n\n🔴Playlist 100 Hari Ocean Only :\nhttps://youtube.com/playlist?list=PLidLJnGRJz0RF4IApP9aLFS6cvYyyyELX\n\n🔴Playlist 100 Hari PaYuDan :\nhttps://youtube.com/playlist?list=PLidLJnGRJz0QDUSsOvFi_uibwnMSz_Xbj\n\n🔴Jangan lupa juga untuk ikutin Sosial Media Aku yaa :\nInstragram ► https://www.instagram.com/mzahirpayudan\n\n🔴Join Discord PaYuDan SKWAD :\nhttps://discord.gg/pJtnHBE58d\n\n🔴Untuk Email Bisnis kalian bisa masukan di\nEmail ► zpayudan@gmail.com\n\n#apocalypse #minecraft #100hariminecraft',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'PaYuDan',
#    'tags': ['100 hari di minecraft tapi desert only',
#     '200 Hari di Minecraft tapi Desert Only',
#     '100 hari minecraft',
#     '100 hari di minecraft one block',
#     '100 hari di minecraft indonesia',
#     '100 hari di minecraft pe',
#     'minecraft survival',
#     'Minecraft Java',
#     'Minecraft pocket edition',
#     'Minecraft Addon',
#     'minecraft',
#     '100 hari di dalam lingkaran',
#     'minecraft 100 hari dalam lingkaran',
#     '100 hari minecraft zombie apocalypse',
#     '100 hari minecraft parasite apocalypse',
#     '100 hari minecraft parasite',
#     'parasite minecraft'],
#    'categoryId': '20',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': '100 Hari Minecraft Jungle Apocalypse Hardcore',
#     'description': 'Aku dan Kapten @Nyashel  Harus menyelamatkan Sahabatku yang tersesat di Hutan yang penuh Zombie Apocalypse selama 100 Hari.\n\nKASIH AKU KEKUATAN 15.000 LIKE++ Dan AKU AKAN LANJUTKAN EPISODENYA❗️❗️\n\n🔴Subscribe Channel PaYuDan :\nhttps://www.youtube.com/payudan\n\n🔴Join Memberships Channel PaYuDan! dan aku jadikan kalian Jenderal Terbaik di Channel ini.\n\n🔴Playlist 100 Hari Ocean Only :\nhttps://youtube.com/playlist?list=PLidLJnGRJz0RF4IApP9aLFS6cvYyyyELX\n\n🔴Playlist 100 Hari PaYuDan :\nhttps://youtube.com/playlist?list=PLidLJnGRJz0QDUSsOvFi_uibwnMSz_Xbj\n\n🔴Jangan lupa juga untuk ikutin Sosial Media Aku yaa :\nInstragram ► https://www.instagram.com/mzahirpayudan\n\n🔴Join Discord PaYuDan SKWAD :\nhttps://discord.gg/pJtnHBE58d\n\n🔴Untuk Email Bisnis kalian bisa masukan di\nEmail ► zpayudan@gmail.com\n\n#apocalypse #minecraft #100hariminecraft'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT22M7S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '353194',
#    'likeCount': '8794',
#    'favoriteCount': '0',
#    'commentCount': '635'}},
#  {'kind': 'youtube#video',
#   'etag': 'zkfaZRx2CaKJsIwsipC_kKu4Ld4',
#   'id': 'Hi3_T300wWU',
#   'snippet': {'publishedAt': '2024-04-28T22:15:00Z',
#    'channelId': 'UCnKdt3zQHbCY_jdOu6QbAjg',
#    'title': 'ALHAMDULILAH OPERASI SELESAI DAN LANCAR ( JADI NGELANTUR KARENA BERJAM2 DI RUANG OPERASI) SEMANGAT',
#    'description': 'klinic yang aku percaya \n\nInstagram beautique korea:\nhttps://www.instagram.com/beautiquekorea?igshid=YmMyMTA2M2Y%3D\n\nInstagram view:\nhttps://www.instagram.com/view_plastic_surgery?igshid=YmMyMTA2M2Y%3D\nhttps://www.instagram.com/viewplasticsurgery_indo?igshid=YmMyMTA2M2Y%3D\n\nhappy banget dengan hasilnya 🥰🥰',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Hi3_T300wWU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Hi3_T300wWU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Hi3_T300wWU/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Hi3_T300wWU/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'Yanti Guixe family',
#    'tags': ['suami bule',
#     'keluarga bahagia',
#     'istri bule',
#     'yanti guixe family',
#     'mertua bule',
#     'keluarga bahagia di barcelona',
#     'liburan',
#     'ketemu dian bara',
#     'dian bara',
#     'ke korea',
#     'bersama dian bara',
#     'makeover',
#     'operasi selesai'],
#    'categoryId': '22',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'ALHAMDULILAH OPERASI SELESAI DAN LANCAR ( JADI NGELANTUR KARENA BERJAM2 DI RUANG OPERASI) SEMANGAT',
#     'description': 'klinic yang aku percaya \n\nInstagram beautique korea:\nhttps://www.instagram.com/beautiquekorea?igshid=YmMyMTA2M2Y%3D\n\nInstagram view:\nhttps://www.instagram.com/view_plastic_surgery?igshid=YmMyMTA2M2Y%3D\nhttps://www.instagram.com/viewplasticsurgery_indo?igshid=YmMyMTA2M2Y%3D\n\nhappy banget dengan hasilnya 🥰🥰'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT23M21S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '370481',
#    'likeCount': '14570',
#    'favoriteCount': '0',
#    'commentCount': '1977'}},
#  {'kind': 'youtube#video',
#   'etag': '4ORLK0Q4B5weWZuVz4rrDrslh1U',
#   'id': 'nOJCGHAHwG0',
#   'snippet': {'publishedAt': '2024-04-25T14:00:43Z',
#    'channelId': 'UCKFC1LYWw1fbe9LNfm2vEPg',
#    'title': 'JURNALRISA X BADARAWUHI #Jurnalrisa',
#    'description': 'Geng gabung Youtube Membernya disini ya !!\nhttps://www.youtube.com/channel/UCKFC1LYWw1fbe9LNfm2vEPg/join\n\nJurnalrisa x Badarawuhi\n\nAmbil yang baik-baiknya \nBuang yang buruk-buruknya\n\nDengerin Podcasttery Jurnalrisa di Spotify \nhttps://open.spotify.com/show/6rDe63cP5fc0n8Jjv7ThTu\n\nFacebook Fans Page \n______________________________________________________\nhttps://www.facebook.com/timjurnalrisa\n______________________________________________________\n\nFollow Instagram for updates!\n______________________________________________________ \nJurnalrisa : https://www.instagram.com/tim_jurnalrisa/\nRisa Saraswati : https://www.instagram.com/risa_saraswati/\nDimasta : https://www.instagram.com/dimasta_/\nRiri : https://www.instagram.com/rianarizki/\nA Angga : https://www.instagram.com/ranggana.purwana/\nIndy : https://www.instagram.com/indyratnap/\nKakang : https://www.instagram.com/abimanyu_______/\nNicko : https://www.instagram.com/nickoirham__/\nKang Jeffry  : https://www.instagram.com/kangjeffman/\nRai : https://www.instagram.com/raisekar/\nFahrul : https://www.instagram.com/fahrulrochman_/\n\n______________________________________________________\n\nFollow Twitter\n______________________________________________________ \nhttps://twitter.com/risa_saraswati?la\n\n______________________________________________________\n\nMusic by :\n______________________________________________________\nhttps://www.instagram.com/kevinrinaldi_/',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Jurnal Risa',
#    'tags': ['jurnalrisa',
#     'risa saraswati',
#     'danur',
#     'asih',
#     'penelusuran',
#     'GhostCarTours',
#     'JurnalCeritaSejarah',
#     'TanyaRisa',
#     'peter cs',
#     'peter cs jurnalrisa',
#     'penelusuran jurnalrisa',
#     'ghostbustour',
#     'ghostcartour',
#     'jurnalrisa ghostbustour',
#     'jurnalrisa ghostcartour',
#     'kisah mistis',
#     'cerita horor',
#     'ghost house tour',
#     'live jurnalrisa',
#     'Jurnalrisa x badarawuhi',
#     'jurnalrisa terbaru',
#     'Badarawuhi'],
#    'categoryId': '22',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'id',
#    'localized': {'title': 'JURNALRISA X BADARAWUHI #Jurnalrisa',
#     'description': 'Geng gabung Youtube Membernya disini ya !!\nhttps://www.youtube.com/channel/UCKFC1LYWw1fbe9LNfm2vEPg/join\n\nJurnalrisa x Badarawuhi\n\nAmbil yang baik-baiknya \nBuang yang buruk-buruknya\n\nDengerin Podcasttery Jurnalrisa di Spotify \nhttps://open.spotify.com/show/6rDe63cP5fc0n8Jjv7ThTu\n\nFacebook Fans Page \n______________________________________________________\nhttps://www.facebook.com/timjurnalrisa\n______________________________________________________\n\nFollow Instagram for updates!\n______________________________________________________ \nJurnalrisa : https://www.instagram.com/tim_jurnalrisa/\nRisa Saraswati : https://www.instagram.com/risa_saraswati/\nDimasta : https://www.instagram.com/dimasta_/\nRiri : https://www.instagram.com/rianarizki/\nA Angga : https://www.instagram.com/ranggana.purwana/\nIndy : https://www.instagram.com/indyratnap/\nKakang : https://www.instagram.com/abimanyu_______/\nNicko : https://www.instagram.com/nickoirham__/\nKang Jeffry  : https://www.instagram.com/kangjeffman/\nRai : https://www.instagram.com/raisekar/\nFahrul : https://www.instagram.com/fahrulrochman_/\n\n______________________________________________________\n\nFollow Twitter\n______________________________________________________ \nhttps://twitter.com/risa_saraswati?la\n\n______________________________________________________\n\nMusic by :\n______________________________________________________\nhttps://www.instagram.com/kevinrinaldi_/'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT48M31S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '2046372',
#    'likeCount': '97985',
#    'favoriteCount': '0',
#    'commentCount': '3170'}},
#  {'kind': 'youtube#video',
#   'etag': '64OZWPtIDNa6Ri7FDckaP5uI0Yo',
#   'id': 'Pv0iVoSZzN8',
#   'snippet': {'publishedAt': '2024-04-27T16:00:00Z',
#    'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#    'title': '10 Minutes To Escape Or This Room Explodes!',
#    'description': 'I didn’t expect that to happen…\nThere’s no jumping through hoops (or plate glass windows) with T-Mobile. Customers can get Magenta Status from day one, including hotel discounts on select brands, deals on rental cars, discounts on select concert tickets nationwide, and so much more. See how at https://t-mobile.com/status\n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'MrBeast',
#    'categoryId': '24',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'en',
#    'localized': {'title': '10 Minutes To Escape Or This Room Explodes!',
#     'description': 'I didn’t expect that to happen…\nThere’s no jumping through hoops (or plate glass windows) with T-Mobile. Customers can get Magenta Status from day one, including hotel discounts on select brands, deals on rental cars, discounts on select concert tickets nationwide, and so much more. See how at https://t-mobile.com/status\n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------'},
#    'defaultAudioLanguage': 'en'},
#   'contentDetails': {'duration': 'PT10M',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'true',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '73883004',
#    'likeCount': '3284509',
#    'favoriteCount': '0',
#    'commentCount': '79415'}}]

# %% [markdown]
# The code `response.get('items', [])` is typically used in Python to retrieve a value associated with the key 'items'.

# %% [markdown]
# ## 4. Processing the Extracted Videos
#
# ### a) Basic Processing for Extracting Video Data
#
# Now that we've obtained the videos from the API response, we can proceed to process them according to our requirements. This processing step involves extracting relevant information from each video or presenting them to the user in a suitable format.

# %%
# iterates through the first five video.
for video in videos[:5]:
    title = video["snippet"]["title"]  # extract video's title
    published_at = video["snippet"]["publishedAt"]  # extract video's publish date 
    view_count = video["statistics"]["viewCount"]  # extract video's view count 

    print(f"Title: {title}, Published At: {published_at}, Views: {view_count}")
# Out:
# Title: THE AMAZING DIGITAL CIRCUS - Ep 2: Candy Carrier Chaos!, Published At: 2024-05-03T22:00:08Z, Views: 37702723
# Title: NGE-RATING SEMUA ROBOSEN TRANSFORMERS YANG PERNAH DIBUAT!, Published At: 2024-05-04T11:30:16Z, Views: 766791
# Title: ARAFAH NGAKU SIAPA PACARNYA SEKARANG! - OMWEN, Published At: 2024-05-04T12:00:55Z, Views: 207703
# Title: KELUARGA BARU KU PART 5 (TAMAT) - Animasi Sekolah, Published At: 2024-05-04T11:12:35Z, Views: 4198713
# Title: skibidi toilet 73 (part 2), Published At: 2024-05-03T03:00:06Z, Views: 22953193

# %% [markdown]
# In this code snippet, we iterate over each video in the `videos` list and extract specific details such as the title, publish date, and view count. These details can then be used for various purposes, such as analysis, reporting, or presentation to users.
#
# > However, it's important to note that the data fetched from each video may include more information beyond what is currently being printed.
#
# The first method above (basic processing) involves directly extracting specific details, such as the video title, publish date, and view count, from the 'video' object using individual assignments.
#
# > While suitable for basic extraction needs, this approach can become cumbersome as requirements become more complex.

# %% [markdown]
# ### b) Advanced Processing Techniques for Comprehensive Video Extraction

# %% [markdown]
# That's why, let's advance to extract more detailed information and append to a list (advanced approach)

# %% [markdown]
# #### Define Relevant Information to Extract

# %% [markdown]
# If the requirements are more complex or the details fetched are more numerous, the basic processing is not recommended. We need a method that allows for easier customization and scalability as new attributes can be added or modified without altering the code structure.
#
# Thus, we can use this advanced method which offers a structured approach by defining a dictionary, 'infos', which maps categories like 'snippet' and 'statistics' to desired attributes.
#
# - After that, by iterating through each category and extracting specified details, stored in a dictionary called 'video_details', this approach streamlines the extraction process and enhances code readability.

# %%
# define the relevant information to extract
infos = {
    'snippet': ['title', 'publishedAt', 'channelTitle'],
    'statistics': ['viewCount']
}

# %% [markdown]
# Expand the original `infos` dictionary into `complete_infos`, adding more attributes to ensure a thorough extraction of video data.

# %%
complete_infos = {
    'snippet':['title', 'publishedAt', 'channelTitle',
               'description', 'categoryId', 'defaultAudioLanguage', 'thumbnails'],
    'statistics':['viewCount', 'likeCount', 'commentCount'],
    'contentDetails':['duration']
}

# %% [markdown]
# With the advanced method, even as we add more information we want to fetch, there's no need to worry about longer code.

# %% [markdown]
# #### Loop Through `infos` to Get All Information

# %% [markdown]
# This loop iterates over different categories of information stored in the 'complete_infos' dictionary.

# %%
# loop through different categories of information
for key, value in complete_infos.items():
    print(f'key: {key} ||  value: {value}')
# Out:
# key: snippet ||  value: ['title', 'publishedAt', 'channelTitle', 'description', 'categoryId', 'defaultAudioLanguage', 'thumbnails']
# key: statistics ||  value: ['viewCount', 'likeCount', 'commentCount']
# key: contentDetails ||  value: ['duration']

# %% [markdown]
# Each info, represented by a key, corresponds to a list of specific details we want to extract from the videos.

# %% [markdown]
# #### Accessing Video Details

# %% [markdown]
# Within each category, the code iterates over the videos in the `videos` list. For each video, it initializes an empty dictionary called `video_details` to store its extracted details.

# %%
for video in videos:
    # for each video, it initializes an empty dictionary to store its details
    video_details = {}
    
    for key, value in complete_infos.items():
        for info in value:
            video_details[info] = video.get(key, {}).get(info)

# %% [markdown]
# Next, it loops through the specific details (`info`) listed under each category (`key`).
#
# Then, `video.get(key, {}).get(info)`: It accesses these details from the `video` object using the `get()` method. If a detail is not found, it defaults to an empty string.
#
# Those code same aim with:
#
# ```python
# if key in video and info in video[key]:
#     video_details[info] = video[key][info]
# else:
#     video_details[info] = None
# ```

# %% [markdown]
# #### Saving Extracted Details

# %% [markdown]
# ```python
# videos_list = []
#
# for video in videos:
#     # code: accessing video details
#     videos_list.append(video_details)
# ```

# %% [markdown]
# After extracting all the details for a video, the `video_details` dictionary containing these details is appended to the `videos_list`. This list will eventually contain dictionaries, each representing the extracted details of a single video.

# %% [markdown]
# Let's combine the code to the loop.

# %%
# initialize list to save videos data
videos_list = []

for video in videos:
    video_details = {}
    
    for key, value in complete_infos.items():
        for info in value:
            video_details[info] = video.get(key, {}).get(info)

    # saving extracted details
    videos_list.append(video_details)

# %%
videos_list
# Out:
# [{'title': 'THE AMAZING DIGITAL CIRCUS - Ep 2: Candy Carrier Chaos!',
#   'publishedAt': '2024-05-03T22:00:08Z',
#   'channelTitle': 'GLITCH',
#   'description': 'The gang are BACK for a WAaAaAaACKY candy filled adventure! They also discover that their lives literally have no meaning. Woohoo! So waaccky!!!!! \n\nALSOOO we just dropped the entire main Digital Circus characters as PLUSHIES!!!: https://digitalcircus.store/ Consider getting one to help support the production of more episodes. No pressure though! Have a great day ❤️',
#   'categoryId': '1',
#   'defaultAudioLanguage': 'en',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '37702723',
#   'likeCount': '2532340',
#   'commentCount': '234462',
#   'duration': 'PT25M14S'},
#  {'title': 'NGE-RATING SEMUA ROBOSEN TRANSFORMERS YANG PERNAH DIBUAT!',
#   'publishedAt': '2024-05-04T11:30:16Z',
#   'channelTitle': 'Medy Renaldy',
#   'description': 'Di video ini gue bakal rating semua Robot Transformer keluaran Robosen Licensed by Hasbro mulai dari Optimus Prime, Grimlock, Bumblebee sampe ke Megatron! Kira-kira, seperti apa penilaian gue dari semua robot yang pernah diproduksi Robosen ini? Saksikan hanya di channel review mainan terbaik abad ini!\n- MR\n\nBELI ROBOSEN TRANSFORMERS:\nhttps://www.robosen.com\n\nSUBSCRIBE 2ND CHANNEL GUE:\nhttps://www.youtube.com/channel/UC6N8-HIEvJtXP6ASqdH13Ag\n\nFOLLOW INSTAGRAM GUE BUAT BOCORAN MAINAN YANG BAKAL DIREVIEW:\nInstagram: http://instagram.com/medyrenaldy/\n\nMainan bekas gue review biasa dijual disini:\nhttps://invol.co/cl3h15c\n\nLink beli mainan yang lain\nhttps://linktr.ee/medyrenaldy\n\nBusiness Inquiries:\ninq.medyrenaldy@gmail.com\n\n#robosen #transformers',
#   'categoryId': '24',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/exNL0QTdhWg/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '766791',
#   'likeCount': '23009',
#   'commentCount': '3467',
#   'duration': 'PT18M10S'},
#  {'title': 'ARAFAH NGAKU SIAPA PACARNYA SEKARANG! - OMWEN',
#   'publishedAt': '2024-05-04T12:00:55Z',
#   'channelTitle': 'WENDI CAGUR',
#   'description': '#KOMEDI #WENDICAGUR \n==========================\nFind Me\n\n@wendicagur\nhttps://www.instagram.com/wendicagur/\n\n@wendicagurofficial\nhttps://www.instagram.com/woyproject/\n\n\n\n=================================\n\nFor Business/Endorse :\nCP : +62877 880 218 15 (INDRI)\n\n\nMakasih buat kalian semua yang udah nyempetin nonton video kita ya. Jangan lupa like, comment jika kalian ada ide untuk kita, share untuk membagikan keseruan kami dan subscribe supaya kalian selalu update kegiatan kita :)',
#   'categoryId': '24',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/zUVcKpUnfq0/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '207703',
#   'likeCount': '4991',
#   'commentCount': '262',
#   'duration': 'PT44M13S'},
#  {'title': 'KELUARGA BARU KU PART 5 (TAMAT) - Animasi Sekolah',
#   'publishedAt': '2024-05-04T11:12:35Z',
#   'channelTitle': 'Dhot Design',
#   'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.',
#   'categoryId': '1',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/AfPbJeTE8dQ/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '4198713',
#   'likeCount': '202320',
#   'commentCount': '19570',
#   'duration': 'PT11M1S'},
#  {'title': 'skibidi toilet 73 (part 2)',
#   'publishedAt': '2024-05-03T03:00:06Z',
#   'channelTitle': 'DaFuq!?Boom!',
#   'description': 'titans confront g-toilet\n\nfull-screen version\n\nRespectful assets used in the video:\nsuits - https://steamcommunity.com/sharedfiles/filedetails/?id=2849230339\nspeakers models by ivip -https://steamcommunity.com/sharedfiles/filedetails/?id=2680336465\nhttps://steamcommunity.com/sharedfiles/filedetails/?id=2684729253\nmap - https://steamcommunity.com/sharedfiles/filedetails/?id=1958007290\nadditional particles by @HoovyTube \n\nContact me:\ninstagram.com/dafuqboomtv\nblugrayguy@gmail.com',
#   'categoryId': '24',
#   'defaultAudioLanguage': 'en',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LCEhBBk080I/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/LCEhBBk080I/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/LCEhBBk080I/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/LCEhBBk080I/sddefault.jpg',
#     'width': 640,
#     'height': 480}},
#   'viewCount': '22953193',
#   'likeCount': '988124',
#   'commentCount': '123212',
#   'duration': 'PT4M15S'},
#  {'title': '[LIVE] INDONESIA VS IRAK | KUALIFIKASI PIALA DUNIA LEG 1',
#   'publishedAt': '2024-05-02T17:18:07Z',
#   'channelTitle': 'RCTI Sports',
#   'description': 'Timnas Indonesia tandang ke markas Irak di Basra Sport City Stadium, dan yah, sayangnya, malam itu tidak berjalan mulus bagi Garuda Muda. Mereka harus menelan kekalahan telak 5-1 dari Irak. Irak mulai dengan percaya diri dan berhasil membobol gawang Indonesia lima kali. Gol pertama datang dari Bashar Rasan yang memenangkan duel dengan Asnawi sebelum melepaskan tendangan keras. Tidak berhenti di situ, Jordi Amat, dengan kesialan, membuat gol bunuh diri yang meningkatkan keunggulan Irak. Dan gol-gol terus berdatangan dari Irak, dengan Osama Rashid, Youssef Amyn, dan Ali Al Zubaidi turut serta dalam pesta gol tersebut.\nPelatih Shin Tae-yong tidak tinggal diam melihat timnya tertinggal, dia melakukan beberapa perubahan strategis, memasukkan Rafael Struick dan membuat perubahan lain di babak kedua. Sayangnya, upaya ini tidak cukup untuk menghentikan dominasi Irak malam itu.',
#   'categoryId': '17',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/U0zidX2JZWk/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '6478917',
#   'likeCount': '20060',
#   'commentCount': '377',
#   'duration': 'PT2H7M51S'},
#  {'title': 'MESSI MAKES HISTORY 🙌 Inter Miami vs. New York Red Bulls | MLS Highlights',
#   'publishedAt': '2024-05-05T01:49:22Z',
#   'channelTitle': 'ESPN FC',
#   'description': 'Watch highlights of Inter Miami’s 6-2 win over New York Red Bulls that featured Lionel Messi recording a goal and five assists in the second half and Luis Suarez netting a hat trick. Messi is the first player in MLS history to have 5 assists in a single match.',
#   'categoryId': '17',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/VIC3fww3v94/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '751071',
#   'likeCount': '18373',
#   'commentCount': '1793',
#   'duration': 'PT5M16S'},
#  {'title': 'Diva Hani - LDR ( Langgeng Dayaning Rasa ) | Sagita Assololley | Dangdut (Official Music Video)',
#   'publishedAt': '2024-05-04T01:00:03Z',
#   'channelTitle': "ENY'S PRODUCTION",
#   'description': "Diva Hani - LDR ( Langgeng Dayaning Rasa ) | Sagita Djandhut Assololley | Dangdut (Official Music Video)\nhttps://youtu.be/6Hncz7ZK-q0\n\nTitle : LDR ( Langgeng Dayaning Rasa )\nArtis : Diva Hani\nSongwritter : Denny Caknan\nMusic : Sagita Djandhut Assololey\nSound & Stage : STUDIO ENY'S PRODUCTION\n\nProduksi : Eny's Production\nKontak Job SAGITA : 0822 3005 9699\n\nYouTube channel managed by \nMusicYes Digital Distribution\nFully YouTube Certified\nJoin MusicYes\nhttps://musicyess.com/Account/Register\n\n#Dangdut  #DivaHani #LDR #LanggengDayaningRasa",
#   'categoryId': '10',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/6Hncz7ZK-q0/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '137009',
#   'likeCount': '2354',
#   'commentCount': '265',
#   'duration': 'PT6M22S'},
#  {'title': 'PREMAN JUALAN ONLINE',
#   'publishedAt': '2024-05-03T12:00:47Z',
#   'channelTitle': 'Maell Lee',
#   'description': 'Setelah Djenggo membeli baju bekas dari LIVE, Maell tertarik untuk memulai berjualan baju bekas di sebuah aplikasi.\n\n#bajubekas  #onlineshop  #live\n\nhttps://www.instagram.com/maell_lee/\nhttps://www.tiktok.com/@maellleeofficial\nhttps://www.facebook.com/maellleeofficial\n-----------------\nhttps://www.instagram.com/putjeck/\nhttps://www.instagram.com/danielnestagoek/\nhttps://www.instagram.com/harrybaik_/\nhttps://www.instagram.com/firmanali_akbar/\nhttps://www.instagram.com/muhammadarba/\n\nBUSINESS INQUIRIES\nEmail : maelllee.management@gmail.com\nCp: 0821-2410-5592 (Hanan)',
#   'categoryId': '23',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/h7IZOgU1LD4/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '426635',
#   'likeCount': '12394',
#   'commentCount': '758',
#   'duration': 'PT13M17S'},
#  {'title': 'PASUKAN SENYAP Vs GENG SELATAN Part 1 - DRAMA ANIMASI',
#   'publishedAt': '2024-05-04T10:00:37Z',
#   'channelTitle': 'Sie EM',
#   'description': '#sie_em\n__________________________________________________\n\nThanks for watching\n\nSUBSCRIBE :\xa0\n\nhttps://youtube.com/@Sie_EM\n\nAkun sosial media kami :\n\nFacebook FANSPAGE :\n\nhttps://www.facebook.com/profile.php?id=100092250417361&mibextid=ZbWKwL\n\nInstagram :\xa0\nhttps://instagram.com/sieem81?igshid=MzRlODBiNWFlZA==\n\nTiktok :\nhttps://www.tiktok.com/@sie.em72?_t=8m45TGMw8Ep&_r=1\n__________________________________________________\n__________________________________________________\nTittle:\nPASUKAN SENYAP Vs GENG SELATAN PART 1 - DRAMA ANIMASI\n__________________________________________________\n__________________________________________________\nDrama animasi, film animasi si em, animasi si em, animasi si m, animasi, cerita animasi, animasi kocak, animasi lucu, kartun kocak, kartun lucu, animasi seru, cerita kartun, drama kartun, film kartun, film kartun viral, animasi viral, animasi trending, animasi menceritakan kehipan sehari hari, animasi keren, si em, si m, drama animasi sie em, pegaton, jojo, mex,genk kobra, sije, katai merah.\n_________________________________________________\n\nSIE EM',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eIVMHwKVG-w/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/eIVMHwKVG-w/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/eIVMHwKVG-w/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/eIVMHwKVG-w/sddefault.jpg',
#     'width': 640,
#     'height': 480}},
#   'viewCount': '521305',
#   'likeCount': '29523',
#   'commentCount': '1796',
#   'duration': 'PT5M29S'},
#  {'title': 'REAL MADRID 3 - 0 CÁDIZ CF | RESUMEN LALIGA EA SPORTS',
#   'publishedAt': '2024-05-04T16:41:31Z',
#   'channelTitle': 'LALIGA EA SPORTS',
#   'description': 'El Real Madrid es el nuevo campeón de LALIGA EA Sports 2023/2024 tras vencer contundentemente al Cádiz CF con un golazo de Brahim Díaz y los tantos de Bellingham y Joselu #realmadrid #cadizcf #brahimdiaz J34 LALIGA EA Sports 2023/2024\n\nSuscríbete al canal de LALIGA EA SPORTS: http://goo.gl/Cp0tC',
#   'categoryId': '17',
#   'defaultAudioLanguage': 'es',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/PGGnOnPSHUg/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '2557519',
#   'likeCount': '58585',
#   'commentCount': '1211',
#   'duration': 'PT3M2S'},
#  {'title': 'SEVENTEEN (세븐틴) - MAESTRO | Show! MusicCore | MBC240504방송',
#   'publishedAt': '2024-05-04T07:44:07Z',
#   'channelTitle': 'MBCkpop',
#   'description': 'SEVENTEEN (세븐틴) - MAESTRO | Show! MusicCore | MBC240504방송\n\n#SEVENTEEN #MAESTRO #MBCKPOP\n\n★★★More clips are available★★★\n\niMBC\nhttps://program.iMBC.com/musiccore\n\nWAVVE\nhttps://www.wavve.com/player/vod?programid=M_1000788100000100000\n\nⓒ MBC&iMBC 무단 전재, 재배포 및 이용(AI학습 포함) 금지',
#   'categoryId': '10',
#   'defaultAudioLanguage': 'ko',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/Ahy-oFk5zb8/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '430885',
#   'likeCount': '44832',
#   'commentCount': '1104',
#   'duration': 'PT3M19S'},
#  {'title': "BADVILLAIN - 'Hurricane' Performance Video",
#   'publishedAt': '2024-05-04T15:00:10Z',
#   'channelTitle': 'BPM Entertainment',
#   'description': "BADVILLAIN - 'Hurricane' Performance Video\n\nBADVILLAIN Official\nYoutube : https://www.youtube.com/channel/UCh0KpQuSJ9m0DaENZmnYwzw\nInstagram : https://www.instagram.com/BADVILLAIN_BPM\nX : https://twitter.com/BADVILLAIN_BPM\nTikTok : https://www.tiktok.com/@BADVILLAIN_BPM\n\nBig Planet Made Official\nInstagram : https://www.instagram.com/bpm_ent_official/\nTwitter : https://twitter.com/bpmentofficial\nFacebook : https://www.facebook.com/BigPlanetMade\nYoutube : https://www.youtube.com/channel/UC6YMr57knEIYXOOKMmYAFXQ\n\n#BADVILLAIN #배드빌런\n#Hurricane\n#BPM #BigPlanetMade",
#   'categoryId': '10',
#   'defaultAudioLanguage': 'ko',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/feXJQ71Xl7A/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '909666',
#   'likeCount': '29803',
#   'commentCount': '1801',
#   'duration': 'PT1M25S'},
#  {'title': 'Nabila Taqiyyah – Hanya Lolongan (Official Music Video)',
#   'publishedAt': '2024-05-02T17:00:07Z',
#   'channelTitle': 'Nabila Taqiyyah',
#   'description': 'Nabila Taqiyyah’s official music video for single ‘Hanya Lolongan’\nDownload and Stream: https://lnk.to/NabilaHanyaLolongan \n#NabilaTaqiyyah #HanyaLolongan\n\nAudio:\nSong written by Nabila Taqiyyah & Abenk\nProduced & Arranged by Lafa Pratomo\nDrum Prog: Lafa Pratomo\nPercussion: Lafa Pratomo\nBass: Lafa Pratomo\nPiano & Synth: Otta Tarrega\nGuitar: Lafa Pratomo\nStrings arrangement: Otta Tarrega\nStrings player: Alexey Zavgorodniy (violin 1 & Viola), Anastasiia Boiko (Violin 2), Kateryna Mytrofanova (Cello)\nMixing by Aldi Nada Permana @ Ruang Waktu Music\nMastered by Dimas Pradipta @ Summit Studios\n\nMusic Video:\nProduced by Kolmar Films\nStarring by: Nabila Taqiyyah\nProducer: Valencia Margarita\nLine Producer: Ilhamgaff\nDirector & Cam: Idho Aruan\nLighting: Risky Erge\nArt: Risky Gedhe, Ayik\nWardrobe: Fiqih Ma’alhunah\nMUA: Natalia Desiandra\nPost: grtscpe studio\nPU: Elok\nLocation: Kukuh \nBTS: Aji Pemana\n\nFollow Nabila Taqiyyah: \nInstagram: https://www.instagram.com/nabilataqiyyah/\nYouTube: https://www.youtube.com/c/NabilaTaqiyyah \nTikTok: https://www.tiktok.com/@nabilataqiyyah_ \nTwitter: https://twitter.com/Nabilataqiyyah_ \n \nLyrics:\nverse1\nKu berjalan sendirian bagaikan hilang arah tujuan\nLangit mendung, riuh angin hujan pun seakan tak berteman\n\nHilang sudah semua harapan yang di depan \nMampukah aku tetap bertahan\nHanya ingin rasakan sedikit kesenangan\n Walau kunikmati dalam diam\n \nreff:\nKau boleh menangis, tapi kembali berdiri\nKau boleh terluka, tapi hanya sementara\nJangan kau terlalu lama tenggelam\nIngatlah masih ada masa depan\nOmongan mereka hanya lolongan\nYang hilang di telan malam\n\nverse 2:\nWajar bila manusia berpura pura untuk bahagia\nPersis dalam cerita yang di tulis sempurna\nAtaukah kisah yang realita\nBerjuta sandiwara ada di depan mata\nJadilah kau pemeran utama\n\nbridge:\nUdep lam donya le cobaan, bek putoh asa..\nBek tanyoe wueh hate geutanyoe beu kong\n\nOfficial Music Video by Nabila Taqiyyah performing Hanya Lolongan © 2024 Universal Music Indonesia',
#   'categoryId': '10',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/XIdG3zsQPvU/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '1375058',
#   'likeCount': '45556',
#   'commentCount': '20295',
#   'duration': 'PT3M50S'},
#  {'title': 'Unboxing kado wedding ikke razor - PART 1',
#   'publishedAt': '2024-05-03T14:18:22Z',
#   'channelTitle': 'ikke jenner',
#   'description': 'Hai guys, sekarang kami (ikke&razor) akan aktif di akun youtube ini, karena akun youtube razor udah lama gak bisa di loginin, di urus belom bisa balik lagi akun nya 🥰',
#   'categoryId': '19',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QQL5qRmTAiw/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/QQL5qRmTAiw/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/QQL5qRmTAiw/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/QQL5qRmTAiw/sddefault.jpg',
#     'width': 640,
#     'height': 480}},
#   'viewCount': '139781',
#   'likeCount': '10869',
#   'commentCount': '628',
#   'duration': 'PT21M13S'},
#  {'title': 'Indonesia Kalah Dari Iraq, Guinea Menunggu Di Paris | R66 Sports',
#   'publishedAt': '2024-05-03T09:00:11Z',
#   'channelTitle': 'R66 Sports',
#   'description': "Hola Sportizen!!! Timnas Indonesia hanya mampu meraih posisi 4 di Piala Asia U23, dengan hasil ini Indonesia harus melalui babak playoff di Paris melawan Guinea. Namun, pencapaian ini sendiri sejatinya sudah melebihi ekspektasi PSSI yang menargetkan lolos 4 Besar Piala Asia U23 5 tahun mendatang. Bagi Koci dan Bung Helmy hasil ini sudah membanggakan!!!!\n\nSelain pembahasan mengenai timnas Indonesia di Piala Asia, ada pertandingan yang menurut Coach Justin membosankan karena Leg pertama UCL selalu begitu, pada episode ini Koci & Bung HY juga membagikan alasan Barcelona dan Xavi melanjutkan kerjasama, sedangkan MU ingin bebersih skuad. Simak video selengkapnya!!!!\n\n---------------------------------------------------------------------------------------------------------------------\n\nWelcome to R66 Sports YouTube Channel! Don't forget to Like, Subscribe and Share our channel to keep you update!\n\nPlease follow our Social Media :\n\nInstagram : https://www.instagram.com/r66sports\nTwitter  :  https://twitter.com/r66sports\nWebsite : https://www.linkedin.com/company/r66-media/\n                  https://r66media.com/\n\nAkun ini dikelola oleh PT. Rute Enam Puluh Enam Indonesia (R66 Media),\nUntuk info kerja sama dapat menghubungi :\n\nEmail : Partnership@R66media.com\nHP :  +62 881-0116-33866\n\n#timnasindonesia #shintaeyong #pialaasia",
#   'categoryId': '17',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8e55e07--bQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/8e55e07--bQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/8e55e07--bQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/8e55e07--bQ/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/8e55e07--bQ/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '318384',
#   'likeCount': '5583',
#   'commentCount': '1045',
#   'duration': 'PT40M36S'},
#  {'title': 'DRIVE THRU MI INSTAN INDOMARET SAMBIL CURHAT SESAMA BUSUI - Ft @DuoPengacara',
#   'publishedAt': '2024-05-03T09:00:26Z',
#   'channelTitle': 'Shely Che',
#   'description': 'Jangan lupa SUBSCRIBE, COMMENT, dan LIKE!\n\nSUBSCRIBE Shely Che :\nhttps://www.youtube.com/channel/UCR_Zu8zKby-Ugy3Ee6Q7Bjw\nSUBSCRIBE Shely & Gian :\nhttps://www.youtube.com/channel/UCKuzyt4EXZ6tmi7TMBFvqxg\n\nFOR BUSINESS : \nEmail : shelyche.id@gmail.com\nor click link : https://linktr.ee/CheManagement\n\n#drivethru #indomaret #duopengacara',
#   'categoryId': '22',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XeoQMl6SgyQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/XeoQMl6SgyQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/XeoQMl6SgyQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/XeoQMl6SgyQ/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/XeoQMl6SgyQ/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '149659',
#   'likeCount': '6732',
#   'commentCount': '119',
#   'duration': 'PT32M58S'},
#  {'title': 'Vior Jadi Saksi Selingkuh',
#   'publishedAt': '2024-05-01T03:00:34Z',
#   'channelTitle': 'Raditya Dika',
#   'description': 'Baru! Stand Up Comedy Raditya Dika selama tur Cerita Sebelku, beli di sini: https://radityadika.com/video/ceritasebelku2024\n\nBeli Merchandise Official Raditya Dika di:\nShopee : https://shopee.co.id/officialekresa\nTokopedia : https://www.tokopedia.com/ekresa-official\n\nBeli video kompilasi tur Stand Up Comedy Raditya Dika (2022) di: https://radityadika.com/video/ceritacintaku2022\n\nBeli video kompilasi tur Stand Up Comedy Raditya Dika (2020) di: https://radityadika.com/video/ceritacintaku2020\n\nBeli video Kelas Menulis Cerita oleh Raditya Dika di:\nhttp://www.kelasnulis.com\n\nFor business enquiry, contact: management@radityadika.com',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qKV-VkYYy8c/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/qKV-VkYYy8c/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/qKV-VkYYy8c/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/qKV-VkYYy8c/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/qKV-VkYYy8c/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '3054239',
#   'likeCount': '127806',
#   'commentCount': '11386',
#   'duration': 'PT41M22S'},
#  {'title': 'Rizky Febian Feat. Mahalini - Bermuara [Official Lyric Video]',
#   'publishedAt': '2024-05-03T07:00:07Z',
#   'channelTitle': 'Rizky Febian',
#   'description': '#RizkyFebian #Mahalini #beRMuara\n\nBermuara mengisahkan tentang sepasang kekasih yang pernah mengarungi sungai yang keruh dan deras, namun pada akhirnya arus membawa mereka ke tujuan yang sama.\n\nRizky Febian dan Mahalini Raharja mengungkapkan harapannya agar lagu ini dapat menjadi penghibur dan penyemangat bagi pendengar di seluruh Indonesia. Mereka berdua sangat antusias untuk berbagi karya ini dengan para penggemar musik mereka, dan berharap agar "BERMUARA" dapat menginspirasi dan memberikan kesan mendalam bagi setiap pendengar. \n\nTujuan serta mimpi yang mereka dambakan di masa depan telah mereka rangkai, melupakan segala masa kelam menyedihkan yang pernah terjadi untuk bermuara di keabadian. \n\nLirik:\nBagai derai hujan \nHapus semua jejak \nSeluruh hal kelam yang menyedihkan \n\nKau ganti senyuman \nLukis kan khayalan \nSusun cerita masa depan \nBisik kan rayuan \nMerayu raya bahagia \n\nSayang ... \nPerjalanan kita kan berlayar \nBerlabuh di tujuan yang sama \nBermuara di keabadian \n\nBagai derai hujan \nHapus semua jejak \nSeluruh hal kelam yang menyedihkan \n\nKau ganti senyuman \nLukis kan khayalan \nSusun cerita masa depan \nBisik kan rayuan \nMerayu raya bahagia\n\nSayang ...\nPerjalanan kita kan berlayar \nBerlabuh di tujuan yang sama \nBermuara di keabadian \n\nSayang ... (sayang) \nPerjalanan kita kan berlayar (berlayar) \nBerlabuh di tujuan yang sama \nTenang ...\nPeluk tempatku pulang \n\n......\n\nSayang ...\nPerjalanan kita kan berlayar \nBerlabuh di tujuan yang sama \nBermuara di keabadian \n\nSayang ... (sayang) \nPerjalanan kita kan berlayar (kita kan berlayar) \nBerlabuh di tujuan yang sama (bermuara di keabadian) \nPeluk tempatku ... pulang\n\nSong Credit :\nExecutive Producer by Rahul Tamara Putra for RFAS Music & Lina Priscilla for HITS Records\nA&R RFAS Music by Beraldy Dean & Racka Fandiana\nA&R HITS Records by Sevri Hadis\nArtist by Rizky Febian & Mahalini Raharja\nComposed by Rizky Febian & Mahalini Raharja\nMusic Produced and Arranged by Beraldy Dean\nAll Keys by Klency Lembono\nAll Guitars by Beraldy Dean\nBass by Ryan Innocentio Tifaona\nStrings Composed by Beraldy Dean & Nicolas Antonius\nVocal Produced by Barsena Bestandhi\nVocal Recorded at Bro’s Studio by Sinyo Drumboy\nInstrument Recorded at Ebony Ivory Studio by Sinyo Drumboy & Jeremy Aditya\nVocal Edited by Jeremy Aditya & Andrew Setiawan\nInstruments Edited by Jeremy Aditya\nMixed & Mastered by Sinyo Drumboy at Ebony Ivory Studio\n\nLyric Video by RFAS Music\n\nFollow Rizky Febian on social media:\nInstagram : https://www.instagram.com/rizkyfbian \nTwitter : https://twitter.com/rizky_febian\nTikTok : https://www.tiktok.com/@rizkyfebian77\nAll digital store: Rizky Febian\n\nFollow Mahalini on social media:\nInstagram : https://www.instagram.com/mahaliniraharja/\nTwitter : https://twitter.com/Mahalinidisini\nTikTok : https://www.tiktok.com/@mahaliniiraharja',
#   'categoryId': '10',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GAf2DQPYvGE/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/GAf2DQPYvGE/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/GAf2DQPYvGE/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/GAf2DQPYvGE/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/GAf2DQPYvGE/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '226053',
#   'likeCount': '12629',
#   'commentCount': '1170',
#   'duration': 'PT5M7S'},
#  {'title': 'GURU GEMBUL AJA NYERAH NGAJARIN KUKUH! | MINTA DIGAMPAR EPS 60',
#   'publishedAt': '2024-05-04T04:00:05Z',
#   'channelTitle': 'KOMTUNG',
#   'description': '----\nKOMTUNGTV : Where The Founder is very rich and found HAPPINESS!\n\nSosial Media :\nhttps://www.instagram.com/komtungtv/\nhttps://twitter.com/komtungTV\n\nJangan lupa Like, Comment and Subscribe.',
#   'categoryId': '24',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CbXKJLAV97k/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/CbXKJLAV97k/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/CbXKJLAV97k/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/CbXKJLAV97k/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/CbXKJLAV97k/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '128704',
#   'likeCount': '3776',
#   'commentCount': '1033',
#   'duration': 'PT38M7S'},
#  {'title': 'VVL part 2 ☺️',
#   'publishedAt': '2024-05-03T13:00:25Z',
#   'channelTitle': 'AnangWaw',
#   'description': 'Bergabung dengan channel ini untuk mendapatkan akses ke berbagai keuntungan:\nhttps://www.youtube.com/channel/UCsYJTxxhUAa1mSXg31F1otQ/join\n\nFor Business Inquiries : anangwawid@gmail.com\n\nSOCIAL MEDIA\nInstagram : https://www.instagram.com/anangwaw/\nTiktok        : https://www.tiktok.com/@anangwaw?lang=id',
#   'categoryId': '24',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QUZ3DluNoHA/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/QUZ3DluNoHA/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/QUZ3DluNoHA/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/QUZ3DluNoHA/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/QUZ3DluNoHA/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '119515',
#   'likeCount': '8006',
#   'commentCount': '1139',
#   'duration': 'PT21M23S'},
#  {'title': 'POWERKUBE CHALLENGE WITH KKAJHE JEKSON KARMELA!',
#   'publishedAt': '2024-05-03T11:30:31Z',
#   'channelTitle': 'celloszxz',
#   'description': 'WADDUP BROBRIES WELCOME BACK TO ANOTHER VIDEO!\n\nDI VIDEO KALI INI GUE AKAN COBA TES KEKUATAN TENDANGAN KKAJHE JEKSON KARMELA DENGAN POWERKUBE!, SEBERAPA KUAT SIH DIA!? APA LEBIH KENCENG DARI RANDY PANGALILA?!? LANGSUNG TONGTON VIDEONYAAA!\n\nJANGAN LUPA BELI ZXZ PLANET ! DI LINK DI BAWAH INI!\nhttps://www.tokopedia.com/zxzplanet\nhttps://shopee.co.id/zxzplanet\n\nSTAY SANE!!\nSTAY HEALTHY!!\n\nOKE GUYS JANGAN LUPA LAYK, KOMENG, SABKES!!!\n\nANOTHER SOCIALS:\nINSTAGRAM : @celloszxz \nTIKTOK : @celloszxz',
#   'categoryId': '23',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/feOzcAETcsA/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/feOzcAETcsA/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/feOzcAETcsA/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/feOzcAETcsA/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/feOzcAETcsA/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '197981',
#   'likeCount': '4799',
#   'commentCount': '435',
#   'duration': 'PT15M7S'},
#  {'title': 'COKI PARDEDE & RUKUN KOMIKA',
#   'publishedAt': '2024-05-03T05:48:33Z',
#   'channelTitle': 'Pandji Pragiwaksono',
#   'description': 'Gue membuka youtube membership kepada yang merasa SATU PAHAM, SATU RASA dan SATU JIWA dengan gue:\nhttps://www.youtube.com/channel/UCh1SzxJAH9B5nZDYYa42UqQ/join',
#   'categoryId': '23',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fex9mWWgyBQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/fex9mWWgyBQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/fex9mWWgyBQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/fex9mWWgyBQ/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/fex9mWWgyBQ/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '216739',
#   'likeCount': '5050',
#   'commentCount': '358',
#   'duration': 'PT57M51S'},
#  {'title': 'BELI SUSHI RATING TERBURUK DI GRAB FOOD!',
#   'publishedAt': '2024-05-03T12:00:31Z',
#   'channelTitle': 'Pebbi Lieyanti',
#   'description': '𝙂𝙚𝙩 𝙩𝙤 𝙠𝙣𝙤𝙬 𝙢𝙚 𝙤𝙣 𝙄𝙣𝙨𝙩𝙖𝙜𝙧𝙖𝙢: @𝙥𝙚𝙗𝙗𝙞.𝙡𝙞𝙚𝙮𝙖𝙣𝙩𝙞 \nhttps://instagram.com/pebbi.lieyanti?igshid=1xdwso1e69n62\n\n𝙁𝙤𝙧 𝙘𝙤𝙡𝙡𝙖𝙗𝙤𝙧𝙖𝙩𝙞𝙤𝙣/𝙚𝙣𝙙𝙤𝙧𝙨𝙚𝙢𝙚𝙣𝙩 𝙥𝙡𝙚𝙖𝙨𝙚 Whatsapp to: 0812-2888-1320',
#   'categoryId': '22',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PKvLE2Zb3zM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/PKvLE2Zb3zM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/PKvLE2Zb3zM/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/PKvLE2Zb3zM/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/PKvLE2Zb3zM/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '214925',
#   'likeCount': '9782',
#   'commentCount': '197',
#   'duration': 'PT16M12S'},
#  {'title': 'SEMPAT BIKIN TRAUMA! ANDRI TUKANG CAT ASAL TEGAL KEMBALI LAGI! KERJA DI RUMAH PESUGIHAN #OMMAMAT',
#   'publishedAt': '2024-05-02T12:45:01Z',
#   'channelTitle': 'RJL 5 - Fajar Aditya',
#   'description': 'YANG MAU KIRIM2 CERITA  --  https://linktr.ee/rjl5.ceritamu\n================================================\nJangan lupa follow Instagram kita:\n- https://instagram.com/donfajaraditya\n- https://www.instagram.com/rjl5.official/ \n- https://www.tiktok.com/@donfajaraditya\n================================================\nTUKANG BANGUNAN LEGEND ASAL TEGAL INI MENGECAT RUMAH PELAKU PESUGIHAN??\n\nAndri seorang tukang bangunan asal Tegal, dirinya sempat mendapat job untuk kembali mengecat sebuah rumah.\n\nSaat itu Andri bekerja seorang diri dan ketika ia hendak mensurvei rumah tempat dirinya kerja, anehnya si pemilik rumah tidak memperbolehkan Andri untuk mendokumentasikan rumahnya.\n\nSelama 4 hari bekerja di rumah tersebutlah, banyak kejanggalan dan keanehan yang Andri alami. Mulai dari Andri yang sempat menemukan sebuah baskom yang airnya berisi tulang Yuyu.\n\nHingga dari waktu ke waktu kejadian makin menjadi-jadi, yang mana Andri sempat ditampakan oleh sosok penampakan seorang wanita dan anak kecil dengan pampers, namun raut mukanya tua.\n\nSetelah mengalami teror-teror tersebut, Andri baru mengetahui jika ternyata rumah tempat ia bekerja itu merupakan rumah pesugihan..\n\nPenasaran bagaimana kisahnya?\n#tegal #tukang \n===================================================\nSpecial Thanks to : Andri\n====================================================\nCopyright 2024, RJL 5',
#   'categoryId': '24',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NPsojwpx-kg/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/NPsojwpx-kg/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/NPsojwpx-kg/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/NPsojwpx-kg/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/NPsojwpx-kg/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '1037814',
#   'likeCount': '27450',
#   'commentCount': '3528',
#   'duration': 'PT52M45S'},
#  {'title': 'DRAKE - FAMILY MATTERS',
#   'publishedAt': '2024-05-04T03:06:01Z',
#   'channelTitle': 'Drake',
#   'description': '',
#   'categoryId': '10',
#   'defaultAudioLanguage': 'en',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZkXG3ZrXlbc/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/ZkXG3ZrXlbc/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/ZkXG3ZrXlbc/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/ZkXG3ZrXlbc/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/ZkXG3ZrXlbc/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '13134261',
#   'likeCount': '641084',
#   'commentCount': '116517',
#   'duration': 'PT7M38S'},
#  {'title': 'meet the grahams',
#   'publishedAt': '2024-05-04T03:58:26Z',
#   'channelTitle': 'Kendrick Lamar',
#   'description': '',
#   'categoryId': '22',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2QiFl9Dc7D0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/2QiFl9Dc7D0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/2QiFl9Dc7D0/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/2QiFl9Dc7D0/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/2QiFl9Dc7D0/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '15221732',
#   'likeCount': '1095929',
#   'commentCount': '142835',
#   'duration': 'PT6M32S'},
#  {'title': 'HIGHLIGHTS! HAALAND HITS FOUR AS CITY POWER PAST WOLVES | Man City 5 - 1 Wolves | Premier League',
#   'publishedAt': '2024-05-04T21:00:17Z',
#   'channelTitle': 'Man City',
#   'description': "A fantastic four-goal display from Erling Haaland helped earn City a 5-1 win over Wolves at the Etihad Stadium and move us within one point of the Premier League summit.\n\nThe Norwegian was at his unstoppable best as he converted two penalties and an incredible header to seal a ninth City hat-trick before the half-time whistle was blown.\n\nHe then added the fourth eight minutes into the second period to restore City’s three-goal advantage just moments after Wolves forward Hwang Hee-chan had scored.\n\nLate substitute Julian Alvarez added further gloss to the scoreline with a fifth in the closing stages.\n\nSUBSCRIBE! http://www.youtube.com/subscription_center?add_user=mancity\n\nhttp://www.mancity.com\nhttp://www.facebook.com/mancity\nhttp://www.twitter.com/mancity\nhttp://www.instagram.com/mancity\nhttps://www.tiktok.com/@mancity\n\nAbout the Official Man City YouTube Channel:\n\nHere you will find all the latest videos from Manchester City, including, all Premier League, Champions League, FA Cup and League Cup goals, highlights, behind-the-scenes footage, training and much more.\n\nGet closer to the likes of Jack Grealish, Bunny Shaw, Kevin De Bruyne, Lauren Hemp, Erling Haaland, Ellie Roebuck, Phil Foden, Esme Morgan and the rest of Pep Guardiola & Gareth Taylor's teams!",
#   'categoryId': '17',
#   'defaultAudioLanguage': 'en-GB',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MPoEjF8RsRE/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/MPoEjF8RsRE/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/MPoEjF8RsRE/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/MPoEjF8RsRE/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/MPoEjF8RsRE/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '1291136',
#   'likeCount': '30098',
#   'commentCount': '996',
#   'duration': 'PT2M15S'},
#  {'title': 'Kakak Beradik Ini Korban Cinta',
#   'publishedAt': '2024-05-03T11:22:06Z',
#   'channelTitle': 'Raditya Dika',
#   'description': 'Baru! Stand Up Comedy Raditya Dika selama tur Cerita Sebelku, beli di sini: https://radityadika.com/video/ceritasebelku2024\n\nBeli Merchandise Official Raditya Dika di:\nShopee : https://shopee.co.id/officialekresa\nTokopedia : https://www.tokopedia.com/ekresa-official\n\nBeli video kompilasi tur Stand Up Comedy Raditya Dika (2022) di: https://radityadika.com/video/ceritacintaku2022\n\nBeli video kompilasi tur Stand Up Comedy Raditya Dika (2020) di: https://radityadika.com/video/ceritacintaku2020\n\nBeli video Kelas Menulis Cerita oleh Raditya Dika di:\nhttp://www.kelasnulis.com\n\nFor business enquiry, contact: management@radityadika.com',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/m2mCjEC8O00/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/m2mCjEC8O00/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/m2mCjEC8O00/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/m2mCjEC8O00/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/m2mCjEC8O00/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '548998',
#   'likeCount': '19604',
#   'commentCount': '1046',
#   'duration': 'PT45M11S'},
#  {'title': 'MATCH HIGHLIGHTS: Jepang 1 -  0 Uzbekistan | Final - AFC U23 Asian Cup 2024',
#   'publishedAt': '2024-05-03T18:50:37Z',
#   'channelTitle': 'Vision Plus',
#   'description': 'Streaming pertandingan terlengkap Piala Asia U23 2024 secara lebih dekat melalui layar gadgetmu di Vision+\n\nDownload Vision+: visionplus.link/download\n\n#AFCU23AsianCup #PialaAsiaU232024 #PialaAsiaU232024diVisionPlus #VisionPlusSports',
#   'categoryId': '17',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NG-OaPtcO-8/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/NG-OaPtcO-8/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/NG-OaPtcO-8/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/NG-OaPtcO-8/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/NG-OaPtcO-8/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '779957',
#   'likeCount': '3990',
#   'commentCount': '1729',
#   'duration': 'PT3M10S'},
#  {'title': 'GUNUNG HARUN - Atap Negeri Kalimantan Utara #1',
#   'publishedAt': '2024-05-02T12:30:39Z',
#   'channelTitle': 'Fiersa Besari',
#   'description': 'Ke Gunung Melewati Perbatasan Malaysia\nAtap Negeri episode 30 / part 1\n\nTemukan Fiersa Besari di\nInstagram https://www.instagram.com/fiersabesari\nTwitter https://www.twitter.com/fiersabesari\nFacebook https://www.facebook.com/fiersabesari\nTiktok https://www.tiktok.com/@fiersabesari\n\n#atapnegeri',
#   'categoryId': '19',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/w94TAi7sdWI/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/w94TAi7sdWI/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/w94TAi7sdWI/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/w94TAi7sdWI/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/w94TAi7sdWI/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '314192',
#   'likeCount': '16230',
#   'commentCount': '1150',
#   'duration': 'PT21M51S'},
#  {'title': 'KELUARGA BARU KU PART 4 - Animasi Sekolah',
#   'publishedAt': '2024-05-02T11:05:25Z',
#   'channelTitle': 'Dhot Design',
# ...
#   'categoryId': '27',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eiZ1qF5wn1o/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/eiZ1qF5wn1o/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/eiZ1qF5wn1o/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/eiZ1qF5wn1o/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/eiZ1qF5wn1o/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '196965',
#   'likeCount': '11111',
#   'commentCount': '1343',
#   'duration': 'PT20M4S'},
#  {'title': 'ADEL TERSESAT Part 6 ( TAMAT ) - DRAMA ANIMASI',
#   'publishedAt': '2024-05-01T10:00:21Z',
#   'channelTitle': 'Sie EM',
#   'description': '#sie_em\n\n__________________________________________________\n\n\nThanks for watching\n\n\nSUBSCRIBE :\xa0\n\n\nhttps://youtube.com/@Sie_EM\n\n\nAkun sosial media kami :\n\n\nFacebook FANSPAGE :\n\n\nhttps://www.facebook.com/profile.php?id=100092250417361&mibextid=ZbWKwL\n\n\nInstagram :\xa0\n\n\nhttps://instagram.com/sieem81?igshid=MzRlODBiNWFlZA==\n\n\nTiktok :\n\n\nhttps://www.tiktok.com/@sie_emm?_t=8dmGSC0gMd7&_r=1\n\n__________________________________________________\n\n__________________________________________________\n\n\nTittle:\n\nADEL TERSESAT Part 6 ( TAMAT ) - DRAMA ANIMASI\n\n__________________________________________________\n\n__________________________________________________\n\nDrama animasi, film animasi si em, animasi si em, animasi si m, animasi, cerita animasi, animasi kocak, animasi lucu, kartun kocak, kartun lucu, animasi seru, cerita kartun, drama kartun, film kartun, film kartun viral, animasi viral, animasi trending, animasi menceritakan kehipan sehari hari, animasi keren, si em, si m, drama animasi sie em, pegaton, jojo, mex,genk kobra, sije, katai merah.\n\n_________________________________________________\n\n\nSIE EM',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SxoXbJggy3g/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/SxoXbJggy3g/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/SxoXbJggy3g/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/SxoXbJggy3g/sddefault.jpg',
#     'width': 640,
#     'height': 480}},
#   'viewCount': '544455',
#   'likeCount': '30620',
#   'commentCount': '1443',
#   'duration': 'PT5M13S'},
#  {'title': '6 hari berburu cat rakit habiskan Rp155,000,000 buat ikan ini & kameramen jadi bang kiko!! #KOOKIKO',
#   'publishedAt': '2024-04-29T11:15:12Z',
#   'channelTitle': 'Bang Tiko {KOO KIKO}',
#   'description': 'Up setiap hari disini:\nInstagram:_kookiko\nTikTok:kookiko2/story kookiko/kookikoo4\nSnackvideo:KOO KIKO {UM}\nLikee:KOO KIKO UM\nYouTube:Bang Tiko {KOO KIKO}\nBaru login Facebook:_kookiko2\n\nSelain dari akun diatas berarti akun fake/pencuri video!!\n\nTerimakasih',
#   'categoryId': '22',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/09QO89nbOWY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/09QO89nbOWY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/09QO89nbOWY/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/09QO89nbOWY/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/09QO89nbOWY/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '755493',
#   'likeCount': '17847',
#   'commentCount': '2181',
#   'duration': 'PT26M53S'},
#  {'title': 'JALANAN PALING MENAKUTKAN DI BANDUNG #ghostcartour',
#   'publishedAt': '2024-04-30T14:00:25Z',
#   'channelTitle': 'Jurnal Risa',
#   'description': 'Geng gabung Youtube Membernya disini ya !!\nhttps://www.youtube.com/channel/UCKFC1LYWw1fbe9LNfm2vEPg/join\n\nAmbil yang baik-baiknya \nBuang yang buruk-buruknya\n\nDengerin Podcasttery Jurnalrisa di Spotify \nhttps://open.spotify.com/show/6rDe63cP5fc0n8Jjv7ThTu\n\nFacebook Fans Page \n______________________________________________________\nhttps://www.facebook.com/timjurnalrisa\n______________________________________________________\n\nFollow Instagram for updates!\n______________________________________________________ \nJurnalrisa : https://www.instagram.com/tim_jurnalrisa/\nRisa Saraswati : https://www.instagram.com/risa_saraswati/\nDimasta : https://www.instagram.com/dimasta_/\nRiri : https://www.instagram.com/rianarizki/\nA Angga : https://www.instagram.com/ranggana.purwana/\nIndy : https://www.instagram.com/indyratnap/\nKakang : https://www.instagram.com/abimanyu_______/\nNicko : https://www.instagram.com/nickoirham__/\nKang Jeffry  : https://www.instagram.com/kangjeffman/\nRai : https://www.instagram.com/raisekar/\nFahrul : https://www.instagram.com/fahrulrochman_/\n\n______________________________________________________\n\nFollow Twitter\n______________________________________________________ \nhttps://twitter.com/risa_saraswati?la\n\n______________________________________________________\n\nMusic by :\n______________________________________________________\nhttps://www.instagram.com/kevinrinaldi_/',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/J_8J85haoIA/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/J_8J85haoIA/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/J_8J85haoIA/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/J_8J85haoIA/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/J_8J85haoIA/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '767691',
#   'likeCount': '36644',
#   'commentCount': '1843',
#   'duration': 'PT42M22S'},
#  {'title': 'BAWA ANAK PULANG DARI JEPANG KE INDONESIA ! GK NGAJAK MAMA NYA ! DIA SEDIH !',
#   'publishedAt': '2024-04-30T07:39:36Z',
#   'channelTitle': 'Neo Japan',
#   'description': '.................\nSEDEKAH BERAS nya om/tante!\nhttps://trakteer.id/neojapan\n..........................................\nchannel PODCAST NEOJAPAN SOON ! https://www.youtube.com/channel/UCN4WWwEz1QMDg1Ua1tz7MEg\n\ninstagram NEOJAPAN_;  https://www.instagram.com/neojapan_/?hl=en\ninstagram Yusufkun ; https://www.instagram.com/yuu.kun21/?hl=en',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'en',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HRF41TLRRhE/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/HRF41TLRRhE/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/HRF41TLRRhE/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/HRF41TLRRhE/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/HRF41TLRRhE/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '340331',
#   'likeCount': '11401',
#   'commentCount': '537',
#   'duration': 'PT17M12S'},
#  {'title': '100 Hari Minecraft Jungle Apocalypse Hardcore',
#   'publishedAt': '2024-04-28T05:43:06Z',
#   'channelTitle': 'PaYuDan',
#   'description': 'Aku dan Kapten @Nyashel  Harus menyelamatkan Sahabatku yang tersesat di Hutan yang penuh Zombie Apocalypse selama 100 Hari.\n\nKASIH AKU KEKUATAN 15.000 LIKE++ Dan AKU AKAN LANJUTKAN EPISODENYA❗️❗️\n\n🔴Subscribe Channel PaYuDan :\nhttps://www.youtube.com/payudan\n\n🔴Join Memberships Channel PaYuDan! dan aku jadikan kalian Jenderal Terbaik di Channel ini.\n\n🔴Playlist 100 Hari Ocean Only :\nhttps://youtube.com/playlist?list=PLidLJnGRJz0RF4IApP9aLFS6cvYyyyELX\n\n🔴Playlist 100 Hari PaYuDan :\nhttps://youtube.com/playlist?list=PLidLJnGRJz0QDUSsOvFi_uibwnMSz_Xbj\n\n🔴Jangan lupa juga untuk ikutin Sosial Media Aku yaa :\nInstragram ► https://www.instagram.com/mzahirpayudan\n\n🔴Join Discord PaYuDan SKWAD :\nhttps://discord.gg/pJtnHBE58d\n\n🔴Untuk Email Bisnis kalian bisa masukan di\nEmail ► zpayudan@gmail.com\n\n#apocalypse #minecraft #100hariminecraft',
#   'categoryId': '20',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/29twGV9khBY/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '353194',
#   'likeCount': '8794',
#   'commentCount': '635',
#   'duration': 'PT22M7S'},
#  {'title': 'ALHAMDULILAH OPERASI SELESAI DAN LANCAR ( JADI NGELANTUR KARENA BERJAM2 DI RUANG OPERASI) SEMANGAT',
#   'publishedAt': '2024-04-28T22:15:00Z',
#   'channelTitle': 'Yanti Guixe family',
#   'description': 'klinic yang aku percaya \n\nInstagram beautique korea:\nhttps://www.instagram.com/beautiquekorea?igshid=YmMyMTA2M2Y%3D\n\nInstagram view:\nhttps://www.instagram.com/view_plastic_surgery?igshid=YmMyMTA2M2Y%3D\nhttps://www.instagram.com/viewplasticsurgery_indo?igshid=YmMyMTA2M2Y%3D\n\nhappy banget dengan hasilnya 🥰🥰',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Hi3_T300wWU/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Hi3_T300wWU/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Hi3_T300wWU/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/Hi3_T300wWU/sddefault.jpg',
#     'width': 640,
#     'height': 480}},
#   'viewCount': '370481',
#   'likeCount': '14570',
#   'commentCount': '1977',
#   'duration': 'PT23M21S'},
#  {'title': 'JURNALRISA X BADARAWUHI #Jurnalrisa',
#   'publishedAt': '2024-04-25T14:00:43Z',
#   'channelTitle': 'Jurnal Risa',
#   'description': 'Geng gabung Youtube Membernya disini ya !!\nhttps://www.youtube.com/channel/UCKFC1LYWw1fbe9LNfm2vEPg/join\n\nJurnalrisa x Badarawuhi\n\nAmbil yang baik-baiknya \nBuang yang buruk-buruknya\n\nDengerin Podcasttery Jurnalrisa di Spotify \nhttps://open.spotify.com/show/6rDe63cP5fc0n8Jjv7ThTu\n\nFacebook Fans Page \n______________________________________________________\nhttps://www.facebook.com/timjurnalrisa\n______________________________________________________\n\nFollow Instagram for updates!\n______________________________________________________ \nJurnalrisa : https://www.instagram.com/tim_jurnalrisa/\nRisa Saraswati : https://www.instagram.com/risa_saraswati/\nDimasta : https://www.instagram.com/dimasta_/\nRiri : https://www.instagram.com/rianarizki/\nA Angga : https://www.instagram.com/ranggana.purwana/\nIndy : https://www.instagram.com/indyratnap/\nKakang : https://www.instagram.com/abimanyu_______/\nNicko : https://www.instagram.com/nickoirham__/\nKang Jeffry  : https://www.instagram.com/kangjeffman/\nRai : https://www.instagram.com/raisekar/\nFahrul : https://www.instagram.com/fahrulrochman_/\n\n______________________________________________________\n\nFollow Twitter\n______________________________________________________ \nhttps://twitter.com/risa_saraswati?la\n\n______________________________________________________\n\nMusic by :\n______________________________________________________\nhttps://www.instagram.com/kevinrinaldi_/',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/nOJCGHAHwG0/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '2046372',
#   'likeCount': '97985',
#   'commentCount': '3170',
#   'duration': 'PT48M31S'},
#  {'title': '10 Minutes To Escape Or This Room Explodes!',
#   'publishedAt': '2024-04-27T16:00:00Z',
#   'channelTitle': 'MrBeast',
#   'description': 'I didn’t expect that to happen…\nThere’s no jumping through hoops (or plate glass windows) with T-Mobile. Customers can get Magenta Status from day one, including hotel discounts on select brands, deals on rental cars, discounts on select concert tickets nationwide, and so much more. See how at https://t-mobile.com/status\n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------',
#   'categoryId': '24',
#   'defaultAudioLanguage': 'en',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/Pv0iVoSZzN8/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '73883004',
#   'likeCount': '3284509',
#   'commentCount': '79415',
#   'duration': 'PT10M'}]

# %% [markdown]
# #### Define Additional Details to Extract (`trendingAt` & `videoId`)

# %% [markdown]
# Since we'll continually update the data then, let's note the time when the video becomes trending and fetch it (`trendingAt`), and also record its video ID (`videoId`) to facilitate storage in the database later.

# %%
# retrieves the current time in UTC format 
time_now = datetime.now(timezone.utc).strftime('%Y-%m-%dT%H:%M:%SZ')
time_now
# Out:
# '2024-05-06T00:50:43Z'

# %%
# way to get videoId
videos[0].get("id")
# Out:
# '4ofJpOEXrZs'

# %% [markdown]
# On the code before, we only make `video_details = {}`
#
# But because we want to add `videoId` and `trendingAt` to `video_details`, we can directly put it in the initialization like this:
#
# `video_details = {'videoId': video.get("id"), 'trendingAt': time_now}`

# %%
videos_list = []

for video in videos:
    # initialize a dictionary to store video details
    video_details = {'videoId': video.get("id"), 'trendingAt': time_now}
    
    for key, value in complete_infos.items():
        for info in value:
            video_details[info] = video.get(key, {}).get(info)
    
    videos_list.append(video_details)

# %% [markdown]
# Finally, we have completed the process. We've transformed raw video data into a structured format ready for analysis.

# %% [markdown]
# Overall, while the basic method may suffice for simple tasks, the advanced method provides a more robust and scalable solution capable of meeting complex requirements and promoting better development practices.

# %% [markdown]
# ## 5. Write Fetched Videos Data to a JSON file

# %% [markdown]
# Writing fetched videos data to a JSON file is crucial as it serves as an interim step in the development process before transitioning to storing the data in a database. This enables efficient data management and facilitates the seamless integration of the extracted information into the database for future development.

# %% [markdown]
# We can store the fetched data using `json.dump()`, which takes two parameters: the data to be stored and the file object where the data will be written.

# %% [markdown]
# - `target_file_path` is the path where the JSON file will be created or overwritten.
# - `videos_list` is a list containing dictionaries, with each dictionary representing details of a video.

# %%
file_path = 'dags/tmp_file.json'

# %% [markdown]
# **Note**: Later, use `"/opt/airflow/dags/..."` for docker purpose

# %%
with open(file_path, "w") as f:
    json.dump(videos_list, f)

# %% [markdown]
# `json.dump()` serializes the `videos_list` into a JSON formatted string and writes it to the file.

# %% [markdown]
# > Open the target file in write mode ('w') using a 'with' statement. This ensures that the file is properly closed after writing, even if an exception occurs.

# %%
len(videos_list)
# Out:
# 50

# %% [markdown]
# Using this single request API, we can get maximum 50 trending videos. Congratulations!

# %% [markdown]
# In summary:
# 1. We sent a request to the YouTube API to fetch videos based on specific criteria.
# 2. The API responded with the requested videos.
# 3. We extracted important details like titles, publish dates, and view counts from the response.
# 4. Then, we processed these details to gain insights or present them to users.
# 5. Finally, we stored the data into a JSON file.
#
# Through these steps, we effectively interacted with the YouTube API, retrieved relevant video data, and made use of it for our purposes.

# %% [markdown]
# **Disadvantages of Single Request**
#
# Actually, there are typically 200 pieces of data for trending YouTube videos at any given time, but due to the maximum limit of 50 items per single request, we cannot retrieve all of them in one fetch.
#
# So, what should be done? This highlights the inherent limitation of a single request: limited data and the risk of data loss. Hence, the necessity for pagination.
#
# **Solution :**
# To solve the limitations of single requests, we can implement pagination by:
#
# 1. Sending an initial request to fetch the first batch of videos.
# 2. Checking if there are more pages of results available.
# 3. If more pages are available, sending additional requests for each page until all desired data is retrieved.
# 4. Processing and aggregating the data from each page to obtain a complete dataset for analysis or presentation.
#
# By following this approach, we ensure comprehensive data retrieval while maintaining efficient resource usage and scalability in our application.

# %% [markdown]
# ## Paginate Through Results Using to Get All Trending Videos
#
# Pagination allows us to retrieve additional batches of videos beyond the initial request.  In this case, we utilize multiple requests to fetch data in batches, ensuring comprehensive coverage of trending videos.
#
# It's a very simple and straightforward process, but by using pagination, we can overcome limitations and ensure we get all trending videos.

# %% [markdown]
# ```python
# next_page_token = ""
# while next_page_token is not None:
#     # all code before here
#     # ...
#     next_page_token = response.get("nextPageToken", None)
# ```

# %%
videos_list = []
# initialize the token
next_page_token = ""

while next_page_token is not None:
    request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        chart="mostPopular",
        regionCode=region_code,
        maxResults=50,
        pageToken=next_page_token # add pageToken to inform the API
    )
    response = request.execute()
    videos = response.get("items", [])

    time_now = datetime.now(timezone.utc).strftime('%Y-%m-%dT%H:%M:%SZ')
    for video in videos:
        video_details = {'videoId': video["id"], 'trendingAt': time_now}
        
        for key, value in complete_infos.items():
            for info in value:
                video_details[info] = video.get(key, {}).get(info)
                    
        videos_list.append(video_details)

    # store the next page to fetch (token)
    next_page_token = response.get("nextPageToken", None)

with open(file_path, "w") as f:
    json.dump(videos_list, f)

# %%
len(videos_list)
# Out:
# 200

# %% [markdown]
# Yay! By utilizing pagination, we've finally obtained all the trending videos! It's simple, isn't it?

# %% [markdown]
# #### Conclusion
# By following these steps, we can progressively learn how to fetch videos from YouTube's API, starting from making a single request and advancing to paginating through the results. This approach allows beginners to grasp the fundamentals of API interaction and data retrieval while gradually building their skills.

# %% [markdown]
# # Data Preprocessing Youtube Data

# %% [markdown]
# Preprocess our fetched data is essential for preparing raw data fetched from YouTube for analysis or usage by restructuring it into a more organized format, enriching it with additional information, cleaning inconsistencies, and normalizing its structure.
#
# > We need to enhances the data's readability and usability while ensuring consistency and reliability. It also improves the efficiency of downstream applications or analyses that rely on the processed data.
#
# Let's take a look to our sample raw data!

# %%
# load the fetched videos data and categories dictionary from json files
with open(file_path, 'r') as f:
    videos_list = json.load(f)

# %%
example_video = videos_list[0]
example_video
# Out:
# {'videoId': '4ofJpOEXrZs',
#  'trendingAt': '2024-05-06T00:50:43Z',
#  'title': 'THE AMAZING DIGITAL CIRCUS - Ep 2: Candy Carrier Chaos!',
#  'publishedAt': '2024-05-03T22:00:08Z',
#  'channelTitle': 'GLITCH',
#  'description': 'The gang are BACK for a WAaAaAaACKY candy filled adventure! They also discover that their lives literally have no meaning. Woohoo! So waaccky!!!!! \n\nALSOOO we just dropped the entire main Digital Circus characters as PLUSHIES!!!: https://digitalcircus.store/ Consider getting one to help support the production of more episodes. No pressure though! Have a great day ❤️',
#  'categoryId': '1',
#  'defaultAudioLanguage': 'en',
#  'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/default.jpg',
#    'width': 120,
#    'height': 90},
#   'medium': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/mqdefault.jpg',
#    'width': 320,
#    'height': 180},
#   'high': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/hqdefault.jpg',
#    'width': 480,
#    'height': 360},
#   'standard': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/sddefault.jpg',
#    'width': 640,
#    'height': 480},
#   'maxres': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/maxresdefault.jpg',
#    'width': 1280,
#    'height': 720}},
#  'viewCount': '37702723',
#  'likeCount': '2532340',
#  'commentCount': '234462',
#  'duration': 'PT25M14S'}

# %% [markdown]
# We can do it by converting duration to seconds, mapping category identifiers to their names, parsing thumbnail URLs, and converting string representations of numerical values to integers.

# %% [markdown]
# ## Converting Duration to Seconds

# %% [markdown]
# We need to convert ISO 8601 duration to seconds after fetching YouTube data because ISO 8601 duration represents the duration of a video in a standardized format, including hours, minutes, and seconds.

# %%
example_video.get('duration', '')
# Out:
# 'PT25M14S'

# %% [markdown]
# We can achieve the conversion by using the `isodate.parse_duration()` function. This function parses the duration string into a duration object, from which we can extract the total duration in seconds using the `.total_seconds()` method.

# %%
# convert ISO 8601 duration to seconds
isodate.parse_duration(example_video.get('duration', '')).total_seconds()
# Out:
# 1514.0

# %% [markdown]
# > **Insight:** The example video's duration is 711 seconds.

# %% [markdown]
#  By converting it to seconds, we can easily perform calculations, comparisons, and manipulations on video durations, allowing for more efficient data processing and analysis.

# %% [markdown]
# ## Convert `categoryId` to Category based on Categories Dictionary
#
# YouTube videos data often includes a `categoryId` attribute representing the category of the video.
#
# However, these IDs are not intuitive for users to understand. Therefore, by converting `categoryId` to a more descriptive category based on a predefined dictionary, we can provide users with clearer and more meaningful information about the content of the videos. This enhances user experience and makes the data more accessible and understandable.

# %% [markdown]
# **Note**: Later, use `"/opt/airflow/dags/..."` for docker purpose

# %%
with open('dags/categories.json', 'r') as f:
    categories = json.load(f)

categories
# Out:
# {'1': 'Film & Animation',
#  '2': 'Autos & Vehicles',
#  '10': 'Music',
#  '15': 'Pets & Animals',
#  '17': 'Sports',
#  '18': 'Short Movies',
#  '19': 'Travel & Events',
#  '20': 'Gaming',
#  '21': 'Videoblogging',
#  '22': 'People & Blogs',
#  '23': 'Comedy',
#  '24': 'Entertainment',
#  '25': 'News & Politics',
#  '26': 'Howto & Style',
#  '27': 'Education',
#  '28': 'Science & Technology',
#  '30': 'Movies',
#  '31': 'Anime/Animation',
#  '32': 'Action/Adventure',
#  '33': 'Classics',
#  '34': 'Comedy',
#  '35': 'Documentary',
#  '36': 'Drama',
#  '37': 'Family',
#  '38': 'Foreign',
#  '39': 'Horror',
#  '40': 'Sci-Fi/Fantasy',
#  '41': 'Thriller',
#  '42': 'Shorts',
#  '43': 'Shows',
#  '44': 'Trailers'}

# %%
example_video.get('categoryId', '')
# Out:
# '1'

# %%
complete_infos
# Out:
# {'snippet': ['title',
#   'publishedAt',
#   'channelTitle',
#   'description',
#   'categoryId',
#   'defaultAudioLanguage',
#   'thumbnails'],
#  'statistics': ['viewCount', 'likeCount', 'commentCount'],
#  'contentDetails': ['duration']}

# %% [markdown]
# ## convert categoryId to category based on categories dictionary

# %%
example_video.get('categoryId', '')
# Out:
# '1'

# %% [markdown]
# We can achieve the conversion by utilizing a predefined dictionary named `categories`.
#
# By accessing this dictionary with the `categoryId` retrieved from each video, we can obtain the corresponding category.

# %%
# convert categoryId to category
categories.get(example_video.get('categoryId', ''))
# Out:
# 'Film & Animation'

# %% [markdown]
# This process ensures that each video's category is represented in a more user-friendly and understandable format.

# %% [markdown]
# ## Parse the Thumbnail `url`

# %% [markdown]
# Parsing the thumbnail URL is important to extract a single URL that represents the thumbnail image of the video in a standardized format.

# %% [markdown]
# Before parsing, the thumbnail data is structured into a dictionary with different sizes of thumbnails (default, medium, high, standard, maxres) each containing a URL along with its corresponding width and height.

# %%
example_video['thumbnails']
# Out:
# {'default': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/default.jpg',
#   'width': 120,
#   'height': 90},
#  'medium': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/mqdefault.jpg',
#   'width': 320,
#   'height': 180},
#  'high': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/hqdefault.jpg',
#   'width': 480,
#   'height': 360},
#  'standard': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/sddefault.jpg',
#   'width': 640,
#   'height': 480},
#  'maxres': {'url': 'https://i.ytimg.com/vi/4ofJpOEXrZs/maxresdefault.jpg',
#   'width': 1280,
#   'height': 720}}

# %% [markdown]
# It is enough for us, to retrieve the URL of the standard thumbnail image only.

# %%
# parse the thumbnail url
example_video.get('thumbnails', {}).get('standard', {}).get('url')
# Out:
# 'https://i.ytimg.com/vi/4ofJpOEXrZs/sddefault.jpg'

# %% [markdown]
#  After parsing, we extract the URL of the standard thumbnail ('sddefault') which typically represents a higher quality image suitable for displaying in various contexts.
#
#  This simplified URL format is more convenient for storage, sharing, and usage in applications compared to the original structured thumbnail data.

# %% [markdown]
# ## Convert Statistical Columns to Integer from String

# %% [markdown]
# Converting 'viewCount', 'likeCount', and 'commentCount' from string to integer is essential for proper data handling and analysis. By converting these values to integers, we can perform mathematical operations, comparisons, and statistical analysis accurately.

# %%
example_video['viewCount']
# Out:
# '37702723'

# %% [markdown]
# We accomplish the conversion by utilizing the int() function, which converts the string representation of 'viewCount' (and similarly 'likeCount' and 'commentCount') to an integer format.
#
# This ensures that these values are represented as numerical data, enabling us to perform mathematical operations and analysis accurately.

# %%
int(example_video.get('viewCount', 0))
# Out:
# 37702723

# %% [markdown]
# > **Insight:** Total views from example video is 1,809,813 views

# %% [markdown]
# Additionally, providing a default value of 0 ensures graceful handling in case the 'viewCount' attribute is missing or contains invalid data.
#
# This conversion allows us to effectively analyze the popularity, engagement, and interactions of YouTube videos based on their view counts, like counts, and comment counts.

# %% [markdown]
# ## Preprocess Each Video in the List

# %% [markdown]
# Combining all the preprocessing functions into a single loop allows for efficient processing of each video in the video list. Instead of manually applying each function to every video, looping through the list enables automated application of all necessary preprocessing steps.

# %%
for video in videos_list:
    # convert categoryId to category based on categories dictionary
    video['category'] = categories.get(video.get('categoryId', ''))
    del video['categoryId']

    # convert ISO 8601 duration to seconds
    video['duration'] = isodate.parse_duration(video.get('duration', '')).total_seconds()
    del video['duration']

    # parse the thumbnail url
    video['thumbnailUrl'] = video.get('thumbnails', {}).get('standard', {}).get('url')
    del video['thumbnails']
    
    # convert viewCount, likeCount, and commentCount to integer
    video['viewCount'] = int(video.get('viewCount', 0))
    video['likeCount'] = int(video.get('likeCount', 0))
    video['commentCount'] = int(video.get('commentCount', 0))

# %% [markdown]
# This approach enhances processing speed and scalability, especially when dealing with a large number of videos, such as the 200 videos typically present in trending YouTube data. By streamlining the preprocessing process, it ensures consistency, accuracy, and effectiveness in preparing the data for further analysis or usage.

# %% [markdown]
# ## Store Postprocessed Data into a JSON File

# %% [markdown]
# After preprocessing, the next step is to store the postprocessed data into a JSON format. This allows for easy storage, sharing, and retrieval of the processed data, ensuring that it remains accessible for future analysis or usage.

# %%
processed_file_path = 'dags/tmp_file_processed.json'

# %% [markdown]
# **Note**: Later, use `"/opt/airflow/dags/..."` for docker purpose

# %%
# save the processed videos data to a new file
with open(processed_file_path, "w") as f:
    json.dump(videos_list, f)

# %% [markdown]
# # Make Custom Function for All Processes

# %% [markdown]
# ## Make Fetching Data Function

# %% [markdown]
# Create a single function that combines all the fetching steps for YouTube video data into one streamlined process.

# %%
def fetch_trending_videos(region_code: str, file_path: str):
    """Fetches trending videos from YouTube for a specific region.

    Args:
        region_code: A string representing the ISO 3166-1 alpha-2 country code for the desired region.
        target_file_path: A string representing the path to the file to be written.
    """
    
    # load API key from .env file
    load_dotenv("/opt/airflow/dags/.env")
    api_key = os.environ.get("YOUTUBE_API_KEY")

    # create YouTube API client
    youtube = build("youtube", "v3", developerKey=api_key)

    complete_infos = {
        'snippet':['title', 'publishedAt', 'channelTitle',
                'description', 'categoryId', 'defaultAudioLanguage', 'thumbnails'],
        'statistics':['viewCount', 'likeCount', 'commentCount'],
        'contentDetails':['duration']
    }

    # fetch videos until max_results is reached or there are no more results
    videos_list = []
    # initialize the token
    next_page_token = ""

    while next_page_token is not None:
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            chart="mostPopular",
            regionCode=region_code,
            maxResults=50,
            pageToken=next_page_token # add pageToken to inform the API
        )
        response = request.execute()
        videos = response.get("items", [])

        time_now = datetime.now(timezone.utc).strftime('%Y-%m-%dT%H:%M:%SZ')
        for video in videos:
            video_details = {'videoId': video["id"], 'trendingAt': time_now}
            
            for key, value in complete_infos.items():
                for info in value:
                    video_details[info] = video.get(key, {}).get(info)
                        
            videos_list.append(video_details)

        # store the next page to fetch (token)
        next_page_token = response.get("nextPageToken", None)

    with open(file_path, "w") as f:
        json.dump(videos_list, f)
    
    print('Done fetched the data.')

# %%
fetch_trending_videos(region_code='ID', file_path='dags/tmp_file.json')
# Out:
# Done fetched the data.

# %% [markdown]
# **Note**: Later, use `"/opt/airflow/dags/..."` for docker purpose

# %% [markdown]
# This process can be named as `fetch_trending_videos` as it encapsulates the functionality of fetching trending videos from YouTube for a specific region and storing them in a JSON file

# %% [markdown]
# ## Make Data Preprocessing Function

# %% [markdown]
# Create a single function that combines all the preprocessing steps for YouTube video data into one streamlined process.

# %%
def data_processing(source_file_path: str, target_file_path: str):
    """Processes the raw data fetched from YouTube.
    
    Args:
        source_file_path: A string representing the path to the file to be processed.
        target_file_path: A string representing the path to the file to be written.
    """
    # Load the fetched videos data from the json file
    with open(source_file_path, 'r') as f:
        videos_list = json.load(f)
    
    # Load the categories dictionary from the json file
    with open('dags/categories.json', 'r') as f:
        categories = json.load(f)
    
    # process each video in the list
    for video in videos_list:
        # convert categoryId to category based on categories dictionary
        video['category'] = categories.get(video.get('categoryId', ''))
        del video['categoryId']

        # convert ISO 8601 duration to seconds
        video['duration'] = isodate.parse_duration(video.get('duration', '')).total_seconds()
        del video['duration']

        # parse the thumbnail url
        video['thumbnailUrl'] = video.get('thumbnails', {}).get('standard', {}).get('url')
        del video['thumbnails']
        
        # convert viewCount, likeCount, and commentCount to integer
        video['viewCount'] = int(video.get('viewCount', 0))
        video['likeCount'] = int(video.get('likeCount', 0))
        video['commentCount'] = int(video.get('commentCount', 0))

    # save the processed videos data to a new file
    with open(target_file_path, "w") as f:
        json.dump(videos_list, f)

    print('Done preprocessed data.')

# %%
data_processing('dags/tmp_file.json', 'dags/tmp_file_processed.json')
# Out:
# Done preprocessed data.

# %% [markdown]
# **Note**: Later, use `"/opt/airflow/dags/..."` for docker purpose

# %% [markdown]
# The process described here can be named "data_processing". It involves several steps, including converting categoryId to category based on a predefined dictionary, converting ISO 8601 duration to seconds, parsing the thumbnail URL, and converting viewCount, likeCount, and commentCount to integers.

# %% [markdown]
# ## Why is Important to Make All Processes a Function
#
# It's important to make this process a function for several reasons:
# 1. **Reusability**: By encapsulating these preprocessing steps into a function, we can easily reuse it across different parts of the codebase or in other projects. This promotes code reuse and reduces redundancy.
#
# 2. **Modularity**: The function creates a clear separation of concerns by encapsulating the preprocessing logic. This makes the code easier to understand, maintain, and debug.
#
# 3. **Abstraction**: The function abstracts away the implementation details of the preprocessing steps, allowing users to focus on the high-level logic without getting bogged down in the specifics.
#
# 4. **Testability**: By making the preprocessing logic a function, it becomes easier to write unit tests to ensure the correctness of the processing steps.
#
# Relating it to the use case of scheduling with Apache Airflow, making this preprocessing logic a function enables us to easily integrate it into an Airflow DAG (Directed Acyclic Graph). We can create an Airflow operator that calls this function to preprocess the data before performing further tasks in the pipeline. This promotes automation, scalability, and maintainability of the data processing workflow within Airflow.

# %% [markdown]
# # Conclusion
#
# In summary, we've successfully completed the fetch and preprocess data steps, enabling us to retrieve trending YouTube videos for a specific region, process the data to extract relevant information, and store it in a JSON format. By encapsulating these processes within functions and ensuring modularity and reusability, we've established a robust foundation for automating our data pipeline.
#
# Moving forward, our next steps involve integrating these functions into a Directed Acyclic Graph (DAG) using Apache Airflow. This will allow us to automate the entire process, scheduling it to run at regular intervals to ensure we always have up-to-date data. Additionally, we can implement error handling, logging, and monitoring within Airflow to ensure the reliability and resilience of our data pipeline.
#
# Overall, this integration with Airflow will enhance the scalability, efficiency, and maintainability of our data acquisition workflow, enabling us to derive valuable insights from trending YouTube data with ease.
