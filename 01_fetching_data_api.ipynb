# %% [markdown]
# # Background: Importance of Data Fetching
#
# ## Importance of Data Fetching
# In today's data-driven world, access to timely and relevant data is crucial for businesses, researchers, and individuals alike. Data fetching refers to the process of retrieving information from various sources, enabling analysis, insights, and informed decision-making. The significance of data fetching lies in:
#
# 1. **Informed Decision-Making**: Data fetching provides access to real-time and historical data, empowering organizations to make informed decisions based on accurate information and trends.
#
# 2. **Business Intelligence**: Fetching data from diverse sources enables businesses to gain insights into market trends, customer behavior, and competitor activities, aiding in strategic planning and performance evaluation.
#
# 3. **Research and Innovation**: Researchers rely on data fetching to gather empirical evidence, conduct analyses, and validate hypotheses across various domains, fostering innovation and scientific discovery.
#
# 4. **Personalization**: Data fetching facilitates the delivery of personalized experiences in sectors such as e-commerce, entertainment, and healthcare, enhancing customer satisfaction and engagement.
#
# ## Methods of Data Fetching
# There are several methods to fetch data from different sources, each suited to specific requirements and use cases:
#
# 1. **Web Scraping**: This involves extracting data directly from web pages using automated scripts or tools. While effective for accessing publicly available information, web scraping may face challenges related to website structure and legality.
#
# 2. **File Transfer**: Data can be fetched by transferring files from one system to another using protocols like FTP (File Transfer Protocol) or SFTP (Secure File Transfer Protocol). This method is commonly used for batch data transfers.
#
# 3. **Database Queries**: Fetching data from databases involves executing queries using SQL (Structured Query Language) or NoSQL (Not Only SQL) languages to retrieve specific information from structured datasets stored in relational or non-relational databases.
#
# 4. **API (Application Programming Interface)**: APIs provide a standardized way for different software applications to communicate and exchange data. They offer a structured interface for accessing specific functionalities and datasets, making them a powerful and versatile method for data fetching.
#
# ## Introduction to API
# An API, or Application Programming Interface, is a set of rules, protocols, and tools that allows different software applications to communicate with each other. APIs define the methods and data formats that applications can use to request and exchange information.
#
# **Key Characteristics of APIs:**
# - **Standardization**: APIs provide a standardized way for applications to interact, ensuring compatibility and interoperability across different systems.
# - **Abstraction**: APIs abstract the underlying complexities of systems, allowing developers to access functionality or data without needing to understand the internal workings.
# - **Security**: APIs often incorporate authentication and authorization mechanisms to control access to sensitive data and resources.
# - **Scalability**: APIs are designed to handle large volumes of requests efficiently, enabling scalability and performance optimization.
#
# ## Example: YouTube API
#
# The YouTube API is a specific API provided by Google that allows developers to access and interact with YouTube's features and data programmatically. With the YouTube API, developers can perform tasks such as retrieving video information, uploading videos, managing playlists, and accessing analytics data.
#
# In the context of our project, we will focus on learning how to fetch data from YouTube using its API. By leveraging the YouTube API, we can programmatically retrieve trending videos, access metadata such as titles, descriptions, and view counts, and incorporate this data into our analytics pipelines or applications. Understanding how to interact with the YouTube API opens up opportunities for data-driven insights and innovation in various domains, including marketing, content creation, and audience engagement.

# %% [markdown]
# # Obtaining a YouTube API Key and Creating a YouTube API Client
#
# **1. Sign in to Google Developer Console**
# - Go to the [Google Developer Console](https://console.developers.google.com/).
# - Sign in with your Google account or create one if you don't have it already.
#
# **2. Create a New Project**
# - Once signed in, create a new project by clicking on the "Select a project" dropdown menu at the top of the page and then clicking on the "+ New Project" button.
# - Enter a name for your project and click "Create".
#
# **3. Enable the YouTube Data API v3**
# - In the Google Developer Console, navigate to the "Library" section from the left sidebar.
# - Search for "YouTube Data API v3" and click on it.
# - Click the "Enable" button to enable the API for your project.
#
# **4. Create API Key**
# - After enabling the YouTube Data API v3, navigate to the "Credentials" section from the left sidebar.
# - Click on the "Create credentials" dropdown menu and select "API key".
# - A dialog will appear displaying your API key. Copy this API key and store it securely.
#
# **5. Secure Your API Key**
# - It's essential to keep your API key secure to prevent unauthorized access and usage. Consider restricting the API key to only allow requests from specific websites or applications.
#
# **6. Integrate API Key into Your Application**
# - In your Python script, import the necessary libraries (`dotenv` for managing environment variables, `os` for interacting with the operating system).
# - Use the `load_dotenv` function to load environment variables from a `.env` file. Ensure that you have the `python-dotenv` library installed (`pip install python-dotenv`).
# - Set your YouTube API key as an environment variable in the `.env` file. For example:
#   ```
#   YOUTUBE_API_KEY=YOUR_API_KEY_HERE
#   ```

# %%
# import necessary libraries
import os
from dotenv import load_dotenv

# %%
# load API key from .env file
load_dotenv("dags/.env") # path only for trial
api_key = os.environ.get("YOUTUBE_API_KEY")

# %% [markdown]
# **Note**: Later, use `"/opt/airflow/dags/..."` for docker purpose

# %% [markdown]
# ## Access the API in Your Script
#
# - Within your Python script, import the `dotenv` and `os` libraries to access the API key.
# - Use the `os.environ.get()` function to retrieve the API key from the environment variables.
# - With the API key obtained, you can now create a YouTube API client using the `build` function from the `googleapiclient.discovery` module.

# %%
# create YouTube API client
from googleapiclient.discovery import build
youtube = build("youtube", "v3", developerKey=api_key)

# %% [markdown]
# By following these steps, you can obtain a YouTube API key and create a YouTube API client in your Python script. This allows you to programmatically interact with the YouTube Data API, fetching data such as trending videos, video metadata, and analytics information for further processing or analysis in your applications or workflows. Remember to keep your API key secure and adhere to Google's usage policies to avoid any potential issues or restrictions.

# %% [markdown]
# # Fetching Videos Using YouTube API

# %% [markdown]
# ## 1. Make a Single API Request for Videos
# Let's begin by taking our first step into accessing YouTube's vast video data through its API. We'll make a single request tailored to our criteria, fetching videos based on specific parameters.
#
# This initial action lays the foundation for our journey, offering a fundamental understanding of how to engage with the API and retrieve essential data.

# %%
region_code='ID'

# %%
# make API request for videos
request = youtube.videos().list(

    # define the parts of the video data to retrieve
    part="snippet,contentDetails,statistics",  

    # specify the type of chart to fetch videos from
    chart="mostPopular",  

    # specify the region based on ISO 3166-1 alpha-2 country code
    regionCode=region_code,  

    # define the maximum number of videos to retrieve in a single request (1-50)
    maxResults=50  
)

# %% [markdown]
# Certainly, let's break down the purpose of each parameter in the API request for a clearer understanding:
#
# - `part`: This parameter specifies which parts of the video resource to include in the API response. In this case, we're requesting the `snippet` (basic details like title, description), `contentDetails` (information about the video content like duration), and `statistics` (metrics like view counts, likes, comments) parts.
#
# - `chart`: The `chart` parameter determines the type of chart to retrieve videos from.
#
# - `regionCode`: This parameter specifies the region for which to fetch videos. It uses the ISO 3166-1 alpha-2 country code format to identify the desired region.
#
# - `maxResults`: The `maxResults` parameter sets the maximum number of videos to retrieve in a single API request. In this case, we're fetching up to 50 videos at a time, which is the maximum allowed by the YouTube API.
#
# **Note:** Detail documentation about `youtube.video.list()` parameters, you can check [here](https://developers.google.com/youtube/v3/docs/videos/list).
#
# By providing these parameters in our API request, we define the scope and criteria for fetching videos from YouTube, tailoring the data retrieval process to our specific needs and objectives.

# %% [markdown]
# ## 2. Execute a Single API Requests for Videos

# %% [markdown]
# After that, let's execute the requests using `execute()` function. This function is like pressing the "send" button on an email. It's what actually sends our request to YouTube's servers, asking for the videos we want. Once we hit "send" (or call `execute()`), YouTube gets our request, processes it, and sends back the information we asked for in a response. This response contains the videos we requested, along with their details like titles, views, and more.

# %%
response = request.execute()
response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'l8sKMOug3P5XUaxOjk0t4zRinf8',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'UExt0_tucgqtupl-u5nVKn8RPrI',
#    'id': '2bopnQpPwgI',
#    'snippet': {'publishedAt': '2024-03-17T18:49:27Z',
#     'channelId': 'UCViN2fPWI6zuZDXwn0O54xg',
#     'title': 'Manchester United 2-2 (4-3 aet) Liverpool | FA Cup 23/24 Match Highlights',
#     'description': 'Tonton liga-liga terbaik hanya di beIN SPORTS CONNECT: https://bein.onelink.me/bApY/beinYT \n\nSimak berita dan update menarik seputar liga terbaik dan beIN Sports Indonesia di semua sosial media:\n\nFacebook: https://www.facebook.com/beinsportsindonesia/\nTwitter: https://twitter.com/beinsportsid\nInstagram: https://www.instagram.com/beinsports.id/\nYouTube: https://www.youtube.com/c/beINSPORTSID',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'beIN SPORTS Indonesia',
#     'tags': ['FA Cup',
#      'Football',
#      'Highlights',
#      'Liverpool',
#      'Manchester United',
#      'Manchester United vs. Liverpool',
#      'Premier League',
#      'Soccer',
#      'Antony',
#      'Garnacho',
#      'Rashford',
#      'Amad Diallo',
#      'Hojlund',
#      'Salah',
#      'Elliot',
#      'macalister',
#      'FA Cup Highlights',
#      'Endo',
#      'Nunez',
#      'Onana'],
#     'categoryId': '17',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Manchester United 2-2 (4-3 aet) Liverpool | FA Cup 23/24 Match Highlights',
#      'description': 'Tonton liga-liga terbaik hanya di beIN SPORTS CONNECT: https://bein.onelink.me/bApY/beinYT \n\nSimak berita dan update menarik seputar liga terbaik dan beIN Sports Indonesia di semua sosial media:\n\nFacebook: https://www.facebook.com/beinsportsindonesia/\nTwitter: https://twitter.com/beinsportsid\nInstagram: https://www.instagram.com/beinsports.id/\nYouTube: https://www.youtube.com/c/beINSPORTSID'}},
#    'contentDetails': {'duration': 'PT11M51S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'regionRestriction': {'allowed': ['ID', 'PH', 'TL']},
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1817393',
#     'likeCount': '26262',
#     'favoriteCount': '0',
#     'commentCount': '3733'}},
#   {'kind': 'youtube#video',
#    'etag': 'rj7vdq132JrigwG5PToJTXNCJIo',
#    'id': 'jnJMc6053P0',
#    'snippet': {'publishedAt': '2024-03-17T03:00:07Z',
#     'channelId': 'UCEdO8A1SpMMF47LuGGV1nMQ',
#     'title': 'HAPPY ASMARA Feat. GILGA SAHID - MANOT | Feat. BINTANG FORTUNA (Official Music Video)',
#     'description': 'HAPPY ASMARA Feat GILGA SAHID - MANOT | Feat.BINTANG FORTUNA (Official Music Video)\n\nExecutive Producer : MUARA BINTANG\nMUSIC PRODUCTION\n\nTitle : Manot\nSongwriter : Gilga Sahid\nMusic By : Bintang Fortuna\nVocal : Happy Asmara Feat Gilga Sahid\nSupport By : HA Management\n\nLyric :\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nAku Sayang Koe, Tapi Koe Sayang Dek E\nLoro Atiku Mbok Sia Sia Ne \nKadung Nibo Nangi\nMerjuangne Kowe Kui \nNanging Nyatane Kowe Golek Pengganti\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nAku Pengene Ro Koweee\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\nMusic Video Playlist From Our Artists:\n♪ HAPPY ASMARA = https://youtube.com/playlist?list=PLx5WocVpsssWtgHHDBMcNSNFouwakJB4O\n♪ DIKE SABRINA =  https://youtube.com/playlist?list=PLx5WocVpsssW_hBLKmZkEfW1y3C5hMLT2\n♪ ROSYNTA DEWI =  https://youtube.com/playlist?list=PLx5WocVpsssVSZC0NBv9ptoweZsYQoG4s\n♪ VIA AMELIA = https://youtube.com/playlist?list=PLx5WocVpsssW_1AAL47-JOgV323whpLQl\n♪ DELVA IRAWAN = https://youtube.com/playlist?list=PLx5WocVpsssVgWeZlmlGz_rSj8yeAQWm4\n♪ YENI INKA  = https://youtube.com/playlist?list=PLx5WocVpsssX_3G4cn4tmfCmAZ2s3ZeG5\n♪ SHEPIN MISA  = https://youtube.com/playlist?list=PLx5WocVpsssUrEi-TUykU2Gvv5d7LdYVO\n♪ WORO WIDOWATI = https://youtube.com/playlist?list=PLx5WocVpsssVO9yjGayi2838twOwAIMoB\n♪ ARNETA YULIA =  https://youtube.com/playlist?list=PLx5WocVpsssXm8cAc3zefpSpADb9NIgtT\n♪ DAMARA DE = https://youtube.com/playlist?list=PLx5WocVpsssW8GluGDcbignRsYoxzDz9r\n♪ PUTRI KRISTYA = https://youtube.com/playlist?list=PLx5WocVpsssUZjCu1L7J3DpE48OAa8TQ5\n♪ LALA WIDY = https://youtube.com/playlist?list=PLx5WocVpsssUuM3MCwdeo48-Jc9Oe53KW\n♪ JIHAN AUDY =  https://youtube.com/playlist?list=PLx5WocVpsssVkZAGR5koEhaNgOZC6M9MZ\n♪ RATNA ANTIKA  = https://youtube.com/playlist?list=PLx5WocVpsssWN7hnGCuMV7ZaQHzosHAEo\n♪ TASYA ROSMALA = https://youtube.com/playlist?list=PLx5WocVpsssWc8t975YTIj1cXHuW9FNy8\n♪ BRODIN = https://youtube.com/playlist?list=PLx5WocVpsssWHqGTLuUO8r4DuHSNej87c\n♪ NEO SARI = https://youtube.com/playlist?list=PLx5WocVpsssVGLpfEMCzsKqCQa096Y32u\n♪ YUNI VEBRA =  https://youtube.com/playlist?list=PLx5WocVpsssX9hhfqWNfv-pKnzWo322zv\n♪ FIRA AZZAHRA = https://youtube.com/playlist?list=PLx5WocVpsssX9358s1rtR0IdX-yrazxE1\n♪ SALSA KIRANA = https://youtube.com/playlist?list=PLx5WocVpsssWF_lOEFU2VjflTiHPNf2s1\n♪ DUET = https://youtube.com/playlist?list=PLx5WocVpsssVfhUBrN_Rg2LgAS7KyzoUy\n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n\nContact our Management:\nTlp. : +62 857-3554-7777\n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n\nLicensed to YouTube by IDE (Music)\nThis channel & Video optimized by IDE Optimization\nLicense your music here: https://smarturl.id/idemusic\nOptimize your video now: https://smarturl.id/optimize\n\n#happyasmara #gilgasahid #manot #mb',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'MUARA BINTANG',
#     'tags': ['terpopuler',
#      'musik',
#      'beritaterkini',
#      'keroncong',
#      'campursari',
#      'orkesviral',
#      'thebastmusik',
#      'rajawali mitra',
#      'rajawali mitra musik',
#      'official video',
#      'trending',
#      'campursari koplo',
#      'anjawening',
#      'pangayu',
#      'cita citata',
#      'ayu ting ting',
#      'nella kharisma',
#      'perdana record',
#      'dd star',
#      'melady record',
#      'new arista',
#      'safari record',
#      'khatulistiwa record',
#      'sandi record',
#      'adella',
#      'adela',
#      'new pallapa',
#      'new palapa',
#      'via valen',
#      'aneka safari record',
#      'denny caknan',
#      'happy asmara music',
#      'gilga sahid',
#      'manot'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'HAPPY ASMARA Feat. GILGA SAHID - MANOT | Feat. BINTANG FORTUNA (Official Music Video)',
#      'description': 'HAPPY ASMARA Feat GILGA SAHID - MANOT | Feat.BINTANG FORTUNA (Official Music Video)\n\nExecutive Producer : MUARA BINTANG\nMUSIC PRODUCTION\n\nTitle : Manot\nSongwriter : Gilga Sahid\nMusic By : Bintang Fortuna\nVocal : Happy Asmara Feat Gilga Sahid\nSupport By : HA Management\n\nLyric :\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nAku Sayang Koe, Tapi Koe Sayang Dek E\nLoro Atiku Mbok Sia Sia Ne \nKadung Nibo Nangi\nMerjuangne Kowe Kui \nNanging Nyatane Kowe Golek Pengganti\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nAku Pengene Ro Koweee\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\nMusic Video Playlist From Our Artists:\n♪ HAPPY ASMARA = https://youtube.com/playlist?list=PLx5WocVpsssWtgHHDBMcNSNFouwakJB4O\n♪ DIKE SABRINA =  https://youtube.com/playlist?list=PLx5WocVpsssW_hBLKmZkEfW1y3C5hMLT2\n♪ ROSYNTA DEWI =  https://youtube.com/playlist?list=PLx5WocVpsssVSZC0NBv9ptoweZsYQoG4s\n♪ VIA AMELIA = https://youtube.com/playlist?list=PLx5WocVpsssW_1AAL47-JOgV323whpLQl\n♪ DELVA IRAWAN = https://youtube.com/playlist?list=PLx5WocVpsssVgWeZlmlGz_rSj8yeAQWm4\n♪ YENI INKA  = https://youtube.com/playlist?list=PLx5WocVpsssX_3G4cn4tmfCmAZ2s3ZeG5\n♪ SHEPIN MISA  = https://youtube.com/playlist?list=PLx5WocVpsssUrEi-TUykU2Gvv5d7LdYVO\n♪ WORO WIDOWATI = https://youtube.com/playlist?list=PLx5WocVpsssVO9yjGayi2838twOwAIMoB\n♪ ARNETA YULIA =  https://youtube.com/playlist?list=PLx5WocVpsssXm8cAc3zefpSpADb9NIgtT\n♪ DAMARA DE = https://youtube.com/playlist?list=PLx5WocVpsssW8GluGDcbignRsYoxzDz9r\n♪ PUTRI KRISTYA = https://youtube.com/playlist?list=PLx5WocVpsssUZjCu1L7J3DpE48OAa8TQ5\n♪ LALA WIDY = https://youtube.com/playlist?list=PLx5WocVpsssUuM3MCwdeo48-Jc9Oe53KW\n♪ JIHAN AUDY =  https://youtube.com/playlist?list=PLx5WocVpsssVkZAGR5koEhaNgOZC6M9MZ\n♪ RATNA ANTIKA  = https://youtube.com/playlist?list=PLx5WocVpsssWN7hnGCuMV7ZaQHzosHAEo\n♪ TASYA ROSMALA = https://youtube.com/playlist?list=PLx5WocVpsssWc8t975YTIj1cXHuW9FNy8\n♪ BRODIN = https://youtube.com/playlist?list=PLx5WocVpsssWHqGTLuUO8r4DuHSNej87c\n♪ NEO SARI = https://youtube.com/playlist?list=PLx5WocVpsssVGLpfEMCzsKqCQa096Y32u\n♪ YUNI VEBRA =  https://youtube.com/playlist?list=PLx5WocVpsssX9hhfqWNfv-pKnzWo322zv\n♪ FIRA AZZAHRA = https://youtube.com/playlist?list=PLx5WocVpsssX9358s1rtR0IdX-yrazxE1\n♪ SALSA KIRANA = https://youtube.com/playlist?list=PLx5WocVpsssWF_lOEFU2VjflTiHPNf2s1\n♪ DUET = https://youtube.com/playlist?list=PLx5WocVpsssVfhUBrN_Rg2LgAS7KyzoUy\n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n\nContact our Management:\nTlp. : +62 857-3554-7777\n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n\nLicensed to YouTube by IDE (Music)\nThis channel & Video optimized by IDE Optimization\nLicense your music here: https://smarturl.id/idemusic\nOptimize your video now: https://smarturl.id/optimize\n\n#happyasmara #gilgasahid #manot #mb'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT6M34S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '2009661',
#     'likeCount': '216448',
#     'favoriteCount': '0',
#     'commentCount': '38871'}},
#   {'kind': 'youtube#video',
#    'etag': 'G-ITehO-X3Ya2uorMxUUCNBv7vg',
#    'id': 'Ra0AhAkYDho',
#    'snippet': {'publishedAt': '2024-03-18T12:00:22Z',
#     'channelId': 'UCfpaSruWW3S4dibonKXENjA',
#     'title': '자카르타1탄) 인도네시아에서 신기록 세웠습니다🇲🇨 7500평 최대규모 식당에서 사테 xxx개 먹방',
#     'description': '#viral#Indonesia#jakarta#sate\n\n각국어 번역 자막 제작 : \n컨텐츠 제작의 마무리는 컨텐츠플라이! 글로벌 진출을 위한 최고의 파트너,\nCONTENTSFLY에서 제작되었습니다.\nhttps://www.contentsfly.com\n\n비지니스 메일:gardenm1120@gmail.com',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ra0AhAkYDho/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ra0AhAkYDho/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ra0AhAkYDho/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Ra0AhAkYDho/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'tzuyang쯔양',
#     'tags': ['real sound',
#      '리얼사운드',
#      'social eating',
#      'mukbang',
#      'eating show',
#      '먹방',
#      '맛집'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'ko',
#     'localized': {'title': '자카르타1탄) 인도네시아에서 신기록 세웠습니다🇲🇨 7500평 최대규모 식당에서 사테 xxx개 먹방',
#      'description': '#viral#Indonesia#jakarta#sate\n\n각국어 번역 자막 제작 : \n컨텐츠 제작의 마무리는 컨텐츠플라이! 글로벌 진출을 위한 최고의 파트너,\nCONTENTSFLY에서 제작되었습니다.\nhttps://www.contentsfly.com\n\n비지니스 메일:gardenm1120@gmail.com'},
#     'defaultAudioLanguage': 'ko'},
#    'contentDetails': {'duration': 'PT23M28S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '586427',
#     'likeCount': '52071',
#     'favoriteCount': '0',
#     'commentCount': '5674'}},
#   {'kind': 'youtube#video',
#    'etag': 'OkgzMaDpWNT9ymbUZwkpl-3nkcM',
#    'id': 'qoU7RFMjE6I',
#    'snippet': {'publishedAt': '2024-03-17T16:35:08Z',
#     'channelId': 'UCl2y8_wNtI7N13fOinesLMA',
#     'title': 'Kiky Saputri dan Suami Buka Suara Terkait Kehamilannya',
#     'description': "Silakan komen di bawah 🖤 Kalian mau aku buat konten apa lagi?\n\nJangan lupa Subscribe nya ya : https://bit.ly/SubsKikySaputri\n\nInstagram : https://www.instagram.com/kikysaputrii\n\nKiky Saputri Official's Youtube is under management of:\ndr.m, Indonesia's 1st Certified & Official Youtube MCN\nhttps://servicesdirectory.withyoutube.com/directory/pt-digital-rantai-maya-drm",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Kiky Saputri Official',
#     'tags': ['kiki',
#      'kiky',
#      'kiki saputri',
#      'kiky saputri official',
#      'stand up comedy',
#      'comedy',
#      'komika',
#      'lucu',
#      'ngakak',
#      'hahaha corp',
#      'comedian',
#      'standup',
#      'komedi',
#      'kiky saputri',
#      'keguguran',
#      'kiky saputri keguguran',
#      'kiky saputri hamil',
#      'kiky saputri kehilangan buah hati',
#      'komika keguguran',
#      'bayi kiky saputri',
#      'anak kiky saputri'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Kiky Saputri dan Suami Buka Suara Terkait Kehamilannya',
#      'description': "Silakan komen di bawah 🖤 Kalian mau aku buat konten apa lagi?\n\nJangan lupa Subscribe nya ya : https://bit.ly/SubsKikySaputri\n\nInstagram : https://www.instagram.com/kikysaputrii\n\nKiky Saputri Official's Youtube is under management of:\ndr.m, Indonesia's 1st Certified & Official Youtube MCN\nhttps://servicesdirectory.withyoutube.com/directory/pt-digital-rantai-maya-drm"}},
#    'contentDetails': {'duration': 'PT26M52S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '411622',
#     'likeCount': '12263',
#     'favoriteCount': '0',
#     'commentCount': '2255'}},
#   {'kind': 'youtube#video',
#    'etag': '9VUtos_lkqPUkKmSpdY_od-9Itc',
#    'id': 'E-GvMpXXr1g',
#    'snippet': {'publishedAt': '2024-03-17T09:05:15Z',
#     'channelId': 'UCVAwRh03m3_1pZjRKvelomA',
#     'title': 'STUDY TOUR #25 - Serena Hilang',
#     'description': 'Yuk gabung dengan channel ini untuk mendapatkan akses ke berbagai keuntungan:\nhttps://www.youtube.com/channel/UCVAwRh03m3_1pZjRKvelomA/join\n\n\nMERCHANDISE Dasi Gantung \nShopee : https://shope.ee/501KQe83d4\n\nIni akun Dasi Gantung yang lain ya\nFacebook.     : https://www.facebook.com/profile.php?id=100066603937194\nTiktok   : https://vt.tiktok.com/ZSEXx5XV/\nInstagram : https://www.instagram.com/dasigantung/\nShopee Video : https://shopee.co.id/universal-link?redir=https%3A%2F%2Fshp.ee%2F9nidyp5&deep_and_deferred=1&smtt=0.0.9\nBstation   : https://bili.im/XXF4OcF\n\nDasi Gantung tidak punya akun sosial media selain diatas. Makasih banyak sudah support terus channel ini\xa0\n\nIni link game “Dimensi Lain Serena” tersedia di AppStore dan Play Store\nPlay Store :\nhttps://play.google.com/store/apps/details?id=com.arcadesindo.dimensilainserena\niOS (App Store) :\nhttps://apps.apple.com/id/app/dimensi-lain-serena/id1617391251?l=id\n\n#animasi #dasigantung #serena #monika #raki #ratara #animasisekolah #studytour',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Dasi Gantung',
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'STUDY TOUR #25 - Serena Hilang',
#      'description': 'Yuk gabung dengan channel ini untuk mendapatkan akses ke berbagai keuntungan:\nhttps://www.youtube.com/channel/UCVAwRh03m3_1pZjRKvelomA/join\n\n\nMERCHANDISE Dasi Gantung \nShopee : https://shope.ee/501KQe83d4\n\nIni akun Dasi Gantung yang lain ya\nFacebook.     : https://www.facebook.com/profile.php?id=100066603937194\nTiktok   : https://vt.tiktok.com/ZSEXx5XV/\nInstagram : https://www.instagram.com/dasigantung/\nShopee Video : https://shopee.co.id/universal-link?redir=https%3A%2F%2Fshp.ee%2F9nidyp5&deep_and_deferred=1&smtt=0.0.9\nBstation   : https://bili.im/XXF4OcF\n\nDasi Gantung tidak punya akun sosial media selain diatas. Makasih banyak sudah support terus channel ini\xa0\n\nIni link game “Dimensi Lain Serena” tersedia di AppStore dan Play Store\nPlay Store :\nhttps://play.google.com/store/apps/details?id=com.arcadesindo.dimensilainserena\niOS (App Store) :\nhttps://apps.apple.com/id/app/dimensi-lain-serena/id1617391251?l=id\n\n#animasi #dasigantung #serena #monika #raki #ratara #animasisekolah #studytour'}},
#    'contentDetails': {'duration': 'PT5M30S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '452049',
#     'likeCount': '49439',
#     'favoriteCount': '0',
#     'commentCount': '3429'}},
#   {'kind': 'youtube#video',
#    'etag': 'YmOvHuH8bP-aEvknmpRvGpOE8nw',
#    'id': 'RZmO08bFgYA',
#    'snippet': {'publishedAt': '2024-03-18T13:49:11Z',
#     'channelId': 'UCA_fIuIBkjjO5IfK50Iqs7w',
#     'title': 'RAMADHAN LOVE STORY PART 1 - Animasi Sekolah',
#     'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Dhot Design',
#     'tags': ['dhot design',
#      'dhokona',
#      'animasi sekolah',
#      'animasi tentang sekolahan',
#      'animasi lucu sekolah',
#      'animasi tentang anak sekolah',
#      'animasi sekolah sma',
#      'animasi kocak bikin ngakak',
#      'animasi lucu anak sma',
#      'animasi sekolah indonesia',
#      'anime school',
#      'anime sekolahan',
#      'kartun lucu sekolah'],
#     'categoryId': '1',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'id',
#     'localized': {'title': 'RAMADHAN LOVE STORY PART 1 - Animasi Sekolah',
#      'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT5M31S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1801057',
#     'likeCount': '107618',
#     'favoriteCount': '0',
#     'commentCount': '7361'}},
#   {'kind': 'youtube#video',
#    'etag': 'W_ygRhI-fHBSkzC9bS4wYWFoRiU',
#    'id': 'RowlrvmyFEk',
#    'snippet': {'publishedAt': '2024-03-18T09:00:07Z',
#     'channelId': 'UCaO6TYtlC8U5ttz62hTrZgg',
#     'title': 'DAY6(데이식스) "Welcome to the Show" M/V',
#     'description': 'DAY6(데이식스) "Welcome to the Show" M/V\r\n\nListen to DAY6 "Welcome to the Show" \nhttps://day6.lnk.to/fourever\n\nDAY6 Official YouTube: http://www.youtube.com/c/DAY6Official\nDAY6 Official Facebook: http://www.facebook.com/DAY6Official\nDAY6 Official Twitter: http://www.twitter.com/DAY6Official\nDAY6 FANS App Store : http://bit.ly/48OILIW\nDAY6 FANS Google Play : http://bit.ly/48tBxKE\nDAY6 Official Homepage: http://DAY6.jype.com\n\nCopyrights 2024 ⓒ JYP Entertainment. All Rights Reserved.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'JYP Entertainment',
#     'tags': ['JYP Entertainment',
#      'JYP',
#      'DAY6',
#      '데이식스',
#      'DAY6 Young K',
#      'DAY6 Sungjin',
#      'DAY6 Wonpil',
#      'DAY6 Dowoon',
#      'DAY6 영케이',
#      'DAY6 성진',
#      'DAY6 원필',
#      'DAY6 도운',
#      '데이식스 Young K',
#      '데이식스 영케이',
#      '데이식스 성진',
#      '데이식스 원필',
#      '데이식스 도운',
#      'Young K',
#      'Sungjin',
#      'Wonpil',
#      'Dowoon',
#      '영케이',
#      '성진',
#      '원필',
#      '도운',
#      'Fourever',
#      'Welcome to the Show'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'DAY6(데이식스) "Welcome to the Show" M/V',
#      'description': 'DAY6(데이식스) "Welcome to the Show" M/V\r\n\nListen to DAY6 "Welcome to the Show" \nhttps://day6.lnk.to/fourever\n\nDAY6 Official YouTube: http://www.youtube.com/c/DAY6Official\nDAY6 Official Facebook: http://www.facebook.com/DAY6Official\nDAY6 Official Twitter: http://www.twitter.com/DAY6Official\nDAY6 FANS App Store : http://bit.ly/48OILIW\nDAY6 FANS Google Play : http://bit.ly/48tBxKE\nDAY6 Official Homepage: http://DAY6.jype.com\n\nCopyrights 2024 ⓒ JYP Entertainment. All Rights Reserved.'},
#     'defaultAudioLanguage': 'ko'},
#    'contentDetails': {'duration': 'PT3M56S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '775938',
#     'likeCount': '65432',
#     'favoriteCount': '0',
#     'commentCount': '5184'}},
#   {'kind': 'youtube#video',
#    'etag': '4HPSY7_g_n0QOpddYX73qzMQRjY',
#    'id': 'oZD34dkfhNQ',
#    'snippet': {'publishedAt': '2024-03-18T11:00:50Z',
#     'channelId': 'UCXURHJRGr4-EB3l87kcbElw',
#     'title': 'No brake getting faster | 7llin’ with DREAM | EP. 3',
#     'description': '#7llin_with_DREAM #칠링윗드림\n#NCTDREAM #Smoothie\n#NCTDREAM_Smoothie\n\nNCT DREAM Official\nhttps://www.youtube.com/nctdream \nhttps://www.instagram.com/nct_dream/ \nhttps://www.tiktok.com/@official_nct\nhttps://twitter.com/NCTsmtown_DREAM \nhttps://www.facebook.com/NCT.smtown',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'NCT DREAM',
#     'tags': ['NCT DREAM',
#      '엔시티 드림',
#      'MARK',
#      'RENJUN',
#      'JENO',
#      'HAECHAN',
#      'JAEMIN',
#      'CHENLE',
#      'JISUNG',
#      '마크',
#      '런쥔',
#      '제노',
#      '해찬',
#      '재민',
#      '천러',
#      '지성'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'No brake getting faster | 7llin’ with DREAM | EP. 3',
#      'description': '#7llin_with_DREAM #칠링윗드림\n#NCTDREAM #Smoothie\n#NCTDREAM_Smoothie\n\nNCT DREAM Official\nhttps://www.youtube.com/nctdream \nhttps://www.instagram.com/nct_dream/ \nhttps://www.tiktok.com/@official_nct\nhttps://twitter.com/NCTsmtown_DREAM \nhttps://www.facebook.com/NCT.smtown'},
#     'defaultAudioLanguage': 'ko'},
#    'contentDetails': {'duration': 'PT32M28S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '343564',
#     'likeCount': '51834',
#     'favoriteCount': '0',
#     'commentCount': '1344'}},
#   {'kind': 'youtube#video',
#    'etag': '1muPtSoa8gHdvw1hnXJXKm3D2jQ',
#    'id': 'yJTy6e62fU8',
#    'snippet': {'publishedAt': '2024-03-17T09:11:05Z',
#     'channelId': 'UCkzbfqQmXyAPY_XEsJvkcWg',
#     'title': 'CARA MEMBUAT MUSUH KESAL PART 38!!!',
#     'description': 'Follow Me on :\nemail : indrawijy08@gmail.com\nInstragram : https://www.instagram.com/gerradwijy08\nTiktok          : https://www.tiktok.com/@barbar_esport1.fb\n \n---------------------------------------------------------------------------------------------------------\nlike, Share, And Comment kalo lu suka, kalo ga suka ya gpp\n---------------------------------------------------------------------------------------------------------\n\n► CREDIT and USAGE\n\n✘ Title:  hyperfun\n✘ Music:  Kevin MacLeod \n✘ License: CC BY 3.0 (http://goo.gl/BlcHZR)\n✘ Download: http://incompetech.com/music/royalty-...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Gerrard Wijaya',
#     'tags': ['bug mlbb', 'gerrard wijaya', 'gerrad wijaya'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-US',
#     'localized': {'title': 'CARA MEMBUAT MUSUH KESAL PART 38!!!',
#      'description': 'Follow Me on :\nemail : indrawijy08@gmail.com\nInstragram : https://www.instagram.com/gerradwijy08\nTiktok          : https://www.tiktok.com/@barbar_esport1.fb\n \n---------------------------------------------------------------------------------------------------------\nlike, Share, And Comment kalo lu suka, kalo ga suka ya gpp\n---------------------------------------------------------------------------------------------------------\n\n► CREDIT and USAGE\n\n✘ Title:  hyperfun\n✘ Music:  Kevin MacLeod \n✘ License: CC BY 3.0 (http://goo.gl/BlcHZR)\n✘ Download: http://incompetech.com/music/royalty-...'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT11M50S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '515746',
#     'likeCount': '21514',
#     'favoriteCount': '0',
#     'commentCount': '1447'}},
#   {'kind': 'youtube#video',
#    'etag': '-KjFKQ5rQ_kj2XXbazlO6Zi_aWM',
#    'id': 'mKdjycj-7eE',
#    'snippet': {'publishedAt': '2024-03-16T16:00:00Z',
#     'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'title': 'Stop This Train, Win a Lamborghini',
#     'description': 'I still can’t believe what happened in this video lol \nCheck out the mind-blowing Galaxy AI on the Samsung Galaxy S24 Ultra. Click this link to see for yourself: https://bit.ly/MrBeast_SamsungGalaxyS24\n\nPlay the Official Fortnite Creative Map For This Video Here:\nMrBeast Minigames 🎯 - 9466-1340-3054\nhttps://www.fortnite.com/@mrbeast/9466-1340-3054\n\nThanks to Daniel Schiffer for the Feastables ad! Go check him out here @danielschiffer \n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'MrBeast',
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'Stop This Train, Win a Lamborghini',
#      'description': 'I still can’t believe what happened in this video lol \nCheck out the mind-blowing Galaxy AI on the Samsung Galaxy S24 Ultra. Click this link to see for yourself: https://bit.ly/MrBeast_SamsungGalaxyS24\n\nPlay the Official Fortnite Creative Map For This Video Here:\nMrBeast Minigames 🎯 - 9466-1340-3054\nhttps://www.fortnite.com/@mrbeast/9466-1340-3054\n\nThanks to Daniel Schiffer for the Feastables ad! Go check him out here @danielschiffer \n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT18M53S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '61606521',
#     'likeCount': '3170076',
#     'favoriteCount': '0',
#     'commentCount': '96375'}},
#   {'kind': 'youtube#video',
#    'etag': 'EcWP2m2KeLtPXx0ESOZh846BblA',
#    'id': 'l90gs0-gcjo',
#    'snippet': {'publishedAt': '2024-03-17T22:26:55Z',
#     'channelId': 'UC14UlmYlSNiQCBe9Eookf_A',
#     'title': 'ATLETICO DE MADRID 0 vs 3 FC BARCELONA | LALIGA 2023/24 MD29',
#     'description': "Goals from João Félix, Lewandowski and Fermín inflict a first home defeat of the season in the league on Atlético.\n\nSUBSCRIBE NOW:\n▶ https://www.youtube.com/user/fcbarcelona \n\n⚽ BARÇATV+: http://barca.link/wT1w30qMyQO\u200b\n💎 Official Culers Membership: http://barca.link/plXS30rAhfC\u200b\n🌐 Site: http://www.fcbarcelona.com\n📱 App: https://go.onelink.me/xndC/DownloadAppYouTube\n\n🔵 Facebook: http://www.facebook.com/fcbarcelona\n📸 Instagram: http://www.instagram.com/fcbarcelona\n𝕏 Twitter: http://twitter.com/FCBarcelona\n🎶 Tiktok: https://www.tiktok.com/@fcbarcelona \n👾 Discord: https://discord.gg/fcbarcelonaofficial\n\n🛍 Get all official Barça apparel from FC Barcelona's online store: http://barca.link/j8QH30qQh4Y \n🔵🔴 #FCBarcelona",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'FC Barcelona',
#     'tags': ['FC Barcelona',
#      'برشلونة،',
#      'Fútbol',
#      'FUTBOL',
#      'soccer',
#      'FUTEBOL',
#      'Sepakbola',
#      'サッカー',
#      'كرة القدم',
#      'football',
#      'FCB',
#      'Barça',
#      'Sport',
#      'Club',
#      'Barcelona',
#      'CAMP NOU',
#      'ter stegen',
#      'pique',
#      'busquets',
#      'goat',
#      'dembele',
#      'yt:cc=on',
#      'ansu fati',
#      'pedri',
#      'de Jong',
#      'Kun Agüero',
#      'Aguero',
#      'lewandowski',
#      'spotify',
#      'kounde',
#      'Joao Felix',
#      'Joao Cancelo',
#      'Gavi',
#      'Marcos Alonso',
#      'Lamine Yamal',
#      'Balde',
#      'Lewy',
#      'Lewandowski',
#      'Marc Guiu',
#      'Atletico Madrid',
#      'Highlights',
#      'Resumen',
#      'Resum',
#      'Civitas',
#      'Metropolitano',
#      'Cholo',
#      'Simeone',
#      'Griezmann',
#      'Cubarsí'],
#     'categoryId': '17',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'ATLETICO DE MADRID 0 vs 3 FC BARCELONA | LALIGA 2023/24 MD29',
#      'description': "Goals from João Félix, Lewandowski and Fermín inflict a first home defeat of the season in the league on Atlético.\n\nSUBSCRIBE NOW:\n▶ https://www.youtube.com/user/fcbarcelona \n\n⚽ BARÇATV+: http://barca.link/wT1w30qMyQO\u200b\n💎 Official Culers Membership: http://barca.link/plXS30rAhfC\u200b\n🌐 Site: http://www.fcbarcelona.com\n📱 App: https://go.onelink.me/xndC/DownloadAppYouTube\n\n🔵 Facebook: http://www.facebook.com/fcbarcelona\n📸 Instagram: http://www.instagram.com/fcbarcelona\n𝕏 Twitter: http://twitter.com/FCBarcelona\n🎶 Tiktok: https://www.tiktok.com/@fcbarcelona \n👾 Discord: https://discord.gg/fcbarcelonaofficial\n\n🛍 Get all official Barça apparel from FC Barcelona's online store: http://barca.link/j8QH30qQh4Y \n🔵🔴 #FCBarcelona"},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT3M26S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1409583',
#     'likeCount': '57468',
#     'favoriteCount': '0',
#     'commentCount': '1530'}},
#   {'kind': 'youtube#video',
#    'etag': 'KQMiiKBzq211yN1qbEeFF7tYbbw',
#    'id': 'V49w-6ZrUQw',
#    'snippet': {'publishedAt': '2024-03-18T05:08:24Z',
#     'channelId': 'UCXXXH-_5wCkVdOLq-hRU6rQ',
#     'title': 'AKHIRNYA KONTRAKSI DAN HARUS CEPAT KE RUMAH SAKIT,  DETIK DETIK LAHIRAN ANAK KEDUA DI CHINA',
#     'description': "#pernikahancampuran #indonesia   #china #desaterpencil #indonesianfood #jualanmakanan \nASSALAMUALAIKUM WRB.\n\nHalo teman-teman kembali lagi di channel YouTube DAILY TIKA WEIXUN DICHINA\nsaya TIKA warga Indonesia yg menikah dengan Warga Tiongkok yg Bernama LIANG WEIXUN kami memiliki anak PERTAMA Yg bernama CHINA LIANG ZHEYU.Nama Indonesia anak kami adalaha MUHAMMAD ABIL SHIDQI \n\nKami memiliki keluarga besar  yg hangat saling toleransi dan selalu menerima perbedaan semua keluarga kami sangat baik \n\nsebelumnya TERIMAKASIH BANYAK atas komentar baik kalian dan kami meminta maaf sebesar besarnya kalau komentar Dari teman teman KAMI belum bisa balas satu-satu 🙏SEMOGA teman teman mengerti Dengan keadaan dan kesibukan kami membuat video setiap hari  untuk menghibur kalian. \nTerima kasih untuk yang sudah komentar memberikan do'a support dan dukungan pada kami.Terima kasih atas saran masukan dan juga tman-teman \nTeman-teman\n\nyuuuk ikutin  keseruan kami divideo kali ini   dari awal sampai habis jangan di-skip \nsemoga kalian suka dengan video kali ini yaaah ...\n\nuntuk teman teman yang baru gabung selamat bergabung di channel kami semoga betah yah dan jangan bosan bosan hehehehe😘\nuntuk teman teman yang belum subscribe,yuuk disubscribe channel ini bantu like dan koment juga yaaah bila perlu di share hehehe\nterimakasih banyak semuanya sudah meluangkan waktunya untuk menonton video Dari kami we love you all\nlangsung nonton yuuuk \njangan di skip skip yaaah teman teman 😚😉😉\n\njangan lupa follow juga ig kami yaaah teman teman\n@tika_weixun02\nhttps://instagram.com/tika_weixun02",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'DAILY TIKA WEIXUN DI CHINA',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'id',
#     'localized': {'title': 'AKHIRNYA KONTRAKSI DAN HARUS CEPAT KE RUMAH SAKIT,  DETIK DETIK LAHIRAN ANAK KEDUA DI CHINA',
#      'description': "#pernikahancampuran #indonesia   #china #desaterpencil #indonesianfood #jualanmakanan \nASSALAMUALAIKUM WRB.\n\nHalo teman-teman kembali lagi di channel YouTube DAILY TIKA WEIXUN DICHINA\nsaya TIKA warga Indonesia yg menikah dengan Warga Tiongkok yg Bernama LIANG WEIXUN kami memiliki anak PERTAMA Yg bernama CHINA LIANG ZHEYU.Nama Indonesia anak kami adalaha MUHAMMAD ABIL SHIDQI \n\nKami memiliki keluarga besar  yg hangat saling toleransi dan selalu menerima perbedaan semua keluarga kami sangat baik \n\nsebelumnya TERIMAKASIH BANYAK atas komentar baik kalian dan kami meminta maaf sebesar besarnya kalau komentar Dari teman teman KAMI belum bisa balas satu-satu 🙏SEMOGA teman teman mengerti Dengan keadaan dan kesibukan kami membuat video setiap hari  untuk menghibur kalian. \nTerima kasih untuk yang sudah komentar memberikan do'a support dan dukungan pada kami.Terima kasih atas saran masukan dan juga tman-teman \nTeman-teman\n\nyuuuk ikutin  keseruan kami divideo kali ini   dari awal sampai habis jangan di-skip \nsemoga kalian suka dengan video kali ini yaaah ...\n\nuntuk teman teman yang baru gabung selamat bergabung di channel kami semoga betah yah dan jangan bosan bosan hehehehe😘\nuntuk teman teman yang belum subscribe,yuuk disubscribe channel ini bantu like dan koment juga yaaah bila perlu di share hehehe\nterimakasih banyak semuanya sudah meluangkan waktunya untuk menonton video Dari kami we love you all\nlangsung nonton yuuuk \njangan di skip skip yaaah teman teman 😚😉😉\n\njangan lupa follow juga ig kami yaaah teman teman\n@tika_weixun02\nhttps://instagram.com/tika_weixun02"},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT20M32S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '406239',
#     'likeCount': '25432',
#     'favoriteCount': '0',
#     'commentCount': '2981'}},
#   {'kind': 'youtube#video',
#    'etag': '6NeC0OvGwGxcTaTmrfB8LVSPUQ8',
#    'id': 'DwZvETHRNT8',
#    'snippet': {'publishedAt': '2024-03-17T11:30:05Z',
#     'channelId': 'UCuVxJ829ysWH2OhZJiWdnbg',
#     'title': 'MONVLOG - NYARI TAKJIL BUAT BUKA PUASA!',
#     'description': 'Yuk gabung jadi member channel youtube aku melalui link ini:\nhttps://www.youtube.com/channel/UCuVxJ829ysWH2OhZJiWdnbg/join\n\nTempat Topup Para Juara:\nhttps://lemontopup.id/\n\nRamein Discord nya yuk!\nhttps://discord.gg/srwdEWE6c4\n\nJangan lupa follow aku ya :\n👉 https://instagram.com/ikhsan_lemon\n\nBussines : 0811-1993-0001\nEmail: business@teamrrq.com',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'RRQ Lemon',
#     'tags': ['lemon',
#      'rrq lemon',
#      'lemon rrq',
#      'team rrq',
#      'rrq hoshi',
#      'mobile legends'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'MONVLOG - NYARI TAKJIL BUAT BUKA PUASA!',
#      'description': 'Yuk gabung jadi member channel youtube aku melalui link ini:\nhttps://www.youtube.com/channel/UCuVxJ829ysWH2OhZJiWdnbg/join\n\nTempat Topup Para Juara:\nhttps://lemontopup.id/\n\nRamein Discord nya yuk!\nhttps://discord.gg/srwdEWE6c4\n\nJangan lupa follow aku ya :\n👉 https://instagram.com/ikhsan_lemon\n\nBussines : 0811-1993-0001\nEmail: business@teamrrq.com'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT12M6S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '459531',
#     'likeCount': '41146',
#     'favoriteCount': '0',
#     'commentCount': '4084'}},
#   {'kind': 'youtube#video',
#    'etag': '9qE0SixoSIgFB9XKl6yp6v7pUx4',
#    'id': 'zji-gXontsM',
#    'snippet': {'publishedAt': '2024-03-17T20:00:21Z',
#     'channelId': 'UCu3Oq_wEChEPaV7abgY688g',
#     'title': 'MIC CHECK ALTER EGO VS EVOS | WEEK 1 - DAY 1 | MPL SEASON 13',
# ...
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT4M8S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '356807',
#     'likeCount': '35606',
#     'favoriteCount': '0',
#     'commentCount': '3098'}},
#   {'kind': 'youtube#video',
#    'etag': 'q3A3X6sk224eQPRylSb8TqkOV50',
#    'id': 'EXZAHdkTP2I',
#    'snippet': {'publishedAt': '2024-03-15T11:58:44Z',
#     'channelId': 'UCA_fIuIBkjjO5IfK50Iqs7w',
#     'title': 'KONA GAK SAUR PART 1 - Animasi Sekolah',
#     'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Dhot Design',
#     'tags': ['dhot design',
#      'dhokona',
#      'animasi sekolah',
#      'animasi tentang sekolahan',
#      'animasi lucu sekolah',
#      'animasi tentang anak sekolah',
#      'animasi sekolah sma',
#      'animasi kocak bikin ngakak',
#      'animasi lucu anak sma',
#      'animasi sekolah indonesia',
#      'anime school',
#      'anime sekolahan',
#      'kartun lucu sekolah'],
#     'categoryId': '1',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'id',
#     'localized': {'title': 'KONA GAK SAUR PART 1 - Animasi Sekolah',
#      'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT8M5S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '4021625',
#     'likeCount': '221312',
#     'favoriteCount': '0',
#     'commentCount': '17893'}},
#   {'kind': 'youtube#video',
#    'etag': 'Ff2kN7MnR8DxBv3Io_ok8yxuESM',
#    'id': 'sQCskcSeKI4',
#    'snippet': {'publishedAt': '2024-03-16T08:59:48Z',
#     'channelId': 'UCVdxec6r85Cy45nL1wQKxrQ',
#     'title': 'SUASANA BERBUKA PUASA DI RUMAH BARU ! ADA MUSHALLA NYA 🥰',
#     'description': '.................\nSEDEKAH BERAS nya om/tante!\nhttps://trakteer.id/neojapan\n..........................................\nchannel PODCAST NEOJAPAN SOON ! https://www.youtube.com/channel/UCN4WWwEz1QMDg1Ua1tz7MEg\n\ninstagram NEOJAPAN_;  https://www.instagram.com/neojapan_/?hl=en\ninstagram Yusufkun ; https://www.instagram.com/yuu.kun21/?hl=en',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Neo Japan',
#     'tags': ['Neo Japan',
#      'cewe jepang',
#      'cewek jepang',
#      'reaksi orang jepang',
#      'reaksi cewe jepang',
#      'reaksi cewek jepang',
#      'kimochi',
#      'dedek jepang gemes',
#      'cewe jepang malu-malu',
#      'lombok',
#      'surfer',
#      'istri jepang',
#      'cara taklukin cewe jepang',
#      'cara dapetin istri jepang',
#      'family vlog',
#      'kehidupan di jepang',
#      'keluarga bahagia',
#      'goal couple',
#      'keluarga lombok',
#      'kuta lombok mandalika',
#      'kisah hidup',
#      'motivasi hidup',
#      'perjuangan hidup',
#      'pernikahan beda budaya',
#      'nikah beda negara',
#      'international marriage',
#      'suami tangguh'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'SUASANA BERBUKA PUASA DI RUMAH BARU ! ADA MUSHALLA NYA 🥰',
#      'description': '.................\nSEDEKAH BERAS nya om/tante!\nhttps://trakteer.id/neojapan\n..........................................\nchannel PODCAST NEOJAPAN SOON ! https://www.youtube.com/channel/UCN4WWwEz1QMDg1Ua1tz7MEg\n\ninstagram NEOJAPAN_;  https://www.instagram.com/neojapan_/?hl=en\ninstagram Yusufkun ; https://www.instagram.com/yuu.kun21/?hl=en'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT15M35S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '227763',
#     'likeCount': '10702',
#     'favoriteCount': '0',
#     'commentCount': '621'}},
#   {'kind': 'youtube#video',
#    'etag': 'qIL4t-dt5PGa2CJ0cfsZKHenFVQ',
#    'id': 'zPkKNW0-JKQ',
#    'snippet': {'publishedAt': '2024-03-16T10:00:48Z',
#     'channelId': 'UC8rHUssNDJ9YEjfduAqJBmw',
#     'title': 'BUKA PUASA BANGKRUTIN RESTORAN ALL YOU CAN EAT LAGI !',
#     'description': 'The Social Pot Pondok Indah\n\nRT.1, Jl. Metro Pondok Indah No.1, RT.1/RW.16, Pondok Pinang, Kebayoran Lama, South Jakarta City, Jakarta 12310',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'tanboy kun',
#     'tags': ['tqnboy kun',
#      'mukbang',
#      'makan banyak',
#      'bangkrutin',
#      'restoran',
#      'daging',
#      'ayce',
#      'all you can eat'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'BUKA PUASA BANGKRUTIN RESTORAN ALL YOU CAN EAT LAGI !',
#      'description': 'The Social Pot Pondok Indah\n\nRT.1, Jl. Metro Pondok Indah No.1, RT.1/RW.16, Pondok Pinang, Kebayoran Lama, South Jakarta City, Jakarta 12310'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT28M54S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1142687',
#     'likeCount': '27507',
#     'favoriteCount': '0',
#     'commentCount': '1279'}},
#   {'kind': 'youtube#video',
#    'etag': 'oOkGdfl38tBsALgbmBf3jrKlNV4',
#    'id': 'q6w-STaQg28',
#    'snippet': {'publishedAt': '2024-03-16T07:20:20Z',
#     'channelId': 'UCirfI35e28WWuMITpWJlwhw',
#     'title': 'PERSIB BANDUNG LANJUTKAN TREN KEMENANGAN, PERSIKABO KENA COUNTER!',
#     'description': 'Review pertandingan Liga 1 antara Persikabo 1973 vs Persib Bandung yang berakhir untuk kemenangan Persib dengan skor 1-3',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Bola Bung Binder',
#     'tags': ['#persikabo1973vspersibbandung',
#      '#persibbandung',
#      '#persib',
#      '#bojanhodak',
#      '#stefanobeltrame',
#      '#daviddasilva',
#      '#ciroalves',
#      '#liga1',
#      '#ligaindonesia',
#      '#sepakbolaindonesia',
#      '#sepakbola',
#      '#indonesia'],
#     'categoryId': '17',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'id',
#     'localized': {'title': 'PERSIB BANDUNG LANJUTKAN TREN KEMENANGAN, PERSIKABO KENA COUNTER!',
#      'description': 'Review pertandingan Liga 1 antara Persikabo 1973 vs Persib Bandung yang berakhir untuk kemenangan Persib dengan skor 1-3'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT14M25S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '226910',
#     'likeCount': '18489',
#     'favoriteCount': '0',
#     'commentCount': '2779'}},
#   {'kind': 'youtube#video',
#    'etag': 'wVk6JHe1nSLIHCk0l8LOB2EuOTk',
#    'id': 'Ol5lscEcRZY',
#    'snippet': {'publishedAt': '2024-03-16T11:00:19Z',
#     'channelId': 'UCgf0wB6vPKlHldseTaqL77A',
#     'title': 'MERAYAKAN HARI PERTAMA DENGAN GULAI AYAM GRATIS UNTUK SEMUANYA YANG DI CHINA PADA HARI PUASA🥹💗',
#     'description': 'Shanty giok : https://shantidichina.com\n===============================\nDukung dan Support Kita terus ya guys!!\nInstagram : https://instagram.com/shanty3182\nTiktok : https://www.tiktok.com/@shantydichinatiktok\nFacebook : https://www.facebook.com/shanty521\nUntuk bisnis dan kerjasama :\nEmail : Christenaperrington5p110@gmail.com\nMakasih buat kalian yang selalu luangin waktu buat nonton video kita. Mohon dibantu comment, like dan subscribe ya!\nJika ada ide ataupun masukan jangan sungkan untuk komen ya guys.\nTerima kasih /// 谢谢你们\n#indonesia     \n#china',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'SHANTY DI CHINA',
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'id',
#     'localized': {'title': 'MERAYAKAN HARI PERTAMA DENGAN GULAI AYAM GRATIS UNTUK SEMUANYA YANG DI CHINA PADA HARI PUASA🥹💗',
#      'description': 'Shanty giok : https://shantidichina.com\n===============================\nDukung dan Support Kita terus ya guys!!\nInstagram : https://instagram.com/shanty3182\nTiktok : https://www.tiktok.com/@shantydichinatiktok\nFacebook : https://www.facebook.com/shanty521\nUntuk bisnis dan kerjasama :\nEmail : Christenaperrington5p110@gmail.com\nMakasih buat kalian yang selalu luangin waktu buat nonton video kita. Mohon dibantu comment, like dan subscribe ya!\nJika ada ide ataupun masukan jangan sungkan untuk komen ya guys.\nTerima kasih /// 谢谢你们\n#indonesia     \n#china'},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT37M12S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '926508',
#     'likeCount': '37753',
#     'favoriteCount': '0',
#     'commentCount': '3332'}},
#   {'kind': 'youtube#video',
#    'etag': 'FbrnaZkUmw4rM6juMiQ27Gb88M8',
#    'id': 'VJgsItSAJ8w',
#    'snippet': {'publishedAt': '2024-03-17T02:00:13Z',
#     'channelId': 'UCnKdt3zQHbCY_jdOu6QbAjg',
#     'title': 'BONGKAR OLEH2 /HARTA KARUN DARI INDONESIA KAYAK TOKO PINDAH ,ALHAMDULILAH PUNYA JAJAN LEBARAN',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Yanti Guixe family',
#     'tags': ['suami bule',
#      'keluarga bahagia',
#      'istri bule',
#      'yanti guixe family',
#      'mertua bule',
#      'keluarga bahagia di barcelona',
#      'pulang indonesia',
#      'pulang indonesia tanpa suami',
#      'bongkar',
#      'bongkar harta karun',
#      'bongkar oleh2'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'BONGKAR OLEH2 /HARTA KARUN DARI INDONESIA KAYAK TOKO PINDAH ,ALHAMDULILAH PUNYA JAJAN LEBARAN',
#      'description': ''},
#     'defaultAudioLanguage': 'id'},
#    'contentDetails': {'duration': 'PT29M10S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '276938',
#     'likeCount': '12365',
#     'favoriteCount': '0',
#     'commentCount': '786'}}],
#  'nextPageToken': 'CDIQAA',
#  'pageInfo': {'totalResults': 200, 'resultsPerPage': 50}}

# %% [markdown]
# If successful, this method returns a response body with the following structure:
# ```
# {
#   'kind': 'youtube#videoListResponse',
#   'etag': etag,
#   'items': [
#     video Resource
#   ],
#   'nextPageToken': string,
#   'pageInfo': {'totalResults': integer, 'resultsPerPage': integer},
# }
# ```

# %% [markdown]
# ## 3. Extract Videos from API Response
#
# Once we've sent our request, the next step is to get the videos from the response sent back by the API. This allows us to access all the important information about each video returned by the API, such as titles, descriptions, and view counts. This step is essential because it's how we actually get the data we're interested in from the API's response.

# %%
videos = response.get("items", [])
videos
# Out:
# [{'kind': 'youtube#video',
#   'etag': 'UExt0_tucgqtupl-u5nVKn8RPrI',
#   'id': '2bopnQpPwgI',
#   'snippet': {'publishedAt': '2024-03-17T18:49:27Z',
#    'channelId': 'UCViN2fPWI6zuZDXwn0O54xg',
#    'title': 'Manchester United 2-2 (4-3 aet) Liverpool | FA Cup 23/24 Match Highlights',
#    'description': 'Tonton liga-liga terbaik hanya di beIN SPORTS CONNECT: https://bein.onelink.me/bApY/beinYT \n\nSimak berita dan update menarik seputar liga terbaik dan beIN Sports Indonesia di semua sosial media:\n\nFacebook: https://www.facebook.com/beinsportsindonesia/\nTwitter: https://twitter.com/beinsportsid\nInstagram: https://www.instagram.com/beinsports.id/\nYouTube: https://www.youtube.com/c/beINSPORTSID',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'beIN SPORTS Indonesia',
#    'tags': ['FA Cup',
#     'Football',
#     'Highlights',
#     'Liverpool',
#     'Manchester United',
#     'Manchester United vs. Liverpool',
#     'Premier League',
#     'Soccer',
#     'Antony',
#     'Garnacho',
#     'Rashford',
#     'Amad Diallo',
#     'Hojlund',
#     'Salah',
#     'Elliot',
#     'macalister',
#     'FA Cup Highlights',
#     'Endo',
#     'Nunez',
#     'Onana'],
#    'categoryId': '17',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'Manchester United 2-2 (4-3 aet) Liverpool | FA Cup 23/24 Match Highlights',
#     'description': 'Tonton liga-liga terbaik hanya di beIN SPORTS CONNECT: https://bein.onelink.me/bApY/beinYT \n\nSimak berita dan update menarik seputar liga terbaik dan beIN Sports Indonesia di semua sosial media:\n\nFacebook: https://www.facebook.com/beinsportsindonesia/\nTwitter: https://twitter.com/beinsportsid\nInstagram: https://www.instagram.com/beinsports.id/\nYouTube: https://www.youtube.com/c/beINSPORTSID'}},
#   'contentDetails': {'duration': 'PT11M51S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'regionRestriction': {'allowed': ['ID', 'PH', 'TL']},
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '1817393',
#    'likeCount': '26262',
#    'favoriteCount': '0',
#    'commentCount': '3733'}},
#  {'kind': 'youtube#video',
#   'etag': 'rj7vdq132JrigwG5PToJTXNCJIo',
#   'id': 'jnJMc6053P0',
#   'snippet': {'publishedAt': '2024-03-17T03:00:07Z',
#    'channelId': 'UCEdO8A1SpMMF47LuGGV1nMQ',
#    'title': 'HAPPY ASMARA Feat. GILGA SAHID - MANOT | Feat. BINTANG FORTUNA (Official Music Video)',
#    'description': 'HAPPY ASMARA Feat GILGA SAHID - MANOT | Feat.BINTANG FORTUNA (Official Music Video)\n\nExecutive Producer : MUARA BINTANG\nMUSIC PRODUCTION\n\nTitle : Manot\nSongwriter : Gilga Sahid\nMusic By : Bintang Fortuna\nVocal : Happy Asmara Feat Gilga Sahid\nSupport By : HA Management\n\nLyric :\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nAku Sayang Koe, Tapi Koe Sayang Dek E\nLoro Atiku Mbok Sia Sia Ne \nKadung Nibo Nangi\nMerjuangne Kowe Kui \nNanging Nyatane Kowe Golek Pengganti\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nAku Pengene Ro Koweee\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\nMusic Video Playlist From Our Artists:\n♪ HAPPY ASMARA = https://youtube.com/playlist?list=PLx5WocVpsssWtgHHDBMcNSNFouwakJB4O\n♪ DIKE SABRINA =  https://youtube.com/playlist?list=PLx5WocVpsssW_hBLKmZkEfW1y3C5hMLT2\n♪ ROSYNTA DEWI =  https://youtube.com/playlist?list=PLx5WocVpsssVSZC0NBv9ptoweZsYQoG4s\n♪ VIA AMELIA = https://youtube.com/playlist?list=PLx5WocVpsssW_1AAL47-JOgV323whpLQl\n♪ DELVA IRAWAN = https://youtube.com/playlist?list=PLx5WocVpsssVgWeZlmlGz_rSj8yeAQWm4\n♪ YENI INKA  = https://youtube.com/playlist?list=PLx5WocVpsssX_3G4cn4tmfCmAZ2s3ZeG5\n♪ SHEPIN MISA  = https://youtube.com/playlist?list=PLx5WocVpsssUrEi-TUykU2Gvv5d7LdYVO\n♪ WORO WIDOWATI = https://youtube.com/playlist?list=PLx5WocVpsssVO9yjGayi2838twOwAIMoB\n♪ ARNETA YULIA =  https://youtube.com/playlist?list=PLx5WocVpsssXm8cAc3zefpSpADb9NIgtT\n♪ DAMARA DE = https://youtube.com/playlist?list=PLx5WocVpsssW8GluGDcbignRsYoxzDz9r\n♪ PUTRI KRISTYA = https://youtube.com/playlist?list=PLx5WocVpsssUZjCu1L7J3DpE48OAa8TQ5\n♪ LALA WIDY = https://youtube.com/playlist?list=PLx5WocVpsssUuM3MCwdeo48-Jc9Oe53KW\n♪ JIHAN AUDY =  https://youtube.com/playlist?list=PLx5WocVpsssVkZAGR5koEhaNgOZC6M9MZ\n♪ RATNA ANTIKA  = https://youtube.com/playlist?list=PLx5WocVpsssWN7hnGCuMV7ZaQHzosHAEo\n♪ TASYA ROSMALA = https://youtube.com/playlist?list=PLx5WocVpsssWc8t975YTIj1cXHuW9FNy8\n♪ BRODIN = https://youtube.com/playlist?list=PLx5WocVpsssWHqGTLuUO8r4DuHSNej87c\n♪ NEO SARI = https://youtube.com/playlist?list=PLx5WocVpsssVGLpfEMCzsKqCQa096Y32u\n♪ YUNI VEBRA =  https://youtube.com/playlist?list=PLx5WocVpsssX9hhfqWNfv-pKnzWo322zv\n♪ FIRA AZZAHRA = https://youtube.com/playlist?list=PLx5WocVpsssX9358s1rtR0IdX-yrazxE1\n♪ SALSA KIRANA = https://youtube.com/playlist?list=PLx5WocVpsssWF_lOEFU2VjflTiHPNf2s1\n♪ DUET = https://youtube.com/playlist?list=PLx5WocVpsssVfhUBrN_Rg2LgAS7KyzoUy\n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n\nContact our Management:\nTlp. : +62 857-3554-7777\n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n\nLicensed to YouTube by IDE (Music)\nThis channel & Video optimized by IDE Optimization\nLicense your music here: https://smarturl.id/idemusic\nOptimize your video now: https://smarturl.id/optimize\n\n#happyasmara #gilgasahid #manot #mb',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'MUARA BINTANG',
#    'tags': ['terpopuler',
#     'musik',
#     'beritaterkini',
#     'keroncong',
#     'campursari',
#     'orkesviral',
#     'thebastmusik',
#     'rajawali mitra',
#     'rajawali mitra musik',
#     'official video',
#     'trending',
#     'campursari koplo',
#     'anjawening',
#     'pangayu',
#     'cita citata',
#     'ayu ting ting',
#     'nella kharisma',
#     'perdana record',
#     'dd star',
#     'melady record',
#     'new arista',
#     'safari record',
#     'khatulistiwa record',
#     'sandi record',
#     'adella',
#     'adela',
#     'new pallapa',
#     'new palapa',
#     'via valen',
#     'aneka safari record',
#     'denny caknan',
#     'happy asmara music',
#     'gilga sahid',
#     'manot'],
#    'categoryId': '10',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'HAPPY ASMARA Feat. GILGA SAHID - MANOT | Feat. BINTANG FORTUNA (Official Music Video)',
#     'description': 'HAPPY ASMARA Feat GILGA SAHID - MANOT | Feat.BINTANG FORTUNA (Official Music Video)\n\nExecutive Producer : MUARA BINTANG\nMUSIC PRODUCTION\n\nTitle : Manot\nSongwriter : Gilga Sahid\nMusic By : Bintang Fortuna\nVocal : Happy Asmara Feat Gilga Sahid\nSupport By : HA Management\n\nLyric :\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nAku Sayang Koe, Tapi Koe Sayang Dek E\nLoro Atiku Mbok Sia Sia Ne \nKadung Nibo Nangi\nMerjuangne Kowe Kui \nNanging Nyatane Kowe Golek Pengganti\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nAku Pengene Ro Koweee\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\nMusic Video Playlist From Our Artists:\n♪ HAPPY ASMARA = https://youtube.com/playlist?list=PLx5WocVpsssWtgHHDBMcNSNFouwakJB4O\n♪ DIKE SABRINA =  https://youtube.com/playlist?list=PLx5WocVpsssW_hBLKmZkEfW1y3C5hMLT2\n♪ ROSYNTA DEWI =  https://youtube.com/playlist?list=PLx5WocVpsssVSZC0NBv9ptoweZsYQoG4s\n♪ VIA AMELIA = https://youtube.com/playlist?list=PLx5WocVpsssW_1AAL47-JOgV323whpLQl\n♪ DELVA IRAWAN = https://youtube.com/playlist?list=PLx5WocVpsssVgWeZlmlGz_rSj8yeAQWm4\n♪ YENI INKA  = https://youtube.com/playlist?list=PLx5WocVpsssX_3G4cn4tmfCmAZ2s3ZeG5\n♪ SHEPIN MISA  = https://youtube.com/playlist?list=PLx5WocVpsssUrEi-TUykU2Gvv5d7LdYVO\n♪ WORO WIDOWATI = https://youtube.com/playlist?list=PLx5WocVpsssVO9yjGayi2838twOwAIMoB\n♪ ARNETA YULIA =  https://youtube.com/playlist?list=PLx5WocVpsssXm8cAc3zefpSpADb9NIgtT\n♪ DAMARA DE = https://youtube.com/playlist?list=PLx5WocVpsssW8GluGDcbignRsYoxzDz9r\n♪ PUTRI KRISTYA = https://youtube.com/playlist?list=PLx5WocVpsssUZjCu1L7J3DpE48OAa8TQ5\n♪ LALA WIDY = https://youtube.com/playlist?list=PLx5WocVpsssUuM3MCwdeo48-Jc9Oe53KW\n♪ JIHAN AUDY =  https://youtube.com/playlist?list=PLx5WocVpsssVkZAGR5koEhaNgOZC6M9MZ\n♪ RATNA ANTIKA  = https://youtube.com/playlist?list=PLx5WocVpsssWN7hnGCuMV7ZaQHzosHAEo\n♪ TASYA ROSMALA = https://youtube.com/playlist?list=PLx5WocVpsssWc8t975YTIj1cXHuW9FNy8\n♪ BRODIN = https://youtube.com/playlist?list=PLx5WocVpsssWHqGTLuUO8r4DuHSNej87c\n♪ NEO SARI = https://youtube.com/playlist?list=PLx5WocVpsssVGLpfEMCzsKqCQa096Y32u\n♪ YUNI VEBRA =  https://youtube.com/playlist?list=PLx5WocVpsssX9hhfqWNfv-pKnzWo322zv\n♪ FIRA AZZAHRA = https://youtube.com/playlist?list=PLx5WocVpsssX9358s1rtR0IdX-yrazxE1\n♪ SALSA KIRANA = https://youtube.com/playlist?list=PLx5WocVpsssWF_lOEFU2VjflTiHPNf2s1\n♪ DUET = https://youtube.com/playlist?list=PLx5WocVpsssVfhUBrN_Rg2LgAS7KyzoUy\n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n\nContact our Management:\nTlp. : +62 857-3554-7777\n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n\nLicensed to YouTube by IDE (Music)\nThis channel & Video optimized by IDE Optimization\nLicense your music here: https://smarturl.id/idemusic\nOptimize your video now: https://smarturl.id/optimize\n\n#happyasmara #gilgasahid #manot #mb'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT6M34S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'true',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '2009661',
#    'likeCount': '216448',
#    'favoriteCount': '0',
#    'commentCount': '38871'}},
#  {'kind': 'youtube#video',
#   'etag': 'G-ITehO-X3Ya2uorMxUUCNBv7vg',
#   'id': 'Ra0AhAkYDho',
#   'snippet': {'publishedAt': '2024-03-18T12:00:22Z',
#    'channelId': 'UCfpaSruWW3S4dibonKXENjA',
#    'title': '자카르타1탄) 인도네시아에서 신기록 세웠습니다🇲🇨 7500평 최대규모 식당에서 사테 xxx개 먹방',
#    'description': '#viral#Indonesia#jakarta#sate\n\n각국어 번역 자막 제작 : \n컨텐츠 제작의 마무리는 컨텐츠플라이! 글로벌 진출을 위한 최고의 파트너,\nCONTENTSFLY에서 제작되었습니다.\nhttps://www.contentsfly.com\n\n비지니스 메일:gardenm1120@gmail.com',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ra0AhAkYDho/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Ra0AhAkYDho/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Ra0AhAkYDho/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Ra0AhAkYDho/sddefault.jpg',
#      'width': 640,
#      'height': 480}},
#    'channelTitle': 'tzuyang쯔양',
#    'tags': ['real sound',
#     '리얼사운드',
#     'social eating',
#     'mukbang',
#     'eating show',
#     '먹방',
#     '맛집'],
#    'categoryId': '22',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'ko',
#    'localized': {'title': '자카르타1탄) 인도네시아에서 신기록 세웠습니다🇲🇨 7500평 최대규모 식당에서 사테 xxx개 먹방',
#     'description': '#viral#Indonesia#jakarta#sate\n\n각국어 번역 자막 제작 : \n컨텐츠 제작의 마무리는 컨텐츠플라이! 글로벌 진출을 위한 최고의 파트너,\nCONTENTSFLY에서 제작되었습니다.\nhttps://www.contentsfly.com\n\n비지니스 메일:gardenm1120@gmail.com'},
#    'defaultAudioLanguage': 'ko'},
#   'contentDetails': {'duration': 'PT23M28S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'true',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '586427',
#    'likeCount': '52071',
#    'favoriteCount': '0',
#    'commentCount': '5674'}},
#  {'kind': 'youtube#video',
#   'etag': 'OkgzMaDpWNT9ymbUZwkpl-3nkcM',
#   'id': 'qoU7RFMjE6I',
#   'snippet': {'publishedAt': '2024-03-17T16:35:08Z',
#    'channelId': 'UCl2y8_wNtI7N13fOinesLMA',
#    'title': 'Kiky Saputri dan Suami Buka Suara Terkait Kehamilannya',
#    'description': "Silakan komen di bawah 🖤 Kalian mau aku buat konten apa lagi?\n\nJangan lupa Subscribe nya ya : https://bit.ly/SubsKikySaputri\n\nInstagram : https://www.instagram.com/kikysaputrii\n\nKiky Saputri Official's Youtube is under management of:\ndr.m, Indonesia's 1st Certified & Official Youtube MCN\nhttps://servicesdirectory.withyoutube.com/directory/pt-digital-rantai-maya-drm",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Kiky Saputri Official',
#    'tags': ['kiki',
#     'kiky',
#     'kiki saputri',
#     'kiky saputri official',
#     'stand up comedy',
#     'comedy',
#     'komika',
#     'lucu',
#     'ngakak',
#     'hahaha corp',
#     'comedian',
#     'standup',
#     'komedi',
#     'kiky saputri',
#     'keguguran',
#     'kiky saputri keguguran',
#     'kiky saputri hamil',
#     'kiky saputri kehilangan buah hati',
#     'komika keguguran',
#     'bayi kiky saputri',
#     'anak kiky saputri'],
#    'categoryId': '24',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'Kiky Saputri dan Suami Buka Suara Terkait Kehamilannya',
#     'description': "Silakan komen di bawah 🖤 Kalian mau aku buat konten apa lagi?\n\nJangan lupa Subscribe nya ya : https://bit.ly/SubsKikySaputri\n\nInstagram : https://www.instagram.com/kikysaputrii\n\nKiky Saputri Official's Youtube is under management of:\ndr.m, Indonesia's 1st Certified & Official Youtube MCN\nhttps://servicesdirectory.withyoutube.com/directory/pt-digital-rantai-maya-drm"}},
#   'contentDetails': {'duration': 'PT26M52S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '411622',
#    'likeCount': '12263',
#    'favoriteCount': '0',
#    'commentCount': '2255'}},
#  {'kind': 'youtube#video',
#   'etag': '9VUtos_lkqPUkKmSpdY_od-9Itc',
#   'id': 'E-GvMpXXr1g',
#   'snippet': {'publishedAt': '2024-03-17T09:05:15Z',
#    'channelId': 'UCVAwRh03m3_1pZjRKvelomA',
#    'title': 'STUDY TOUR #25 - Serena Hilang',
#    'description': 'Yuk gabung dengan channel ini untuk mendapatkan akses ke berbagai keuntungan:\nhttps://www.youtube.com/channel/UCVAwRh03m3_1pZjRKvelomA/join\n\n\nMERCHANDISE Dasi Gantung \nShopee : https://shope.ee/501KQe83d4\n\nIni akun Dasi Gantung yang lain ya\nFacebook.     : https://www.facebook.com/profile.php?id=100066603937194\nTiktok   : https://vt.tiktok.com/ZSEXx5XV/\nInstagram : https://www.instagram.com/dasigantung/\nShopee Video : https://shopee.co.id/universal-link?redir=https%3A%2F%2Fshp.ee%2F9nidyp5&deep_and_deferred=1&smtt=0.0.9\nBstation   : https://bili.im/XXF4OcF\n\nDasi Gantung tidak punya akun sosial media selain diatas. Makasih banyak sudah support terus channel ini\xa0\n\nIni link game “Dimensi Lain Serena” tersedia di AppStore dan Play Store\nPlay Store :\nhttps://play.google.com/store/apps/details?id=com.arcadesindo.dimensilainserena\niOS (App Store) :\nhttps://apps.apple.com/id/app/dimensi-lain-serena/id1617391251?l=id\n\n#animasi #dasigantung #serena #monika #raki #ratara #animasisekolah #studytour',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Dasi Gantung',
#    'categoryId': '24',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'STUDY TOUR #25 - Serena Hilang',
#     'description': 'Yuk gabung dengan channel ini untuk mendapatkan akses ke berbagai keuntungan:\nhttps://www.youtube.com/channel/UCVAwRh03m3_1pZjRKvelomA/join\n\n\nMERCHANDISE Dasi Gantung \nShopee : https://shope.ee/501KQe83d4\n\nIni akun Dasi Gantung yang lain ya\nFacebook.     : https://www.facebook.com/profile.php?id=100066603937194\nTiktok   : https://vt.tiktok.com/ZSEXx5XV/\nInstagram : https://www.instagram.com/dasigantung/\nShopee Video : https://shopee.co.id/universal-link?redir=https%3A%2F%2Fshp.ee%2F9nidyp5&deep_and_deferred=1&smtt=0.0.9\nBstation   : https://bili.im/XXF4OcF\n\nDasi Gantung tidak punya akun sosial media selain diatas. Makasih banyak sudah support terus channel ini\xa0\n\nIni link game “Dimensi Lain Serena” tersedia di AppStore dan Play Store\nPlay Store :\nhttps://play.google.com/store/apps/details?id=com.arcadesindo.dimensilainserena\niOS (App Store) :\nhttps://apps.apple.com/id/app/dimensi-lain-serena/id1617391251?l=id\n\n#animasi #dasigantung #serena #monika #raki #ratara #animasisekolah #studytour'}},
#   'contentDetails': {'duration': 'PT5M30S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '452049',
#    'likeCount': '49439',
#    'favoriteCount': '0',
#    'commentCount': '3429'}},
#  {'kind': 'youtube#video',
#   'etag': 'YmOvHuH8bP-aEvknmpRvGpOE8nw',
#   'id': 'RZmO08bFgYA',
#   'snippet': {'publishedAt': '2024-03-18T13:49:11Z',
#    'channelId': 'UCA_fIuIBkjjO5IfK50Iqs7w',
#    'title': 'RAMADHAN LOVE STORY PART 1 - Animasi Sekolah',
#    'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Dhot Design',
#    'tags': ['dhot design',
#     'dhokona',
#     'animasi sekolah',
#     'animasi tentang sekolahan',
#     'animasi lucu sekolah',
#     'animasi tentang anak sekolah',
#     'animasi sekolah sma',
#     'animasi kocak bikin ngakak',
#     'animasi lucu anak sma',
#     'animasi sekolah indonesia',
#     'anime school',
#     'anime sekolahan',
#     'kartun lucu sekolah'],
#    'categoryId': '1',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'id',
#    'localized': {'title': 'RAMADHAN LOVE STORY PART 1 - Animasi Sekolah',
#     'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT5M31S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '1801057',
#    'likeCount': '107618',
#    'favoriteCount': '0',
#    'commentCount': '7361'}},
#  {'kind': 'youtube#video',
#   'etag': 'W_ygRhI-fHBSkzC9bS4wYWFoRiU',
#   'id': 'RowlrvmyFEk',
#   'snippet': {'publishedAt': '2024-03-18T09:00:07Z',
#    'channelId': 'UCaO6TYtlC8U5ttz62hTrZgg',
#    'title': 'DAY6(데이식스) "Welcome to the Show" M/V',
#    'description': 'DAY6(데이식스) "Welcome to the Show" M/V\r\n\nListen to DAY6 "Welcome to the Show" \nhttps://day6.lnk.to/fourever\n\nDAY6 Official YouTube: http://www.youtube.com/c/DAY6Official\nDAY6 Official Facebook: http://www.facebook.com/DAY6Official\nDAY6 Official Twitter: http://www.twitter.com/DAY6Official\nDAY6 FANS App Store : http://bit.ly/48OILIW\nDAY6 FANS Google Play : http://bit.ly/48tBxKE\nDAY6 Official Homepage: http://DAY6.jype.com\n\nCopyrights 2024 ⓒ JYP Entertainment. All Rights Reserved.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'JYP Entertainment',
#    'tags': ['JYP Entertainment',
#     'JYP',
#     'DAY6',
#     '데이식스',
#     'DAY6 Young K',
#     'DAY6 Sungjin',
#     'DAY6 Wonpil',
#     'DAY6 Dowoon',
#     'DAY6 영케이',
#     'DAY6 성진',
#     'DAY6 원필',
#     'DAY6 도운',
#     '데이식스 Young K',
#     '데이식스 영케이',
#     '데이식스 성진',
#     '데이식스 원필',
#     '데이식스 도운',
#     'Young K',
#     'Sungjin',
#     'Wonpil',
#     'Dowoon',
#     '영케이',
#     '성진',
#     '원필',
#     '도운',
#     'Fourever',
#     'Welcome to the Show'],
#    'categoryId': '10',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'en',
#    'localized': {'title': 'DAY6(데이식스) "Welcome to the Show" M/V',
#     'description': 'DAY6(데이식스) "Welcome to the Show" M/V\r\n\nListen to DAY6 "Welcome to the Show" \nhttps://day6.lnk.to/fourever\n\nDAY6 Official YouTube: http://www.youtube.com/c/DAY6Official\nDAY6 Official Facebook: http://www.facebook.com/DAY6Official\nDAY6 Official Twitter: http://www.twitter.com/DAY6Official\nDAY6 FANS App Store : http://bit.ly/48OILIW\nDAY6 FANS Google Play : http://bit.ly/48tBxKE\nDAY6 Official Homepage: http://DAY6.jype.com\n\nCopyrights 2024 ⓒ JYP Entertainment. All Rights Reserved.'},
#    'defaultAudioLanguage': 'ko'},
#   'contentDetails': {'duration': 'PT3M56S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'true',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '775938',
#    'likeCount': '65432',
#    'favoriteCount': '0',
#    'commentCount': '5184'}},
#  {'kind': 'youtube#video',
#   'etag': '4HPSY7_g_n0QOpddYX73qzMQRjY',
#   'id': 'oZD34dkfhNQ',
#   'snippet': {'publishedAt': '2024-03-18T11:00:50Z',
#    'channelId': 'UCXURHJRGr4-EB3l87kcbElw',
#    'title': 'No brake getting faster | 7llin’ with DREAM | EP. 3',
#    'description': '#7llin_with_DREAM #칠링윗드림\n#NCTDREAM #Smoothie\n#NCTDREAM_Smoothie\n\nNCT DREAM Official\nhttps://www.youtube.com/nctdream \nhttps://www.instagram.com/nct_dream/ \nhttps://www.tiktok.com/@official_nct\nhttps://twitter.com/NCTsmtown_DREAM \nhttps://www.facebook.com/NCT.smtown',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'NCT DREAM',
#    'tags': ['NCT DREAM',
#     '엔시티 드림',
#     'MARK',
#     'RENJUN',
#     'JENO',
#     'HAECHAN',
#     'JAEMIN',
#     'CHENLE',
#     'JISUNG',
#     '마크',
#     '런쥔',
#     '제노',
#     '해찬',
#     '재민',
#     '천러',
#     '지성'],
#    'categoryId': '10',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'No brake getting faster | 7llin’ with DREAM | EP. 3',
#     'description': '#7llin_with_DREAM #칠링윗드림\n#NCTDREAM #Smoothie\n#NCTDREAM_Smoothie\n\nNCT DREAM Official\nhttps://www.youtube.com/nctdream \nhttps://www.instagram.com/nct_dream/ \nhttps://www.tiktok.com/@official_nct\nhttps://twitter.com/NCTsmtown_DREAM \nhttps://www.facebook.com/NCT.smtown'},
#    'defaultAudioLanguage': 'ko'},
#   'contentDetails': {'duration': 'PT32M28S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'true',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '343564',
#    'likeCount': '51834',
#    'favoriteCount': '0',
#    'commentCount': '1344'}},
#  {'kind': 'youtube#video',
#   'etag': '1muPtSoa8gHdvw1hnXJXKm3D2jQ',
#   'id': 'yJTy6e62fU8',
#   'snippet': {'publishedAt': '2024-03-17T09:11:05Z',
#    'channelId': 'UCkzbfqQmXyAPY_XEsJvkcWg',
#    'title': 'CARA MEMBUAT MUSUH KESAL PART 38!!!',
#    'description': 'Follow Me on :\nemail : indrawijy08@gmail.com\nInstragram : https://www.instagram.com/gerradwijy08\nTiktok          : https://www.tiktok.com/@barbar_esport1.fb\n \n---------------------------------------------------------------------------------------------------------\nlike, Share, And Comment kalo lu suka, kalo ga suka ya gpp\n---------------------------------------------------------------------------------------------------------\n\n► CREDIT and USAGE\n\n✘ Title:  hyperfun\n✘ Music:  Kevin MacLeod \n✘ License: CC BY 3.0 (http://goo.gl/BlcHZR)\n✘ Download: http://incompetech.com/music/royalty-...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Gerrard Wijaya',
#    'tags': ['bug mlbb', 'gerrard wijaya', 'gerrad wijaya'],
#    'categoryId': '20',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'en-US',
#    'localized': {'title': 'CARA MEMBUAT MUSUH KESAL PART 38!!!',
#     'description': 'Follow Me on :\nemail : indrawijy08@gmail.com\nInstragram : https://www.instagram.com/gerradwijy08\nTiktok          : https://www.tiktok.com/@barbar_esport1.fb\n \n---------------------------------------------------------------------------------------------------------\nlike, Share, And Comment kalo lu suka, kalo ga suka ya gpp\n---------------------------------------------------------------------------------------------------------\n\n► CREDIT and USAGE\n\n✘ Title:  hyperfun\n✘ Music:  Kevin MacLeod \n✘ License: CC BY 3.0 (http://goo.gl/BlcHZR)\n✘ Download: http://incompetech.com/music/royalty-...'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT11M50S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '515746',
#    'likeCount': '21514',
#    'favoriteCount': '0',
#    'commentCount': '1447'}},
#  {'kind': 'youtube#video',
#   'etag': '-KjFKQ5rQ_kj2XXbazlO6Zi_aWM',
#   'id': 'mKdjycj-7eE',
#   'snippet': {'publishedAt': '2024-03-16T16:00:00Z',
#    'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#    'title': 'Stop This Train, Win a Lamborghini',
#    'description': 'I still can’t believe what happened in this video lol \nCheck out the mind-blowing Galaxy AI on the Samsung Galaxy S24 Ultra. Click this link to see for yourself: https://bit.ly/MrBeast_SamsungGalaxyS24\n\nPlay the Official Fortnite Creative Map For This Video Here:\nMrBeast Minigames 🎯 - 9466-1340-3054\nhttps://www.fortnite.com/@mrbeast/9466-1340-3054\n\nThanks to Daniel Schiffer for the Feastables ad! Go check him out here @danielschiffer \n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'MrBeast',
#    'categoryId': '24',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'en',
#    'localized': {'title': 'Stop This Train, Win a Lamborghini',
#     'description': 'I still can’t believe what happened in this video lol \nCheck out the mind-blowing Galaxy AI on the Samsung Galaxy S24 Ultra. Click this link to see for yourself: https://bit.ly/MrBeast_SamsungGalaxyS24\n\nPlay the Official Fortnite Creative Map For This Video Here:\nMrBeast Minigames 🎯 - 9466-1340-3054\nhttps://www.fortnite.com/@mrbeast/9466-1340-3054\n\nThanks to Daniel Schiffer for the Feastables ad! Go check him out here @danielschiffer \n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------'},
#    'defaultAudioLanguage': 'en'},
#   'contentDetails': {'duration': 'PT18M53S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'true',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '61606521',
#    'likeCount': '3170076',
#    'favoriteCount': '0',
#    'commentCount': '96375'}},
#  {'kind': 'youtube#video',
#   'etag': 'EcWP2m2KeLtPXx0ESOZh846BblA',
#   'id': 'l90gs0-gcjo',
#   'snippet': {'publishedAt': '2024-03-17T22:26:55Z',
#    'channelId': 'UC14UlmYlSNiQCBe9Eookf_A',
#    'title': 'ATLETICO DE MADRID 0 vs 3 FC BARCELONA | LALIGA 2023/24 MD29',
#    'description': "Goals from João Félix, Lewandowski and Fermín inflict a first home defeat of the season in the league on Atlético.\n\nSUBSCRIBE NOW:\n▶ https://www.youtube.com/user/fcbarcelona \n\n⚽ BARÇATV+: http://barca.link/wT1w30qMyQO\u200b\n💎 Official Culers Membership: http://barca.link/plXS30rAhfC\u200b\n🌐 Site: http://www.fcbarcelona.com\n📱 App: https://go.onelink.me/xndC/DownloadAppYouTube\n\n🔵 Facebook: http://www.facebook.com/fcbarcelona\n📸 Instagram: http://www.instagram.com/fcbarcelona\n𝕏 Twitter: http://twitter.com/FCBarcelona\n🎶 Tiktok: https://www.tiktok.com/@fcbarcelona \n👾 Discord: https://discord.gg/fcbarcelonaofficial\n\n🛍 Get all official Barça apparel from FC Barcelona's online store: http://barca.link/j8QH30qQh4Y \n🔵🔴 #FCBarcelona",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'FC Barcelona',
#    'tags': ['FC Barcelona',
#     'برشلونة،',
#     'Fútbol',
#     'FUTBOL',
#     'soccer',
#     'FUTEBOL',
#     'Sepakbola',
#     'サッカー',
#     'كرة القدم',
#     'football',
#     'FCB',
#     'Barça',
#     'Sport',
#     'Club',
#     'Barcelona',
#     'CAMP NOU',
#     'ter stegen',
#     'pique',
#     'busquets',
#     'goat',
#     'dembele',
#     'yt:cc=on',
#     'ansu fati',
#     'pedri',
#     'de Jong',
#     'Kun Agüero',
#     'Aguero',
#     'lewandowski',
#     'spotify',
#     'kounde',
#     'Joao Felix',
#     'Joao Cancelo',
#     'Gavi',
#     'Marcos Alonso',
#     'Lamine Yamal',
#     'Balde',
#     'Lewy',
#     'Lewandowski',
#     'Marc Guiu',
#     'Atletico Madrid',
#     'Highlights',
#     'Resumen',
#     'Resum',
#     'Civitas',
#     'Metropolitano',
#     'Cholo',
#     'Simeone',
#     'Griezmann',
#     'Cubarsí'],
#    'categoryId': '17',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'en',
#    'localized': {'title': 'ATLETICO DE MADRID 0 vs 3 FC BARCELONA | LALIGA 2023/24 MD29',
#     'description': "Goals from João Félix, Lewandowski and Fermín inflict a first home defeat of the season in the league on Atlético.\n\nSUBSCRIBE NOW:\n▶ https://www.youtube.com/user/fcbarcelona \n\n⚽ BARÇATV+: http://barca.link/wT1w30qMyQO\u200b\n💎 Official Culers Membership: http://barca.link/plXS30rAhfC\u200b\n🌐 Site: http://www.fcbarcelona.com\n📱 App: https://go.onelink.me/xndC/DownloadAppYouTube\n\n🔵 Facebook: http://www.facebook.com/fcbarcelona\n📸 Instagram: http://www.instagram.com/fcbarcelona\n𝕏 Twitter: http://twitter.com/FCBarcelona\n🎶 Tiktok: https://www.tiktok.com/@fcbarcelona \n👾 Discord: https://discord.gg/fcbarcelonaofficial\n\n🛍 Get all official Barça apparel from FC Barcelona's online store: http://barca.link/j8QH30qQh4Y \n🔵🔴 #FCBarcelona"},
#    'defaultAudioLanguage': 'en'},
#   'contentDetails': {'duration': 'PT3M26S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '1409583',
#    'likeCount': '57468',
#    'favoriteCount': '0',
#    'commentCount': '1530'}},
#  {'kind': 'youtube#video',
#   'etag': 'KQMiiKBzq211yN1qbEeFF7tYbbw',
#   'id': 'V49w-6ZrUQw',
#   'snippet': {'publishedAt': '2024-03-18T05:08:24Z',
#    'channelId': 'UCXXXH-_5wCkVdOLq-hRU6rQ',
#    'title': 'AKHIRNYA KONTRAKSI DAN HARUS CEPAT KE RUMAH SAKIT,  DETIK DETIK LAHIRAN ANAK KEDUA DI CHINA',
#    'description': "#pernikahancampuran #indonesia   #china #desaterpencil #indonesianfood #jualanmakanan \nASSALAMUALAIKUM WRB.\n\nHalo teman-teman kembali lagi di channel YouTube DAILY TIKA WEIXUN DICHINA\nsaya TIKA warga Indonesia yg menikah dengan Warga Tiongkok yg Bernama LIANG WEIXUN kami memiliki anak PERTAMA Yg bernama CHINA LIANG ZHEYU.Nama Indonesia anak kami adalaha MUHAMMAD ABIL SHIDQI \n\nKami memiliki keluarga besar  yg hangat saling toleransi dan selalu menerima perbedaan semua keluarga kami sangat baik \n\nsebelumnya TERIMAKASIH BANYAK atas komentar baik kalian dan kami meminta maaf sebesar besarnya kalau komentar Dari teman teman KAMI belum bisa balas satu-satu 🙏SEMOGA teman teman mengerti Dengan keadaan dan kesibukan kami membuat video setiap hari  untuk menghibur kalian. \nTerima kasih untuk yang sudah komentar memberikan do'a support dan dukungan pada kami.Terima kasih atas saran masukan dan juga tman-teman \nTeman-teman\n\nyuuuk ikutin  keseruan kami divideo kali ini   dari awal sampai habis jangan di-skip \nsemoga kalian suka dengan video kali ini yaaah ...\n\nuntuk teman teman yang baru gabung selamat bergabung di channel kami semoga betah yah dan jangan bosan bosan hehehehe😘\nuntuk teman teman yang belum subscribe,yuuk disubscribe channel ini bantu like dan koment juga yaaah bila perlu di share hehehe\nterimakasih banyak semuanya sudah meluangkan waktunya untuk menonton video Dari kami we love you all\nlangsung nonton yuuuk \njangan di skip skip yaaah teman teman 😚😉😉\n\njangan lupa follow juga ig kami yaaah teman teman\n@tika_weixun02\nhttps://instagram.com/tika_weixun02",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'DAILY TIKA WEIXUN DI CHINA',
#    'categoryId': '22',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'id',
#    'localized': {'title': 'AKHIRNYA KONTRAKSI DAN HARUS CEPAT KE RUMAH SAKIT,  DETIK DETIK LAHIRAN ANAK KEDUA DI CHINA',
#     'description': "#pernikahancampuran #indonesia   #china #desaterpencil #indonesianfood #jualanmakanan \nASSALAMUALAIKUM WRB.\n\nHalo teman-teman kembali lagi di channel YouTube DAILY TIKA WEIXUN DICHINA\nsaya TIKA warga Indonesia yg menikah dengan Warga Tiongkok yg Bernama LIANG WEIXUN kami memiliki anak PERTAMA Yg bernama CHINA LIANG ZHEYU.Nama Indonesia anak kami adalaha MUHAMMAD ABIL SHIDQI \n\nKami memiliki keluarga besar  yg hangat saling toleransi dan selalu menerima perbedaan semua keluarga kami sangat baik \n\nsebelumnya TERIMAKASIH BANYAK atas komentar baik kalian dan kami meminta maaf sebesar besarnya kalau komentar Dari teman teman KAMI belum bisa balas satu-satu 🙏SEMOGA teman teman mengerti Dengan keadaan dan kesibukan kami membuat video setiap hari  untuk menghibur kalian. \nTerima kasih untuk yang sudah komentar memberikan do'a support dan dukungan pada kami.Terima kasih atas saran masukan dan juga tman-teman \nTeman-teman\n\nyuuuk ikutin  keseruan kami divideo kali ini   dari awal sampai habis jangan di-skip \nsemoga kalian suka dengan video kali ini yaaah ...\n\nuntuk teman teman yang baru gabung selamat bergabung di channel kami semoga betah yah dan jangan bosan bosan hehehehe😘\nuntuk teman teman yang belum subscribe,yuuk disubscribe channel ini bantu like dan koment juga yaaah bila perlu di share hehehe\nterimakasih banyak semuanya sudah meluangkan waktunya untuk menonton video Dari kami we love you all\nlangsung nonton yuuuk \njangan di skip skip yaaah teman teman 😚😉😉\n\njangan lupa follow juga ig kami yaaah teman teman\n@tika_weixun02\nhttps://instagram.com/tika_weixun02"},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT20M32S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '406239',
#    'likeCount': '25432',
#    'favoriteCount': '0',
#    'commentCount': '2981'}},
#  {'kind': 'youtube#video',
#   'etag': '6NeC0OvGwGxcTaTmrfB8LVSPUQ8',
#   'id': 'DwZvETHRNT8',
#   'snippet': {'publishedAt': '2024-03-17T11:30:05Z',
#    'channelId': 'UCuVxJ829ysWH2OhZJiWdnbg',
#    'title': 'MONVLOG - NYARI TAKJIL BUAT BUKA PUASA!',
#    'description': 'Yuk gabung jadi member channel youtube aku melalui link ini:\nhttps://www.youtube.com/channel/UCuVxJ829ysWH2OhZJiWdnbg/join\n\nTempat Topup Para Juara:\nhttps://lemontopup.id/\n\nRamein Discord nya yuk!\nhttps://discord.gg/srwdEWE6c4\n\nJangan lupa follow aku ya :\n👉 https://instagram.com/ikhsan_lemon\n\nBussines : 0811-1993-0001\nEmail: business@teamrrq.com',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'RRQ Lemon',
#    'tags': ['lemon',
#     'rrq lemon',
#     'lemon rrq',
#     'team rrq',
#     'rrq hoshi',
#     'mobile legends'],
#    'categoryId': '20',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'MONVLOG - NYARI TAKJIL BUAT BUKA PUASA!',
#     'description': 'Yuk gabung jadi member channel youtube aku melalui link ini:\nhttps://www.youtube.com/channel/UCuVxJ829ysWH2OhZJiWdnbg/join\n\nTempat Topup Para Juara:\nhttps://lemontopup.id/\n\nRamein Discord nya yuk!\nhttps://discord.gg/srwdEWE6c4\n\nJangan lupa follow aku ya :\n👉 https://instagram.com/ikhsan_lemon\n\nBussines : 0811-1993-0001\nEmail: business@teamrrq.com'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT12M6S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '459531',
#    'likeCount': '41146',
#    'favoriteCount': '0',
#    'commentCount': '4084'}},
#  {'kind': 'youtube#video',
#   'etag': '9qE0SixoSIgFB9XKl6yp6v7pUx4',
#   'id': 'zji-gXontsM',
#   'snippet': {'publishedAt': '2024-03-17T20:00:21Z',
#    'channelId': 'UCu3Oq_wEChEPaV7abgY688g',
#    'title': 'MIC CHECK ALTER EGO VS EVOS | WEEK 1 - DAY 1 | MPL SEASON 13',
#    'description': 'Hai Champs!!\n\nMic check Alter Ego vs Evos\nMPL Season 13\nWeek 1 - Day 1\n\nDon’t forget to like, comment, subscribe and turn on the notification for our latest contents. Keep supporting us on our upcoming tournaments also, champs! \n\n=========================================== \n\nAlter Ego Esports Social Media:\nInstagram : https://www.instagram.com/alteregoesports/\nFacebook: https://www.facebook.com/alteregoesportsid\nTiktok: https://www.tiktok.com/@alterego.esports\nTwitter: https://twitter.com/AlterEgo_IDN\nYoutube: https://www.youtube.com/@AlterEgoEsports\n\nAlter Ego PUBG Mobile Social Media:\nInstagram: https://www.instagram.com/alteregopubgmobile/\nFacebook: https://www.facebook.com/alteregopubgmobile\nTiktok: https://www.tiktok.com/@alteregopubgmobile\nYoutube: https://www.youtube.com/@alteregopubgmobile\n\nIf you want to buy our official merchandise, you can visit our official store below:\nShopee: https://shopee.co.id/alterego_merch\nTokopedia: https://www.tokopedia.com/alteregomerch \n\n#alteregoesports #alterchamps',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zji-gXontsM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/zji-gXontsM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
# ...
#     '#Dimar_Music',
#     '#AlipBaTa',
#     '#AlifGustakhiyat',
#     '#Fingerstyle'],
#    'categoryId': '10',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'Alip_Ba_Ta - Ibu (Fingerstyle Version)',
#     'description': 'Monggo dimidangetaken ugi tembang kulo dateng toko musik digital lintune\n\nSpotify : https://open.spotify.com/artist/6jV3Kyd4AEGrCCyLTGyikT\nItunes : https://music.apple.com/id/artist/alip-ba-ta/1533787470\nLangit Musik : https://www.langitmusik.co.id/new/artist/12093564\nDeezer : https://deezer.page.link/S3X8XVfChmKs2ahUA\n\n\n\nSocial Network \nTwitter : @AlifGustakhiyat https://twitter.com/AlifGustakhiyat\nInstagram : @alif_gustakhiyat https://www.instagram.com/alif_gustakhiyat/\nTikTok : @alif_gustakhiyat https://www.tiktok.com/@alif_gustakhiyat'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT4M8S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '356807',
#    'likeCount': '35606',
#    'favoriteCount': '0',
#    'commentCount': '3098'}},
#  {'kind': 'youtube#video',
#   'etag': 'q3A3X6sk224eQPRylSb8TqkOV50',
#   'id': 'EXZAHdkTP2I',
#   'snippet': {'publishedAt': '2024-03-15T11:58:44Z',
#    'channelId': 'UCA_fIuIBkjjO5IfK50Iqs7w',
#    'title': 'KONA GAK SAUR PART 1 - Animasi Sekolah',
#    'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Dhot Design',
#    'tags': ['dhot design',
#     'dhokona',
#     'animasi sekolah',
#     'animasi tentang sekolahan',
#     'animasi lucu sekolah',
#     'animasi tentang anak sekolah',
#     'animasi sekolah sma',
#     'animasi kocak bikin ngakak',
#     'animasi lucu anak sma',
#     'animasi sekolah indonesia',
#     'anime school',
#     'anime sekolahan',
#     'kartun lucu sekolah'],
#    'categoryId': '1',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'id',
#    'localized': {'title': 'KONA GAK SAUR PART 1 - Animasi Sekolah',
#     'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT8M5S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '4021625',
#    'likeCount': '221312',
#    'favoriteCount': '0',
#    'commentCount': '17893'}},
#  {'kind': 'youtube#video',
#   'etag': 'Ff2kN7MnR8DxBv3Io_ok8yxuESM',
#   'id': 'sQCskcSeKI4',
#   'snippet': {'publishedAt': '2024-03-16T08:59:48Z',
#    'channelId': 'UCVdxec6r85Cy45nL1wQKxrQ',
#    'title': 'SUASANA BERBUKA PUASA DI RUMAH BARU ! ADA MUSHALLA NYA 🥰',
#    'description': '.................\nSEDEKAH BERAS nya om/tante!\nhttps://trakteer.id/neojapan\n..........................................\nchannel PODCAST NEOJAPAN SOON ! https://www.youtube.com/channel/UCN4WWwEz1QMDg1Ua1tz7MEg\n\ninstagram NEOJAPAN_;  https://www.instagram.com/neojapan_/?hl=en\ninstagram Yusufkun ; https://www.instagram.com/yuu.kun21/?hl=en',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Neo Japan',
#    'tags': ['Neo Japan',
#     'cewe jepang',
#     'cewek jepang',
#     'reaksi orang jepang',
#     'reaksi cewe jepang',
#     'reaksi cewek jepang',
#     'kimochi',
#     'dedek jepang gemes',
#     'cewe jepang malu-malu',
#     'lombok',
#     'surfer',
#     'istri jepang',
#     'cara taklukin cewe jepang',
#     'cara dapetin istri jepang',
#     'family vlog',
#     'kehidupan di jepang',
#     'keluarga bahagia',
#     'goal couple',
#     'keluarga lombok',
#     'kuta lombok mandalika',
#     'kisah hidup',
#     'motivasi hidup',
#     'perjuangan hidup',
#     'pernikahan beda budaya',
#     'nikah beda negara',
#     'international marriage',
#     'suami tangguh'],
#    'categoryId': '22',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'SUASANA BERBUKA PUASA DI RUMAH BARU ! ADA MUSHALLA NYA 🥰',
#     'description': '.................\nSEDEKAH BERAS nya om/tante!\nhttps://trakteer.id/neojapan\n..........................................\nchannel PODCAST NEOJAPAN SOON ! https://www.youtube.com/channel/UCN4WWwEz1QMDg1Ua1tz7MEg\n\ninstagram NEOJAPAN_;  https://www.instagram.com/neojapan_/?hl=en\ninstagram Yusufkun ; https://www.instagram.com/yuu.kun21/?hl=en'},
#    'defaultAudioLanguage': 'en'},
#   'contentDetails': {'duration': 'PT15M35S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '227763',
#    'likeCount': '10702',
#    'favoriteCount': '0',
#    'commentCount': '621'}},
#  {'kind': 'youtube#video',
#   'etag': 'qIL4t-dt5PGa2CJ0cfsZKHenFVQ',
#   'id': 'zPkKNW0-JKQ',
#   'snippet': {'publishedAt': '2024-03-16T10:00:48Z',
#    'channelId': 'UC8rHUssNDJ9YEjfduAqJBmw',
#    'title': 'BUKA PUASA BANGKRUTIN RESTORAN ALL YOU CAN EAT LAGI !',
#    'description': 'The Social Pot Pondok Indah\n\nRT.1, Jl. Metro Pondok Indah No.1, RT.1/RW.16, Pondok Pinang, Kebayoran Lama, South Jakarta City, Jakarta 12310',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'tanboy kun',
#    'tags': ['tqnboy kun',
#     'mukbang',
#     'makan banyak',
#     'bangkrutin',
#     'restoran',
#     'daging',
#     'ayce',
#     'all you can eat'],
#    'categoryId': '24',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'BUKA PUASA BANGKRUTIN RESTORAN ALL YOU CAN EAT LAGI !',
#     'description': 'The Social Pot Pondok Indah\n\nRT.1, Jl. Metro Pondok Indah No.1, RT.1/RW.16, Pondok Pinang, Kebayoran Lama, South Jakarta City, Jakarta 12310'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT28M54S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '1142687',
#    'likeCount': '27507',
#    'favoriteCount': '0',
#    'commentCount': '1279'}},
#  {'kind': 'youtube#video',
#   'etag': 'oOkGdfl38tBsALgbmBf3jrKlNV4',
#   'id': 'q6w-STaQg28',
#   'snippet': {'publishedAt': '2024-03-16T07:20:20Z',
#    'channelId': 'UCirfI35e28WWuMITpWJlwhw',
#    'title': 'PERSIB BANDUNG LANJUTKAN TREN KEMENANGAN, PERSIKABO KENA COUNTER!',
#    'description': 'Review pertandingan Liga 1 antara Persikabo 1973 vs Persib Bandung yang berakhir untuk kemenangan Persib dengan skor 1-3',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Bola Bung Binder',
#    'tags': ['#persikabo1973vspersibbandung',
#     '#persibbandung',
#     '#persib',
#     '#bojanhodak',
#     '#stefanobeltrame',
#     '#daviddasilva',
#     '#ciroalves',
#     '#liga1',
#     '#ligaindonesia',
#     '#sepakbolaindonesia',
#     '#sepakbola',
#     '#indonesia'],
#    'categoryId': '17',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'id',
#    'localized': {'title': 'PERSIB BANDUNG LANJUTKAN TREN KEMENANGAN, PERSIKABO KENA COUNTER!',
#     'description': 'Review pertandingan Liga 1 antara Persikabo 1973 vs Persib Bandung yang berakhir untuk kemenangan Persib dengan skor 1-3'},
#    'defaultAudioLanguage': 'en'},
#   'contentDetails': {'duration': 'PT14M25S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '226910',
#    'likeCount': '18489',
#    'favoriteCount': '0',
#    'commentCount': '2779'}},
#  {'kind': 'youtube#video',
#   'etag': 'wVk6JHe1nSLIHCk0l8LOB2EuOTk',
#   'id': 'Ol5lscEcRZY',
#   'snippet': {'publishedAt': '2024-03-16T11:00:19Z',
#    'channelId': 'UCgf0wB6vPKlHldseTaqL77A',
#    'title': 'MERAYAKAN HARI PERTAMA DENGAN GULAI AYAM GRATIS UNTUK SEMUANYA YANG DI CHINA PADA HARI PUASA🥹💗',
#    'description': 'Shanty giok : https://shantidichina.com\n===============================\nDukung dan Support Kita terus ya guys!!\nInstagram : https://instagram.com/shanty3182\nTiktok : https://www.tiktok.com/@shantydichinatiktok\nFacebook : https://www.facebook.com/shanty521\nUntuk bisnis dan kerjasama :\nEmail : Christenaperrington5p110@gmail.com\nMakasih buat kalian yang selalu luangin waktu buat nonton video kita. Mohon dibantu comment, like dan subscribe ya!\nJika ada ide ataupun masukan jangan sungkan untuk komen ya guys.\nTerima kasih /// 谢谢你们\n#indonesia     \n#china',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'SHANTY DI CHINA',
#    'categoryId': '22',
#    'liveBroadcastContent': 'none',
#    'defaultLanguage': 'id',
#    'localized': {'title': 'MERAYAKAN HARI PERTAMA DENGAN GULAI AYAM GRATIS UNTUK SEMUANYA YANG DI CHINA PADA HARI PUASA🥹💗',
#     'description': 'Shanty giok : https://shantidichina.com\n===============================\nDukung dan Support Kita terus ya guys!!\nInstagram : https://instagram.com/shanty3182\nTiktok : https://www.tiktok.com/@shantydichinatiktok\nFacebook : https://www.facebook.com/shanty521\nUntuk bisnis dan kerjasama :\nEmail : Christenaperrington5p110@gmail.com\nMakasih buat kalian yang selalu luangin waktu buat nonton video kita. Mohon dibantu comment, like dan subscribe ya!\nJika ada ide ataupun masukan jangan sungkan untuk komen ya guys.\nTerima kasih /// 谢谢你们\n#indonesia     \n#china'},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT37M12S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '926508',
#    'likeCount': '37753',
#    'favoriteCount': '0',
#    'commentCount': '3332'}},
#  {'kind': 'youtube#video',
#   'etag': 'FbrnaZkUmw4rM6juMiQ27Gb88M8',
#   'id': 'VJgsItSAJ8w',
#   'snippet': {'publishedAt': '2024-03-17T02:00:13Z',
#    'channelId': 'UCnKdt3zQHbCY_jdOu6QbAjg',
#    'title': 'BONGKAR OLEH2 /HARTA KARUN DARI INDONESIA KAYAK TOKO PINDAH ,ALHAMDULILAH PUNYA JAJAN LEBARAN',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Yanti Guixe family',
#    'tags': ['suami bule',
#     'keluarga bahagia',
#     'istri bule',
#     'yanti guixe family',
#     'mertua bule',
#     'keluarga bahagia di barcelona',
#     'pulang indonesia',
#     'pulang indonesia tanpa suami',
#     'bongkar',
#     'bongkar harta karun',
#     'bongkar oleh2'],
#    'categoryId': '22',
#    'liveBroadcastContent': 'none',
#    'localized': {'title': 'BONGKAR OLEH2 /HARTA KARUN DARI INDONESIA KAYAK TOKO PINDAH ,ALHAMDULILAH PUNYA JAJAN LEBARAN',
#     'description': ''},
#    'defaultAudioLanguage': 'id'},
#   'contentDetails': {'duration': 'PT29M10S',
#    'dimension': '2d',
#    'definition': 'hd',
#    'caption': 'false',
#    'licensedContent': True,
#    'contentRating': {},
#    'projection': 'rectangular'},
#   'statistics': {'viewCount': '276938',
#    'likeCount': '12365',
#    'favoriteCount': '0',
#    'commentCount': '786'}}]

# %% [markdown]
# The code `response.get('items', [])` is typically used in Python to retrieve a value associated with the key 'items'.

# %% [markdown]
# ## 4. Processing the Extracted Videos
#
# ### a) Basic Processing for Extracting Video Data
#
# Now that we've obtained the videos from the API response, we can proceed to process them according to our requirements. This processing step involves extracting relevant information from each video or presenting them to the user in a suitable format.

# %%
# iterates through the first five video.
for video in videos[:5]:
    title = video["snippet"]["title"]  # extract video's title
    published_at = video["snippet"]["publishedAt"]  # extract video's publish date 
    view_count = video["statistics"]["viewCount"]  # extract video's view count 

    print(f"Title: {title}, Published At: {published_at}, Views: {view_count}")
# Out:
# Title: Manchester United 2-2 (4-3 aet) Liverpool | FA Cup 23/24 Match Highlights, Published At: 2024-03-17T18:49:27Z, Views: 1817393
# Title: HAPPY ASMARA Feat. GILGA SAHID - MANOT | Feat. BINTANG FORTUNA (Official Music Video), Published At: 2024-03-17T03:00:07Z, Views: 2009661
# Title: 자카르타1탄) 인도네시아에서 신기록 세웠습니다🇲🇨 7500평 최대규모 식당에서 사테 xxx개 먹방, Published At: 2024-03-18T12:00:22Z, Views: 586427
# Title: Kiky Saputri dan Suami Buka Suara Terkait Kehamilannya, Published At: 2024-03-17T16:35:08Z, Views: 411622
# Title: STUDY TOUR #25 - Serena Hilang, Published At: 2024-03-17T09:05:15Z, Views: 452049

# %% [markdown]
# In this code snippet, we iterate over each video in the `videos` list and extract specific details such as the title, publish date, and view count. These details can then be used for various purposes, such as analysis, reporting, or presentation to users.
#
# > However, it's important to note that the data fetched from each video may include more information beyond what is currently being printed.
#
# The first method above (basic processing) involves directly extracting specific details, such as the video title, publish date, and view count, from the 'video' object using individual assignments.
#
# > While suitable for basic extraction needs, this approach can become cumbersome as requirements become more complex.

# %% [markdown]
# ### b) Advanced Processing Techniques for Comprehensive Video Extraction

# %% [markdown]
# That's why, let's advance to extract more detailed information and append to a list (advanced approach)

# %% [markdown]
# #### Define Relevant Information to Extract

# %% [markdown]
# If the requirements are more complex or the details fetched are more numerous, the basic processing is not recommended. We need a method that allows for easier customization and scalability as new attributes can be added or modified without altering the code structure.
#
# Thus, we can use this advanced method which offers a structured approach by defining a dictionary, 'infos', which maps categories like 'snippet' and 'statistics' to desired attributes.
#
# - After that, by iterating through each category and extracting specified details, stored in a dictionary called 'video_details', this approach streamlines the extraction process and enhances code readability.

# %%
# define the relevant information to extract
infos = {
    'snippet': ['title', 'publishedAt', 'channelTitle'],
    'statistics': ['viewCount']
}

# %% [markdown]
# Expand the original `infos` dictionary into `complete_infos`, adding more attributes to ensure a thorough extraction of video data.

# %%
complete_infos = {
    'snippet':['title', 'publishedAt', 'channelTitle',
               'description', 'categoryId', 'defaultAudioLanguage', 'thumbnails'],
    'statistics':['viewCount', 'likeCount', 'commentCount'],
    'contentDetails':['duration']
}

# %% [markdown]
# With the advanced method, even as we add more information we want to fetch, there's no need to worry about longer code.

# %% [markdown]
# #### Loop Through `infos` to Get All Information

# %% [markdown]
# This loop iterates over different categories of information stored in the 'complete_infos' dictionary.

# %%
# loop through different categories of information
for key, value in complete_infos.items():
    print(f'key: {key} ||  value: {value}')
# Out:
# key: snippet ||  value: ['title', 'publishedAt', 'channelTitle', 'description', 'categoryId', 'defaultAudioLanguage', 'thumbnails']
# key: statistics ||  value: ['viewCount', 'likeCount', 'commentCount']
# key: contentDetails ||  value: ['duration']

# %% [markdown]
# Each info, represented by a key, corresponds to a list of specific details we want to extract from the videos.

# %% [markdown]
# #### Accessing Video Details

# %% [markdown]
# Within each category, the code iterates over the videos in the `videos` list. For each video, it initializes an empty dictionary called `video_details` to store its extracted details.

# %%
for video in videos:
    # for each video, it initializes an empty dictionary to store its details
    video_details = {}
    
    for key, value in complete_infos.items():
        for info in value:
            video_details[info] = video.get(key, {}).get(info)

# %% [markdown]
# Next, it loops through the specific details (`info`) listed under each category (`key`).
#
# Then, `video.get(key, {}).get(info)`: It accesses these details from the `video` object using the `get()` method. If a detail is not found, it defaults to an empty string.
#
# Those code same aim with:
#
# ```python
# if key in video and info in video[key]:
#     video_details[info] = video[key][info]
# else:
#     video_details[info] = None
# ```

# %% [markdown]
# #### Saving Extracted Details

# %% [markdown]
# ```python
# videos_list = []
#
# for video in videos:
#     # code: accessing video details
#     videos_list.append(video_details)
# ```

# %% [markdown]
# After extracting all the details for a video, the `video_details` dictionary containing these details is appended to the `videos_list`. This list will eventually contain dictionaries, each representing the extracted details of a single video.

# %% [markdown]
# Let's combine the code to the loop.

# %%
# initialize list to save videos data
videos_list = []

for video in videos:
    video_details = {}
    
    for key, value in complete_infos.items():
        for info in value:
            video_details[info] = video.get(key, {}).get(info)

    # saving extracted details
    videos_list.append(video_details)

# %%
videos_list
# Out:
# [{'title': 'Manchester United 2-2 (4-3 aet) Liverpool | FA Cup 23/24 Match Highlights',
#   'publishedAt': '2024-03-17T18:49:27Z',
#   'channelTitle': 'beIN SPORTS Indonesia',
#   'description': 'Tonton liga-liga terbaik hanya di beIN SPORTS CONNECT: https://bein.onelink.me/bApY/beinYT \n\nSimak berita dan update menarik seputar liga terbaik dan beIN Sports Indonesia di semua sosial media:\n\nFacebook: https://www.facebook.com/beinsportsindonesia/\nTwitter: https://twitter.com/beinsportsid\nInstagram: https://www.instagram.com/beinsports.id/\nYouTube: https://www.youtube.com/c/beINSPORTSID',
#   'categoryId': '17',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '1817393',
#   'likeCount': '26262',
#   'commentCount': '3733',
#   'duration': 'PT11M51S'},
#  {'title': 'HAPPY ASMARA Feat. GILGA SAHID - MANOT | Feat. BINTANG FORTUNA (Official Music Video)',
#   'publishedAt': '2024-03-17T03:00:07Z',
#   'channelTitle': 'MUARA BINTANG',
#   'description': 'HAPPY ASMARA Feat GILGA SAHID - MANOT | Feat.BINTANG FORTUNA (Official Music Video)\n\nExecutive Producer : MUARA BINTANG\nMUSIC PRODUCTION\n\nTitle : Manot\nSongwriter : Gilga Sahid\nMusic By : Bintang Fortuna\nVocal : Happy Asmara Feat Gilga Sahid\nSupport By : HA Management\n\nLyric :\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nAku Sayang Koe, Tapi Koe Sayang Dek E\nLoro Atiku Mbok Sia Sia Ne \nKadung Nibo Nangi\nMerjuangne Kowe Kui \nNanging Nyatane Kowe Golek Pengganti\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nAku Pengene Ro Koweee\n\nGetun Rasane, Wes Tak Upayakne \nGinio Kok Koyo Ngene Akhire \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nSedih Mbok Tinggal Lungo\nKarepku Yo Wes Rapopo\nNing Nyatane Saben Wengi\nAku Sek Kerep Ngimpeni \nIki Lagu Teko Ati Dudu Mung Crito Ngapusi\nJujur Tresnoku Seh Gedi\n\nTulung Ngertenono Aku Sayang\nTresnoku Tenanan Dudu \nMung Dinggo Dolanan\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\nSumpah Aku Seh Tresno Sliramu\nTapi Tresnomu Dudu Nggo Aku \n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\nMusic Video Playlist From Our Artists:\n♪ HAPPY ASMARA = https://youtube.com/playlist?list=PLx5WocVpsssWtgHHDBMcNSNFouwakJB4O\n♪ DIKE SABRINA =  https://youtube.com/playlist?list=PLx5WocVpsssW_hBLKmZkEfW1y3C5hMLT2\n♪ ROSYNTA DEWI =  https://youtube.com/playlist?list=PLx5WocVpsssVSZC0NBv9ptoweZsYQoG4s\n♪ VIA AMELIA = https://youtube.com/playlist?list=PLx5WocVpsssW_1AAL47-JOgV323whpLQl\n♪ DELVA IRAWAN = https://youtube.com/playlist?list=PLx5WocVpsssVgWeZlmlGz_rSj8yeAQWm4\n♪ YENI INKA  = https://youtube.com/playlist?list=PLx5WocVpsssX_3G4cn4tmfCmAZ2s3ZeG5\n♪ SHEPIN MISA  = https://youtube.com/playlist?list=PLx5WocVpsssUrEi-TUykU2Gvv5d7LdYVO\n♪ WORO WIDOWATI = https://youtube.com/playlist?list=PLx5WocVpsssVO9yjGayi2838twOwAIMoB\n♪ ARNETA YULIA =  https://youtube.com/playlist?list=PLx5WocVpsssXm8cAc3zefpSpADb9NIgtT\n♪ DAMARA DE = https://youtube.com/playlist?list=PLx5WocVpsssW8GluGDcbignRsYoxzDz9r\n♪ PUTRI KRISTYA = https://youtube.com/playlist?list=PLx5WocVpsssUZjCu1L7J3DpE48OAa8TQ5\n♪ LALA WIDY = https://youtube.com/playlist?list=PLx5WocVpsssUuM3MCwdeo48-Jc9Oe53KW\n♪ JIHAN AUDY =  https://youtube.com/playlist?list=PLx5WocVpsssVkZAGR5koEhaNgOZC6M9MZ\n♪ RATNA ANTIKA  = https://youtube.com/playlist?list=PLx5WocVpsssWN7hnGCuMV7ZaQHzosHAEo\n♪ TASYA ROSMALA = https://youtube.com/playlist?list=PLx5WocVpsssWc8t975YTIj1cXHuW9FNy8\n♪ BRODIN = https://youtube.com/playlist?list=PLx5WocVpsssWHqGTLuUO8r4DuHSNej87c\n♪ NEO SARI = https://youtube.com/playlist?list=PLx5WocVpsssVGLpfEMCzsKqCQa096Y32u\n♪ YUNI VEBRA =  https://youtube.com/playlist?list=PLx5WocVpsssX9hhfqWNfv-pKnzWo322zv\n♪ FIRA AZZAHRA = https://youtube.com/playlist?list=PLx5WocVpsssX9358s1rtR0IdX-yrazxE1\n♪ SALSA KIRANA = https://youtube.com/playlist?list=PLx5WocVpsssWF_lOEFU2VjflTiHPNf2s1\n♪ DUET = https://youtube.com/playlist?list=PLx5WocVpsssVfhUBrN_Rg2LgAS7KyzoUy\n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n\nContact our Management:\nTlp. : +62 857-3554-7777\n\n▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n\nLicensed to YouTube by IDE (Music)\nThis channel & Video optimized by IDE Optimization\nLicense your music here: https://smarturl.id/idemusic\nOptimize your video now: https://smarturl.id/optimize\n\n#happyasmara #gilgasahid #manot #mb',
#   'categoryId': '10',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/jnJMc6053P0/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '2009661',
#   'likeCount': '216448',
#   'commentCount': '38871',
#   'duration': 'PT6M34S'},
#  {'title': '자카르타1탄) 인도네시아에서 신기록 세웠습니다🇲🇨 7500평 최대규모 식당에서 사테 xxx개 먹방',
#   'publishedAt': '2024-03-18T12:00:22Z',
#   'channelTitle': 'tzuyang쯔양',
#   'description': '#viral#Indonesia#jakarta#sate\n\n각국어 번역 자막 제작 : \n컨텐츠 제작의 마무리는 컨텐츠플라이! 글로벌 진출을 위한 최고의 파트너,\nCONTENTSFLY에서 제작되었습니다.\nhttps://www.contentsfly.com\n\n비지니스 메일:gardenm1120@gmail.com',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'ko',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ra0AhAkYDho/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Ra0AhAkYDho/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Ra0AhAkYDho/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/Ra0AhAkYDho/sddefault.jpg',
#     'width': 640,
#     'height': 480}},
#   'viewCount': '586427',
#   'likeCount': '52071',
#   'commentCount': '5674',
#   'duration': 'PT23M28S'},
#  {'title': 'Kiky Saputri dan Suami Buka Suara Terkait Kehamilannya',
#   'publishedAt': '2024-03-17T16:35:08Z',
#   'channelTitle': 'Kiky Saputri Official',
#   'description': "Silakan komen di bawah 🖤 Kalian mau aku buat konten apa lagi?\n\nJangan lupa Subscribe nya ya : https://bit.ly/SubsKikySaputri\n\nInstagram : https://www.instagram.com/kikysaputrii\n\nKiky Saputri Official's Youtube is under management of:\ndr.m, Indonesia's 1st Certified & Official Youtube MCN\nhttps://servicesdirectory.withyoutube.com/directory/pt-digital-rantai-maya-drm",
#   'categoryId': '24',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/qoU7RFMjE6I/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '411622',
#   'likeCount': '12263',
#   'commentCount': '2255',
#   'duration': 'PT26M52S'},
#  {'title': 'STUDY TOUR #25 - Serena Hilang',
#   'publishedAt': '2024-03-17T09:05:15Z',
#   'channelTitle': 'Dasi Gantung',
#   'description': 'Yuk gabung dengan channel ini untuk mendapatkan akses ke berbagai keuntungan:\nhttps://www.youtube.com/channel/UCVAwRh03m3_1pZjRKvelomA/join\n\n\nMERCHANDISE Dasi Gantung \nShopee : https://shope.ee/501KQe83d4\n\nIni akun Dasi Gantung yang lain ya\nFacebook.     : https://www.facebook.com/profile.php?id=100066603937194\nTiktok   : https://vt.tiktok.com/ZSEXx5XV/\nInstagram : https://www.instagram.com/dasigantung/\nShopee Video : https://shopee.co.id/universal-link?redir=https%3A%2F%2Fshp.ee%2F9nidyp5&deep_and_deferred=1&smtt=0.0.9\nBstation   : https://bili.im/XXF4OcF\n\nDasi Gantung tidak punya akun sosial media selain diatas. Makasih banyak sudah support terus channel ini\xa0\n\nIni link game “Dimensi Lain Serena” tersedia di AppStore dan Play Store\nPlay Store :\nhttps://play.google.com/store/apps/details?id=com.arcadesindo.dimensilainserena\niOS (App Store) :\nhttps://apps.apple.com/id/app/dimensi-lain-serena/id1617391251?l=id\n\n#animasi #dasigantung #serena #monika #raki #ratara #animasisekolah #studytour',
#   'categoryId': '24',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/E-GvMpXXr1g/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '452049',
#   'likeCount': '49439',
#   'commentCount': '3429',
#   'duration': 'PT5M30S'},
#  {'title': 'RAMADHAN LOVE STORY PART 1 - Animasi Sekolah',
#   'publishedAt': '2024-03-18T13:49:11Z',
#   'channelTitle': 'Dhot Design',
#   'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.',
#   'categoryId': '1',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/RZmO08bFgYA/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '1801057',
#   'likeCount': '107618',
#   'commentCount': '7361',
#   'duration': 'PT5M31S'},
#  {'title': 'DAY6(데이식스) "Welcome to the Show" M/V',
#   'publishedAt': '2024-03-18T09:00:07Z',
#   'channelTitle': 'JYP Entertainment',
#   'description': 'DAY6(데이식스) "Welcome to the Show" M/V\r\n\nListen to DAY6 "Welcome to the Show" \nhttps://day6.lnk.to/fourever\n\nDAY6 Official YouTube: http://www.youtube.com/c/DAY6Official\nDAY6 Official Facebook: http://www.facebook.com/DAY6Official\nDAY6 Official Twitter: http://www.twitter.com/DAY6Official\nDAY6 FANS App Store : http://bit.ly/48OILIW\nDAY6 FANS Google Play : http://bit.ly/48tBxKE\nDAY6 Official Homepage: http://DAY6.jype.com\n\nCopyrights 2024 ⓒ JYP Entertainment. All Rights Reserved.',
#   'categoryId': '10',
#   'defaultAudioLanguage': 'ko',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/RowlrvmyFEk/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '775938',
#   'likeCount': '65432',
#   'commentCount': '5184',
#   'duration': 'PT3M56S'},
#  {'title': 'No brake getting faster | 7llin’ with DREAM | EP. 3',
#   'publishedAt': '2024-03-18T11:00:50Z',
#   'channelTitle': 'NCT DREAM',
#   'description': '#7llin_with_DREAM #칠링윗드림\n#NCTDREAM #Smoothie\n#NCTDREAM_Smoothie\n\nNCT DREAM Official\nhttps://www.youtube.com/nctdream \nhttps://www.instagram.com/nct_dream/ \nhttps://www.tiktok.com/@official_nct\nhttps://twitter.com/NCTsmtown_DREAM \nhttps://www.facebook.com/NCT.smtown',
#   'categoryId': '10',
#   'defaultAudioLanguage': 'ko',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/oZD34dkfhNQ/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '343564',
#   'likeCount': '51834',
#   'commentCount': '1344',
#   'duration': 'PT32M28S'},
#  {'title': 'CARA MEMBUAT MUSUH KESAL PART 38!!!',
#   'publishedAt': '2024-03-17T09:11:05Z',
#   'channelTitle': 'Gerrard Wijaya',
#   'description': 'Follow Me on :\nemail : indrawijy08@gmail.com\nInstragram : https://www.instagram.com/gerradwijy08\nTiktok          : https://www.tiktok.com/@barbar_esport1.fb\n \n---------------------------------------------------------------------------------------------------------\nlike, Share, And Comment kalo lu suka, kalo ga suka ya gpp\n---------------------------------------------------------------------------------------------------------\n\n► CREDIT and USAGE\n\n✘ Title:  hyperfun\n✘ Music:  Kevin MacLeod \n✘ License: CC BY 3.0 (http://goo.gl/BlcHZR)\n✘ Download: http://incompetech.com/music/royalty-...',
#   'categoryId': '20',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/yJTy6e62fU8/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '515746',
#   'likeCount': '21514',
#   'commentCount': '1447',
#   'duration': 'PT11M50S'},
#  {'title': 'Stop This Train, Win a Lamborghini',
#   'publishedAt': '2024-03-16T16:00:00Z',
#   'channelTitle': 'MrBeast',
#   'description': 'I still can’t believe what happened in this video lol \nCheck out the mind-blowing Galaxy AI on the Samsung Galaxy S24 Ultra. Click this link to see for yourself: https://bit.ly/MrBeast_SamsungGalaxyS24\n\nPlay the Official Fortnite Creative Map For This Video Here:\nMrBeast Minigames 🎯 - 9466-1340-3054\nhttps://www.fortnite.com/@mrbeast/9466-1340-3054\n\nThanks to Daniel Schiffer for the Feastables ad! Go check him out here @danielschiffer \n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------',
#   'categoryId': '24',
#   'defaultAudioLanguage': 'en',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/mKdjycj-7eE/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '61606521',
#   'likeCount': '3170076',
#   'commentCount': '96375',
#   'duration': 'PT18M53S'},
#  {'title': 'ATLETICO DE MADRID 0 vs 3 FC BARCELONA | LALIGA 2023/24 MD29',
#   'publishedAt': '2024-03-17T22:26:55Z',
#   'channelTitle': 'FC Barcelona',
#   'description': "Goals from João Félix, Lewandowski and Fermín inflict a first home defeat of the season in the league on Atlético.\n\nSUBSCRIBE NOW:\n▶ https://www.youtube.com/user/fcbarcelona \n\n⚽ BARÇATV+: http://barca.link/wT1w30qMyQO\u200b\n💎 Official Culers Membership: http://barca.link/plXS30rAhfC\u200b\n🌐 Site: http://www.fcbarcelona.com\n📱 App: https://go.onelink.me/xndC/DownloadAppYouTube\n\n🔵 Facebook: http://www.facebook.com/fcbarcelona\n📸 Instagram: http://www.instagram.com/fcbarcelona\n𝕏 Twitter: http://twitter.com/FCBarcelona\n🎶 Tiktok: https://www.tiktok.com/@fcbarcelona \n👾 Discord: https://discord.gg/fcbarcelonaofficial\n\n🛍 Get all official Barça apparel from FC Barcelona's online store: http://barca.link/j8QH30qQh4Y \n🔵🔴 #FCBarcelona",
#   'categoryId': '17',
#   'defaultAudioLanguage': 'en',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/l90gs0-gcjo/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '1409583',
#   'likeCount': '57468',
#   'commentCount': '1530',
#   'duration': 'PT3M26S'},
#  {'title': 'AKHIRNYA KONTRAKSI DAN HARUS CEPAT KE RUMAH SAKIT,  DETIK DETIK LAHIRAN ANAK KEDUA DI CHINA',
#   'publishedAt': '2024-03-18T05:08:24Z',
#   'channelTitle': 'DAILY TIKA WEIXUN DI CHINA',
#   'description': "#pernikahancampuran #indonesia   #china #desaterpencil #indonesianfood #jualanmakanan \nASSALAMUALAIKUM WRB.\n\nHalo teman-teman kembali lagi di channel YouTube DAILY TIKA WEIXUN DICHINA\nsaya TIKA warga Indonesia yg menikah dengan Warga Tiongkok yg Bernama LIANG WEIXUN kami memiliki anak PERTAMA Yg bernama CHINA LIANG ZHEYU.Nama Indonesia anak kami adalaha MUHAMMAD ABIL SHIDQI \n\nKami memiliki keluarga besar  yg hangat saling toleransi dan selalu menerima perbedaan semua keluarga kami sangat baik \n\nsebelumnya TERIMAKASIH BANYAK atas komentar baik kalian dan kami meminta maaf sebesar besarnya kalau komentar Dari teman teman KAMI belum bisa balas satu-satu 🙏SEMOGA teman teman mengerti Dengan keadaan dan kesibukan kami membuat video setiap hari  untuk menghibur kalian. \nTerima kasih untuk yang sudah komentar memberikan do'a support dan dukungan pada kami.Terima kasih atas saran masukan dan juga tman-teman \nTeman-teman\n\nyuuuk ikutin  keseruan kami divideo kali ini   dari awal sampai habis jangan di-skip \nsemoga kalian suka dengan video kali ini yaaah ...\n\nuntuk teman teman yang baru gabung selamat bergabung di channel kami semoga betah yah dan jangan bosan bosan hehehehe😘\nuntuk teman teman yang belum subscribe,yuuk disubscribe channel ini bantu like dan koment juga yaaah bila perlu di share hehehe\nterimakasih banyak semuanya sudah meluangkan waktunya untuk menonton video Dari kami we love you all\nlangsung nonton yuuuk \njangan di skip skip yaaah teman teman 😚😉😉\n\njangan lupa follow juga ig kami yaaah teman teman\n@tika_weixun02\nhttps://instagram.com/tika_weixun02",
#   'categoryId': '22',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/V49w-6ZrUQw/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '406239',
#   'likeCount': '25432',
#   'commentCount': '2981',
#   'duration': 'PT20M32S'},
#  {'title': 'MONVLOG - NYARI TAKJIL BUAT BUKA PUASA!',
#   'publishedAt': '2024-03-17T11:30:05Z',
#   'channelTitle': 'RRQ Lemon',
#   'description': 'Yuk gabung jadi member channel youtube aku melalui link ini:\nhttps://www.youtube.com/channel/UCuVxJ829ysWH2OhZJiWdnbg/join\n\nTempat Topup Para Juara:\nhttps://lemontopup.id/\n\nRamein Discord nya yuk!\nhttps://discord.gg/srwdEWE6c4\n\nJangan lupa follow aku ya :\n👉 https://instagram.com/ikhsan_lemon\n\nBussines : 0811-1993-0001\nEmail: business@teamrrq.com',
#   'categoryId': '20',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/DwZvETHRNT8/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '459531',
#   'likeCount': '41146',
#   'commentCount': '4084',
#   'duration': 'PT12M6S'},
#  {'title': 'MIC CHECK ALTER EGO VS EVOS | WEEK 1 - DAY 1 | MPL SEASON 13',
#   'publishedAt': '2024-03-17T20:00:21Z',
#   'channelTitle': 'Alter Ego Esports',
#   'description': 'Hai Champs!!\n\nMic check Alter Ego vs Evos\nMPL Season 13\nWeek 1 - Day 1\n\nDon’t forget to like, comment, subscribe and turn on the notification for our latest contents. Keep supporting us on our upcoming tournaments also, champs! \n\n=========================================== \n\nAlter Ego Esports Social Media:\nInstagram : https://www.instagram.com/alteregoesports/\nFacebook: https://www.facebook.com/alteregoesportsid\nTiktok: https://www.tiktok.com/@alterego.esports\nTwitter: https://twitter.com/AlterEgo_IDN\nYoutube: https://www.youtube.com/@AlterEgoEsports\n\nAlter Ego PUBG Mobile Social Media:\nInstagram: https://www.instagram.com/alteregopubgmobile/\nFacebook: https://www.facebook.com/alteregopubgmobile\nTiktok: https://www.tiktok.com/@alteregopubgmobile\nYoutube: https://www.youtube.com/@alteregopubgmobile\n\nIf you want to buy our official merchandise, you can visit our official store below:\nShopee: https://shopee.co.id/alterego_merch\nTokopedia: https://www.tokopedia.com/alteregomerch \n\n#alteregoesports #alterchamps',
#   'categoryId': '20',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zji-gXontsM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/zji-gXontsM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/zji-gXontsM/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/zji-gXontsM/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/zji-gXontsM/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '174016',
#   'likeCount': '4611',
#   'commentCount': '425',
#   'duration': 'PT4M34S'},
#  {'title': 'NGABUBURIT 2',
#   'publishedAt': '2024-03-17T09:19:49Z',
#   'channelTitle': 'Fadil Jaidi',
#   'description': '',
#   'categoryId': '10',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3RIzATWdGeI/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/3RIzATWdGeI/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/3RIzATWdGeI/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/3RIzATWdGeI/sddefault.jpg',
#     'width': 640,
#     'height': 480}},
#   'viewCount': '1150446',
#   'likeCount': '94492',
#   'commentCount': '4141',
#   'duration': 'PT10M22S'},
#  {'title': 'Chelsea 4-2 Leicester City | FA Cup 23/24 Match Highlights',
#   'publishedAt': '2024-03-17T15:23:23Z',
#   'channelTitle': 'beIN SPORTS Indonesia',
#   'description': 'Tonton liga-liga terbaik hanya di beIN SPORTS CONNECT: https://bein.onelink.me/bApY/beinYT \n\nSimak berita dan update menarik seputar liga terbaik dan beIN Sports Indonesia di semua sosial media:\n\nFacebook: https://www.facebook.com/beinsportsindonesia/\nTwitter: https://twitter.com/beinsportsid\nInstagram: https://www.instagram.com/beinsports.id/\nYouTube: https://www.youtube.com/c/beINSPORTSID',
#   'categoryId': '17',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LcUr3Jdf-os/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/LcUr3Jdf-os/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/LcUr3Jdf-os/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/LcUr3Jdf-os/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/LcUr3Jdf-os/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '334799',
#   'likeCount': '4305',
#   'commentCount': '436',
#   'duration': 'PT12M3S'},
#  {'title': 'Match Highlight: RANS Nusantara FC vs Bali United | Liga 1 2023/2024',
#   'publishedAt': '2024-03-17T17:17:09Z',
#   'channelTitle': 'RANS FC Official',
#   'description': '#Ranskandia #RANSNusantaraFC #RANSFC #RiseUp #Liga1\n\n___________________________\n\n📲 RANS FC on Social Media\nInstagram: https://instagram.com/rans.nusantara\nFacebook: https://www.facebook.com/rans.nusantara.fc\nTwitter: https://twitter.com/ransfcofficial\nTikTok: https://www.tiktok.com/@ransnusantara.fc',
#   'categoryId': '17',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qAi911Yd9Sk/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/qAi911Yd9Sk/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/qAi911Yd9Sk/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/qAi911Yd9Sk/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/qAi911Yd9Sk/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '108886',
#   'likeCount': '773',
#   'commentCount': '132',
#   'duration': 'PT2M19S'},
#  {'title': 'AYAH DESTA BUKA KONSULTASI.. GUMI, MISKHA, MIGUEL CURHAT TERBUKA YUK..',
#   'publishedAt': '2024-03-17T09:00:10Z',
#   'channelTitle': 'Trio Strong Family',
#   'description': 'Terima Kasih Udah Nonton Trio Strong Family\nJangan Lupa Like, Comment dan Subscribe Yaaa :)\n\n====================================\n\nDengerin juga podcast DESTAnya Siapa?\nhttps://open.spotify.com/show/4gLJ97S\u200b...\n\nDan podcastnya CERITAACA\nhttps://open.spotify.com/show/01wwgw8\u200b...\n\nFollow Juga Instagram Kita :\n@desta80s\nhttps://www.instagram.com/desta80s/\u200b\n\n@natasharizkynew\nhttps://www.instagram.com/natasharizk\u200b...\n\n====================================\n\nPERINGATAN :\nSemua materi Audio Video dalam video ini adalah milik "Trio Strong Family" Channel, mengambil/meng copy video atau audio baik keseluruhan ataupun sebagian untuk di publish ulang tanpa mencantumkan courtesy adalah pelanggaran terhadap hukum yang berlaku.\n\n#Desta\u200b #Natasha\u200b #Family\u200b\n#TrioStrongFamily\n#DailyVlog #Megumi #Miskha #Miguel',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DVUDu8moUP4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/DVUDu8moUP4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/DVUDu8moUP4/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/DVUDu8moUP4/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/DVUDu8moUP4/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '241754',
#   'likeCount': '10604',
#   'commentCount': '899',
#   'duration': 'PT29M35S'},
#  {'title': 'THE BOYZ(더보이즈) ’Nectar’ MV',
#   'publishedAt': '2024-03-18T09:00:07Z',
#   'channelTitle': 'THE BOYZ',
#   'description': 'THE BOYZ ‘Nectar’ on iTunes : https://apple.co/4agZUeZ\n\n✔ More information about THE BOYZ\nhttp://www.theboyz.kr\nhttps://www.youtube.com/c/THEBOYZofficial\nhttps://weverse.onelink.me/qt3S/f766oroa\nhttps://twitter.com/IST_THEBOYZ?s=20\nhttps://www.instagram.com/official_theboyz\nhttps://www.facebook.com/officialTHEBOYZ\nhttp://cafe.daum.net/officialTHEBOYZ\n\nCopyrights 2024 ⓒ IST Entertainment. All Rights Reserved.\n\n#THEBOYZ #PHANTASY #Nectar',
#   'categoryId': '24',
#   'defaultAudioLanguage': 'en',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CL3F7Cgkaxw/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/CL3F7Cgkaxw/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/CL3F7Cgkaxw/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/CL3F7Cgkaxw/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/CL3F7Cgkaxw/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '4725055',
#   'likeCount': '84548',
#   'commentCount': '3940',
#   'duration': 'PT5M3S'},
#  {'title': '[ID] 2024 PMSL SEA GFD2 | Spring | BERTAHAN SAMPAI AKHIR',
#   'publishedAt': '2024-03-16T15:10:16Z',
#   'channelTitle': 'PUBG MOBILE Indonesia',
#   'description': "2024 PMSL SEA SPRING Finals akan berlangsung! Setelah melewati babak liga selama 3 minggu, seluruh 8 tim Indonesia berhasil mengamankan posisi mereka untuk melaju ke babak Finals yang akan di adakan selama 3 hari mulai dari tanggal 15 - 17 Maret 2024 di Tropicana Gardens Mall Centre Court, CC Floor, Petaling Jaya, Malaysia. Siapa di antara mereka yang akan berhasil menjadi juara di 2024 PMSL SEA SPRING dan mendapatkan slot langsung ke 2024 PMGO MAIN EVENT?\n\nSaksikan dan berikan dukungan untuk tim Indonesia, agar mereka dapat memberikan hasil terbaik dan mendominasi Asia Tenggara! 🔥🌟 #SUPERDOMINASEA\n\nFINALS TEAMS:\n🇮🇩BIGETRON RED ALIENS\n🇮🇩TALON ESPORTS\n🇮🇩ALTER EGO ARES\n🇮🇩MORPH GPX\n🇮🇩BOOM ESPORTS\n🇮🇩VOIN ESPORTS\n🇮🇩RRQ RYU\n🇮🇩PIGMY ESPORTS\n🇲🇾SEM9\n🇲🇾GEEK FAM\n🇲🇾Y. ALLIANCE\n🇹🇭FaZe Clan\n🇹🇭Vampire Esports\n🇻🇳D'XAVIER\n🇻🇳TEAM FLASH\n🇻🇳\u200b\u200bTeam X\n\nSetiap tim akan bertarung 6 match perharinya. Berikut adalah rotasi map:\n⚔️Match 1: Sanhok\n⚔️Match 2: Erangel\n⚔️Match 3: Erangel\n⚔️Match 4: Erangel\n⚔️Match 5: Miramar\n⚔️Match 6: Miramar \n\n2024 PMSL SEA Spring🍃🏆\n🗓️ 15 - 17 Maret 2024 (Finals)\n\n📺 Live On:\n🔴 Youtube : PUBG Mobile Indonesia\n🔴 Youtube : PUBG Mobile Esports\n🔵 Fanpage : PUBG MOBILE (ID)\n🟣 Vidio : PUBG Mobile Indonesia\n⚫ Tiktok : PUBG MOBILE Indonesia\n⚫ Tiktok : PUBG MOBILE Esports Indonesia\n\n#PUBGMOBILE #2024PMSLSEASPRING  #SUPERDOMINASEA #PUBGMINDONESIA #PUBGMOBILEESPORTS #PMSL #PMSLSEA #PUBGM #ESPORTS #MOBILEESPORTS",
#   'categoryId': '20',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Z4L938l1WV0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Z4L938l1WV0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Z4L938l1WV0/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/Z4L938l1WV0/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/Z4L938l1WV0/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '1151963',
#   'likeCount': '19738',
#   'commentCount': '84',
#   'duration': 'PT6H36M50S'},
#  {'title': 'KONA GAK SAUR PART 2 - Animasi Sekolah',
#   'publishedAt': '2024-03-17T11:00:16Z',
#   'channelTitle': 'Dhot Design',
#   'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.',
#   'categoryId': '1',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NY72IWZqF7U/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/NY72IWZqF7U/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/NY72IWZqF7U/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/NY72IWZqF7U/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/NY72IWZqF7U/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '3052558',
#   'likeCount': '144231',
#   'commentCount': '5734',
#   'duration': 'PT6M58S'},
#  {'title': 'MALIQ & D’Essentials — Kita Bikin Romantis (Storylizer)',
#   'publishedAt': '2024-03-17T06:45:07Z',
#   'channelTitle': "MALIQ & D'Essentials",
#   'description': 'Selamat menikmati "Kita Bikin Romantis" – lagu kedua setelah "Aduh" yang akan jadi bagian dari album ke-9 MALIQ & D\'Essentials nanti.\n\nLagunya juga bisa didengar di https://wmid.lnk.to/KitaBikinRomantisMAD\nFollow juga Instagram kami di https://www.instagram.com/maliqmusic/\n\nIni adalah rangkuman dari ribuan cerita yang masuk ke social media kami, terutama Tiktok. Berisi tentang berbagai intepretasi bentuk romantisme dalam kehidupannya masing-masing. Juga sebagai bukti bahwa tidak semua hal-hal romantis bentuknya manis. Kebahagiaan sejati sering kali ditemukan dalam sebuah kesederhanaan.\n\nTerima kasih untuk kalian yang sudah dengan senang hati membuat video creation dari #KitaBikinRomantis di berbagai platform social media. Keep \'em coming! Menyenangkan sekali melihat berbagai kisah kalian.\n\nMuch love,\nMAD.\n\n–\n\nPerformed by : MALIQ & D’Essentials\nWritten & Composed by : Widi Puradiredja\nExecutive Producer : MAD Haus & Warner Music Indonesia\nProduced by : MALIQ & D\'Essentials\nMixed by : Widi & Jawa at MAD Haus\nMastered by : Geoff at Abbey Road Studio\nDrums & Programming by : Widi Puradiredja\nKeyboard & Synth by : Ilman Ibrahim\nGuitars by : Arya “Lale” Aditya\nSynth Bass by : Widi Puradiredja\nRecording Engineered by : Widi & Jawa\nAll Recorded at : MAD Haus Studio\n\n–\n\nCreative Director : Dimasz Joey\nVideo Lyric by : Dimasz Joey\n\n#KitaBikinRomantis #SurgaItuKamu #LaguBaruMAD',
#   'categoryId': '10',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3uPN8pj3ld4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/3uPN8pj3ld4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/3uPN8pj3ld4/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/3uPN8pj3ld4/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/3uPN8pj3ld4/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '234768',
#   'likeCount': '4530',
#   'commentCount': '347',
#   'duration': 'PT4M3S'},
#  {'title': 'Menguasai Planet Dengan 10,000 Villager Brudal',
#   'publishedAt': '2024-03-17T05:15:01Z',
#   'channelTitle': 'RemanRHN',
#   'description': 'Inspired By : GroxMC  & NotSafe\ndunia perizinan di community post cuyy\n\nspecial thanks for: \n@BigRoyyan \n@IgnRels_Shorts \n\n****\ndi video kali ini gw dan para villager brudal telah menemukan planet baru yang akan di gunakan sebagai peradaban  baru untuk villager brudal namun di planet ini kita tidak sendirian maka karena itu kami akan menguasai planet ini dan menamainya dengan planet brudal, gimana keseruan dan kelucuannya? tonton sampai tamat!!!\n\nyok bisa yok biar gw semangat 20K+\n\n*** Medsos Reman (Selain Ini Fake) :\nTiktok : Reman (@remanrhn)\nInstagram : Reman (@remanrhn)\n\n\n*** source\n\nbuild:\nThe Planet - by @michaelmana \nSpaceShip Blu 01 - build by thịnh lê made in vietnam minecraft\nanother build - RemanRHN & minecraftschematic\n\nMusic :\nbigdruming\nChill Luxury R&B By Soyb.\nROYALTY FREE Ceremony Music  Ceremony Background Music by MUSIC4VIDEO.\nSolitary, solitude By Prod Riddiman',
#   'categoryId': '20',
#   'defaultAudioLanguage': 'en-US',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JOi4Tm7gnkc/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/JOi4Tm7gnkc/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/JOi4Tm7gnkc/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/JOi4Tm7gnkc/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/JOi4Tm7gnkc/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '215799',
#   'likeCount': '16350',
#   'commentCount': '795',
#   'duration': 'PT8M51S'},
#  {'title': 'Resep Menu Buka Puasa, Simple & Elegant. Daging,Ikan, Salad Kentang.',
#   'publishedAt': '2024-03-18T01:34:58Z',
#   'channelTitle': 'Nikmatul Rosidah',
#   'description': '',
#   'categoryId': '26',
#   'defaultAudioLanguage': 'en-CA',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pizPC3WmWqU/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/pizPC3WmWqU/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/pizPC3WmWqU/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/pizPC3WmWqU/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/pizPC3WmWqU/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '103095',
#   'likeCount': '3254',
#   'commentCount': '140',
#   'duration': 'PT15M45S'},
#  {'title': '[WARTAK] AWAL DARI SEMUANYA!!',
#   'publishedAt': '2024-03-17T20:00:29Z',
#   'channelTitle': 'JKT48 TV',
#   'description': 'Kalian udah pada disini belum waktu itu? 👀\n\n*\nJangan lupa untuk Like, Comment, Share dan Subscribe ya! Silahkan follow juga akun-akun kami yang lain:\nJKT48 Youtube: @JKT48 \nJKT48 X: https://x.com/officialJKT48?t=Clke_mnjfHTIe8YA9-0vmQ&s=09\nJKT48 Facebook Fan Page: https://www.facebook.com/official.JKT48\nJKT48 Instagram: https://www.instagram.com/jkt48/\n\n*\n\nProfil member Olla:\n- Official member: https://jkt48.com/member/detail/id/213?lang=id\n\n- X: https://x.com/F_OllaJKT48?s=20\n\n- Instagram: https://www.instagram.com/jkt48.olla/?utm_source=ig_web_button_share_sheet&igshid=OGQ5ZDc2ODk2ZA==\n\nTiktok: https://www.tiktok.com/@ollajkt48?is_from_webapp=1&sender_device=pc\n\n*\n\nProfil member Freya:\n- Official member: https://jkt48.com/member/detail/id/214?lang=id\n- X: https://x.com/Freya_JKT48?s=20\n- Instagram: https://www.instagram.com/jkt48.freya/?utm_source=ig_web_button_share_sheet&igshid=OGQ5ZDc2ODk2ZA==\n- Tiktok: https://www.tiktok.com/@freyajkt48?is_from_webapp=1&sender_device=pc',
#   'categoryId': '24',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wFb6wAjyPz0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/wFb6wAjyPz0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/wFb6wAjyPz0/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/wFb6wAjyPz0/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/wFb6wAjyPz0/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '242252',
#   'likeCount': '26798',
#   'commentCount': '2715',
#   'duration': 'PT18M28S'},
#  {'title': 'REBUTAN TAKJIL BUAT BUKBER RRQ HOSHI',
#   'publishedAt': '2024-03-17T11:12:25Z',
#   'channelTitle': 'RRQ AP',
#   'description': 'Di hari pertama puasa kemarin, saya ke pasar BendHil untuk berburu takjil dan buka puasa sama anak-anak Hoshi. Nextnya sama siapa lagi ya?',
#   'categoryId': '20',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5E5aqkyCXg8/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/5E5aqkyCXg8/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/5E5aqkyCXg8/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/5E5aqkyCXg8/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/5E5aqkyCXg8/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '284592',
#   'likeCount': '14168',
#   'commentCount': '1021',
#   'duration': 'PT10M34S'},
#  {'title': "[LIVE] 라이브로 듣는 뷔의 감미로운 고백, 'FRI(END)S'  by W Korea",
#   'publishedAt': '2024-03-18T07:57:49Z',
#   'channelTitle': 'W KOREA',
#   'description': "W X V X Cartier\n“많은 추억이 담긴 노래입니다.” 2년동안 소중하게 간직했던 곡을 이제서야 선보이게 되었다며 촬영 당일 설렘을 감추지 못한 뷔. 이 계절에 어울리는 감미롭고 담담한 고백. 두 가지 버전의 라이브로 담은 뷔의 'FRI(END)S' 중 감미로운 목소리와 깊은 감성이 담긴 메인 클립을 지금 만나보세요. \n-\nMeet the main film of V's 'FRI(END)S' captured in two versions of live clips, imbued with mellifluous vocals and profound emotions. \n-\n패션 에디터ㅣ이예진 \n영상ㅣ홍장현 \n스타일리스트ㅣ김예진 \n헤어ㅣ최무진 \n메이크업ㅣ안성희 \n-\n#V #BTS #V_FRIENDS #FRI_END_S #Cartier #뷔 #김태형 #방탄소년단 #까르띠에",
#   'categoryId': '24',
#   'defaultAudioLanguage': 'en',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VUFuh4glr8I/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/VUFuh4glr8I/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/VUFuh4glr8I/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/VUFuh4glr8I/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/VUFuh4glr8I/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '853467',
#   'likeCount': '199701',
#   'commentCount': '11979',
#   'duration': 'PT2M31S'},
#  {'title': '[BWF] MS - Quarterfinals｜Viktor AXELSEN vs A.S.GINTING H/L| All England Open Badminton Championships',
#   'publishedAt': '2024-03-15T21:07:37Z',
#   'channelTitle': 'SPOTV ASIA',
#   'description': "[YONEX All England Open Badminton Championships 2024]\nMen's Singles - Quarterfinals\nViktor AXELSEN vs Anthony Sinisuka GINTING\n\nWherever, Whenever Watch SPOTV NOW! ☞ https://www.spotvnow.com\n Play Store  ▷ https://play.google.com/store/apps/details?id=com.spotvnow.app\n App Store ▷ https://apps.apple.com/app/spotv-now-asia/id1585915793",
#   'categoryId': '17',
#   'defaultAudioLanguage': 'en',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sFo8zCm85QQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/sFo8zCm85QQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/sFo8zCm85QQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/sFo8zCm85QQ/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/sFo8zCm85QQ/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '887436',
#   'likeCount': '10812',
#   'commentCount': '1226',
#   'duration': 'PT13M50S'},
#  {'title': 'BIKIN TAKJIL 5 MACAM, SEMUA DARI ACI! 🤤',
#   'publishedAt': '2024-03-17T10:00:26Z',
#   'channelTitle': 'Kimbab Family',
#   'description': '',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/c6laEoob8z0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/c6laEoob8z0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/c6laEoob8z0/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/c6laEoob8z0/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/c6laEoob8z0/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '357634',
#   'likeCount': '24505',
#   'commentCount': '1080',
#   'duration': 'PT27M31S'},
#  {'title': 'NGABUBURIT NYARI TAKJIL',
#   'publishedAt': '2024-03-16T11:30:06Z',
#   'channelTitle': 'Fadli Faisal',
#   'description': '',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GtGLsjEDOfs/default.jpg',
#     'width': 120,
# ...
#  {'title': '[ID] 2024 PMSL SEA GFD1 | Spring | 8 TIM INDONESIA BERTARUNG UNTUK JUARA',
#   'publishedAt': '2024-03-15T14:47:08Z',
#   'channelTitle': 'PUBG MOBILE Indonesia',
#   'description': "2024 PMSL SEA SPRING Finals akan berlangsung! Setelah melewati babak liga selama 3 minggu, seluruh 8 tim Indonesia berhasil mengamankan posisi mereka untuk melaju ke babak Finals yang akan di adakan selama 3 hari mulai dari tanggal 15 - 17 Maret 2024 di Tropicana Gardens Mall Centre Court, CC Floor, Petaling Jaya, Malaysia. Siapa di antara mereka yang akan berhasil menjadi juara di 2024 PMSL SEA SPRING dan mendapatkan slot langsung ke 2024 PMGO MAIN EVENT?\n\nSaksikan dan berikan dukungan untuk tim Indonesia, agar mereka dapat memberikan hasil terbaik dan mendominasi Asia Tenggara! 🔥🌟 #SUPERDOMINASEA\n\nFINALS TEAMS:\n🇮🇩BIGETRON RED ALIENS\n🇮🇩TALON ESPORTS\n🇮🇩ALTER EGO ARES\n🇮🇩MORPH GPX\n🇮🇩BOOM ESPORTS\n🇮🇩VOIN ESPORTS\n🇮🇩RRQ RYU\n🇮🇩PIGMY ESPORTS\n🇲🇾SEM9\n🇲🇾GEEK FAM\n🇲🇾Y. ALLIANCE\n🇹🇭FaZe Clan\n🇹🇭Vampire Esports\n🇻🇳D'XAVIER\n🇻🇳TEAM FLASH\n🇻🇳\u200b\u200bTeam X\n\nSetiap tim akan bertarung 6 match perharinya. Berikut adalah rotasi map:\n⚔️Match 1: Sanhok\n⚔️Match 2: Erangel\n⚔️Match 3: Erangel\n⚔️Match 4: Erangel\n⚔️Match 5: Miramar\n⚔️Match 6: Miramar \n\n2024 PMSL SEA Spring🍃🏆\n🗓️ 15 - 17 Maret 2024 (Finals)\n\n📺 Live On:\n🔴 Youtube : PUBG Mobile Indonesia\n🔴 Youtube : PUBG Mobile Esports\n🔵 Fanpage : PUBG MOBILE (ID)\n🟣 Vidio : PUBG Mobile Indonesia\n⚫ Tiktok : PUBG MOBILE Indonesia\n⚫ Tiktok : PUBG MOBILE Esports Indonesia\n\n#PUBGMOBILE #2024PMSLSEASPRING  #SUPERDOMINASEA #PUBGMINDONESIA #PUBGMOBILEESPORTS #PMSL #PMSLSEA #PUBGM #ESPORTS #MOBILEESPORTS",
#   'categoryId': '20',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Lg-tjAY-R74/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Lg-tjAY-R74/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Lg-tjAY-R74/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/Lg-tjAY-R74/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/Lg-tjAY-R74/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '1124526',
#   'likeCount': '15984',
#   'commentCount': '94',
#   'duration': 'PT6H16M30S'},
#  {'title': 'HIGHLIGHTS | Fulham 3-0 Spurs | London Derby Delight 🔥',
#   'publishedAt': '2024-03-16T22:00:09Z',
#   'channelTitle': 'Fulham Football Club',
#   'description': 'Watch the best of the action as Fulham defeated Spurs in a London derby under the lights 🏡\n\nSUBSCRIBE now and never miss an upload: https://tinyurl.com/yf9vsfwb \n\nFacebook: http://ow.ly/1lGs30rhHUk\nTwitter: http://ow.ly/dJIA30rhHUN\nInstagram: http://ow.ly/fowC30rhHV2\nTikTok: https://www.tiktok.com/@fulhamfc?y\n\n#Fulham #FFC #Highlights',
#   'categoryId': '17',
#   'defaultAudioLanguage': 'en-GB',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HFJZme86It4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/HFJZme86It4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/HFJZme86It4/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/HFJZme86It4/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/HFJZme86It4/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '470217',
#   'likeCount': '7938',
#   'commentCount': '285',
#   'duration': 'PT2M1S'},
#  {'title': 'HOROR DARI AYAT ALKITAB YANG SANGAT MENGERIKAN! Psalm 5:9-13',
#   'publishedAt': '2024-03-17T21:01:00Z',
#   'channelTitle': 'Windah Basudara',
#   'description': 'Guys Join discord Motion Ime disana semua komunitas ada!: https://discord.gg/motionime \nFestival Motionimefest: https://www.instagram.com/motionimefest/\nTop up termurah & terpercaya sampai kasih garansi 10x cuma di Lapakgaming! Top up di sini https://bit.ly/LGXWindah\nPake code ini biar makin cuan! DISKONSERUFF untuk Free Fire\n\nToko top up game ku Windah Topup: https://windahtopupstore.com/\nFollow Instagram ku: https://www.instagram.com/windahbasudara/?hl=en\n\nSubscribe Channel Youtube RRQ:  https://www.youtube.com/@teamrrq\n----------------------------------------------------------------------------------------------- \nSebut nama oleh nightbot langsung aja ketik !sebutnama\n\nTerima kasih buat yang sudah mampir, dan yang sudah like, share, dan subscribe!\n\nStream ini tidak membuka donasi teman- teman 😊. Donasi-kan lah ke anak yatim piatu atau orang- orang yang lebih me mbutuhkan, hal tersebut sudah menjadi bentuk donasi ke stream ini, terima kasih. Atau kalian bisa donasi ke sesama yang membutuhkan di https://kitabisa.com/\u200b\n------------------------------------------------------------------------------------------------\n\nnightbot commands:\n\n!discord\n!topupstore\n!sebutnamaku\n!daganganku\n!instagram\n!umur\n!asal\n!awalyoutube\n!gamefavorite\n!jadwal\n!pacar\n!cendy\n!rio\n!harly\n!eka\n\n#WindahBasudara #Psalm5:9-13',
#   'categoryId': '20',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/y1IOphuDOnE/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/y1IOphuDOnE/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/y1IOphuDOnE/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/y1IOphuDOnE/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/y1IOphuDOnE/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '427617',
#   'likeCount': '21302',
#   'commentCount': '2387',
#   'duration': 'PT36M44S'},
#  {'title': 'REBUTAN HUKUMAN (AYAHKU SEORANG POLISI END PART)',
#   'publishedAt': '2024-03-16T10:00:07Z',
#   'channelTitle': 'SANTOON TV',
#   'description': 'Series Ayahku Seorang Polisi End Part: Hukuman yang dijatuhkan untuk Pipin dan Ayahnya.\n#santoontv #animasi',
#   'categoryId': '1',
#   'defaultAudioLanguage': None,
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/oazeIrQ8hj8/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/oazeIrQ8hj8/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/oazeIrQ8hj8/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/oazeIrQ8hj8/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/oazeIrQ8hj8/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '297097',
#   'likeCount': '15773',
#   'commentCount': '1924',
#   'duration': 'PT4M24S'},
#  {'title': 'Alip_Ba_Ta - Ibu (Fingerstyle Version)',
#   'publishedAt': '2024-03-16T10:00:03Z',
#   'channelTitle': 'Alip_Ba_Ta',
#   'description': 'Monggo dimidangetaken ugi tembang kulo dateng toko musik digital lintune\n\nSpotify : https://open.spotify.com/artist/6jV3Kyd4AEGrCCyLTGyikT\nItunes : https://music.apple.com/id/artist/alip-ba-ta/1533787470\nLangit Musik : https://www.langitmusik.co.id/new/artist/12093564\nDeezer : https://deezer.page.link/S3X8XVfChmKs2ahUA\n\n\n\nSocial Network \nTwitter : @AlifGustakhiyat https://twitter.com/AlifGustakhiyat\nInstagram : @alif_gustakhiyat https://www.instagram.com/alif_gustakhiyat/\nTikTok : @alif_gustakhiyat https://www.tiktok.com/@alif_gustakhiyat',
#   'categoryId': '10',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3K6hwdB2VPY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/3K6hwdB2VPY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/3K6hwdB2VPY/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/3K6hwdB2VPY/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/3K6hwdB2VPY/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '356807',
#   'likeCount': '35606',
#   'commentCount': '3098',
#   'duration': 'PT4M8S'},
#  {'title': 'KONA GAK SAUR PART 1 - Animasi Sekolah',
#   'publishedAt': '2024-03-15T11:58:44Z',
#   'channelTitle': 'Dhot Design',
#   'description': 'Animasi yang menceritakan masa masa sekolah SMA, yang seru, lucu, membahas percitaan dan penuh dengan arti kehidupan.\n\nSOCIAL MEDIA :\n\nINSTAGRAM : https://www.instagram.com/dhot.design/\n\nFACEBOOK : DHOT (Design)\nhttps://www.facebook.com/profile.php?id=100087442015696&mibextid=ZbWKwL\n\nFacebook FANSPAGE : https://www.facebook.com/profile.php?id=100088236669799&mibextid=ZbWKwL\n\nTIKTOK : Dhot Design\ntiktok.com/@dhotdesign\n\nBSTATION : Dhot Design\n\nSNACK VIDEO : DHOT DESIGN\nhttps://sck.io/u/@DhotDesign/XB3hjPGs\n\n#dhokona #animasisekolah #animasilucusekolah #kartunsekolah #animasilucuindo #animasindonesia #animasianaksma #animeschool #schoolanime\n\nAnimasi sekolah, animasi lucu sekolahan, animasi menceritakan masa sekolah, animasi lokal, animasi lucu indonesia, kartun anak sekolah, animasi kocak sekolah, animasi kocak bikin ngakak, animasi menceritakan anak sekolah, anime school, anime sekolahan, animasi masa sekolah sma, animasi anak sma, animasi anak smp, amimasi seru sekolahan, animasi keren sekolahan.',
#   'categoryId': '1',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/EXZAHdkTP2I/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '4021625',
#   'likeCount': '221312',
#   'commentCount': '17893',
#   'duration': 'PT8M5S'},
#  {'title': 'SUASANA BERBUKA PUASA DI RUMAH BARU ! ADA MUSHALLA NYA 🥰',
#   'publishedAt': '2024-03-16T08:59:48Z',
#   'channelTitle': 'Neo Japan',
#   'description': '.................\nSEDEKAH BERAS nya om/tante!\nhttps://trakteer.id/neojapan\n..........................................\nchannel PODCAST NEOJAPAN SOON ! https://www.youtube.com/channel/UCN4WWwEz1QMDg1Ua1tz7MEg\n\ninstagram NEOJAPAN_;  https://www.instagram.com/neojapan_/?hl=en\ninstagram Yusufkun ; https://www.instagram.com/yuu.kun21/?hl=en',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'en',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/sQCskcSeKI4/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '227763',
#   'likeCount': '10702',
#   'commentCount': '621',
#   'duration': 'PT15M35S'},
#  {'title': 'BUKA PUASA BANGKRUTIN RESTORAN ALL YOU CAN EAT LAGI !',
#   'publishedAt': '2024-03-16T10:00:48Z',
#   'channelTitle': 'tanboy kun',
#   'description': 'The Social Pot Pondok Indah\n\nRT.1, Jl. Metro Pondok Indah No.1, RT.1/RW.16, Pondok Pinang, Kebayoran Lama, South Jakarta City, Jakarta 12310',
#   'categoryId': '24',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/zPkKNW0-JKQ/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '1142687',
#   'likeCount': '27507',
#   'commentCount': '1279',
#   'duration': 'PT28M54S'},
#  {'title': 'PERSIB BANDUNG LANJUTKAN TREN KEMENANGAN, PERSIKABO KENA COUNTER!',
#   'publishedAt': '2024-03-16T07:20:20Z',
#   'channelTitle': 'Bola Bung Binder',
#   'description': 'Review pertandingan Liga 1 antara Persikabo 1973 vs Persib Bandung yang berakhir untuk kemenangan Persib dengan skor 1-3',
#   'categoryId': '17',
#   'defaultAudioLanguage': 'en',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/q6w-STaQg28/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '226910',
#   'likeCount': '18489',
#   'commentCount': '2779',
#   'duration': 'PT14M25S'},
#  {'title': 'MERAYAKAN HARI PERTAMA DENGAN GULAI AYAM GRATIS UNTUK SEMUANYA YANG DI CHINA PADA HARI PUASA🥹💗',
#   'publishedAt': '2024-03-16T11:00:19Z',
#   'channelTitle': 'SHANTY DI CHINA',
#   'description': 'Shanty giok : https://shantidichina.com\n===============================\nDukung dan Support Kita terus ya guys!!\nInstagram : https://instagram.com/shanty3182\nTiktok : https://www.tiktok.com/@shantydichinatiktok\nFacebook : https://www.facebook.com/shanty521\nUntuk bisnis dan kerjasama :\nEmail : Christenaperrington5p110@gmail.com\nMakasih buat kalian yang selalu luangin waktu buat nonton video kita. Mohon dibantu comment, like dan subscribe ya!\nJika ada ide ataupun masukan jangan sungkan untuk komen ya guys.\nTerima kasih /// 谢谢你们\n#indonesia     \n#china',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/Ol5lscEcRZY/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '926508',
#   'likeCount': '37753',
#   'commentCount': '3332',
#   'duration': 'PT37M12S'},
#  {'title': 'BONGKAR OLEH2 /HARTA KARUN DARI INDONESIA KAYAK TOKO PINDAH ,ALHAMDULILAH PUNYA JAJAN LEBARAN',
#   'publishedAt': '2024-03-17T02:00:13Z',
#   'channelTitle': 'Yanti Guixe family',
#   'description': '',
#   'categoryId': '22',
#   'defaultAudioLanguage': 'id',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/VJgsItSAJ8w/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'viewCount': '276938',
#   'likeCount': '12365',
#   'commentCount': '786',
#   'duration': 'PT29M10S'}]

# %% [markdown]
# #### Define Additional Details to Extract (`trendingAt` & `videoId`)

# %% [markdown]
# Since we'll continually update the data then, let's note the time when the video becomes trending and fetch it (`trendingAt`), and also record its video ID (`videoId`) to facilitate storage in the database later.

# %%
# modules for handling date and time operations with time zone support
from datetime import datetime, timezone

# %%
# retrieves the current time in UTC format 
time_now = datetime.now(timezone.utc).strftime('%Y-%m-%dT%H:%M:%SZ')
time_now
# Out:
# '2024-03-19T05:28:06Z'

# %%
# way to get videoId
videos[0].get("id")
# Out:
# '2bopnQpPwgI'

# %% [markdown]
# On the code before, we only make `video_details = {}`
#
# But because we want to add `videoId` and `trendingAt` to `video_details`, we can directly put it in the initialization like this:
#
# `video_details = {'videoId': video.get("id"), 'trendingAt': time_now}`

# %%
videos_list = []

for video in videos:
    # initialize a dictionary to store video details
    video_details = {'videoId': video.get("id"), 'trendingAt': time_now}
    
    for key, value in complete_infos.items():
        for info in value:
            video_details[info] = video.get(key, {}).get(info)
    
    videos_list.append(video_details)

# %% [markdown]
# Finally, we have completed the process. We've transformed raw video data into a structured format ready for analysis.

# %% [markdown]
# Overall, while the basic method may suffice for simple tasks, the advanced method provides a more robust and scalable solution capable of meeting complex requirements and promoting better development practices.

# %% [markdown]
# ## 5. Write Fetched Videos Data to a JSON file

# %% [markdown]
# Writing fetched videos data to a JSON file is crucial as it serves as an interim step in the development process before transitioning to storing the data in a database. This enables efficient data management and facilitates the seamless integration of the extracted information into the database for future development.

# %% [markdown]
# We can store the fetched data using `json.dump()`, which takes two parameters: the data to be stored and the file object where the data will be written.

# %% [markdown]
# - `target_file_path` is the path where the JSON file will be created or overwritten.
# - `videos_list` is a list containing dictionaries, with each dictionary representing details of a video.

# %%
file_path = 'dags/tmp_file.json'

# %% [markdown]
# **Note**: Later, use `"/opt/airflow/dags/..."` for docker purpose

# %%
import json

with open(file_path, "w") as f:
    json.dump(videos_list, f)

# %% [markdown]
# `json.dump()` serializes the `videos_list` into a JSON formatted string and writes it to the file.

# %% [markdown]
# > Open the target file in write mode ('w') using a 'with' statement. This ensures that the file is properly closed after writing, even if an exception occurs.

# %%
len(videos_list)
# Out:
# 50

# %% [markdown]
# Using this single request API, we can get maximum 50 trending videos. Congratulations!

# %% [markdown]
# In summary:
# 1. We sent a request to the YouTube API to fetch videos based on specific criteria.
# 2. The API responded with the requested videos.
# 3. We extracted important details like titles, publish dates, and view counts from the response.
# 4. Then, we processed these details to gain insights or present them to users.
# 5. Finally, we stored the data into a JSON file.
#
# Through these steps, we effectively interacted with the YouTube API, retrieved relevant video data, and made use of it for our purposes.

# %% [markdown]
# **Disadvantages of Single Request**
#
# Actually, there are typically 200 pieces of data for trending YouTube videos at any given time, but due to the maximum limit of 50 items per single request, we cannot retrieve all of them in one fetch.
#
# So, what should be done? This highlights the inherent limitation of a single request: limited data and the risk of data loss. Hence, the necessity for pagination.
#
# **Solution :**
# To solve the limitations of single requests, we can implement pagination by:
#
# 1. Sending an initial request to fetch the first batch of videos.
# 2. Checking if there are more pages of results available.
# 3. If more pages are available, sending additional requests for each page until all desired data is retrieved.
# 4. Processing and aggregating the data from each page to obtain a complete dataset for analysis or presentation.
#
# By following this approach, we ensure comprehensive data retrieval while maintaining efficient resource usage and scalability in our application.

# %% [markdown]
# ## Paginate Through Results Using to Get All Trending Videos
#
# Pagination allows us to retrieve additional batches of videos beyond the initial request.  In this case, we utilize multiple requests to fetch data in batches, ensuring comprehensive coverage of trending videos.
#
# It's a very simple and straightforward process, but by using pagination, we can overcome limitations and ensure we get all trending videos.

# %% [markdown]
# ```python
# next_page_token = ""
# while next_page_token is not None:
#     # all code before here
#     # ...
#     next_page_token = response.get("nextPageToken", None)
# ```

# %%
videos_list = []
# initialize the token
next_page_token = ""

while next_page_token is not None:
    request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        chart="mostPopular",
        regionCode=region_code,
        maxResults=50,
        pageToken=next_page_token # add pageToken to inform the API
    )
    response = request.execute()
    videos = response.get("items", [])

    time_now = datetime.now(timezone.utc).strftime('%Y-%m-%dT%H:%M:%SZ')
    for video in videos:
        video_details = {'videoId': video["id"], 'trendingAt': time_now}
        
        for key, value in complete_infos.items():
            for info in value:
                video_details[info] = video.get(key, {}).get(info)
                    
        videos_list.append(video_details)

    # store the next page to fetch (token)
    next_page_token = response.get("nextPageToken", None)

with open(file_path, "w") as f:
    json.dump(videos_list, f)

# %%
len(videos_list)
# Out:
# 200

# %% [markdown]
# Yay! By utilizing pagination, we've finally obtained all the trending videos! It's simple, isn't it?

# %% [markdown]
# #### Conclusion
# By following these steps, we can progressively learn how to fetch videos from YouTube's API, starting from making a single request and advancing to paginating through the results. This approach allows beginners to grasp the fundamentals of API interaction and data retrieval while gradually building their skills.

# %% [markdown]
# # Data Preprocessing Youtube Data

# %% [markdown]
# Preprocess our fetched data is essential for preparing raw data fetched from YouTube for analysis or usage by restructuring it into a more organized format, enriching it with additional information, cleaning inconsistencies, and normalizing its structure.
#
# > We need to enhances the data's readability and usability while ensuring consistency and reliability. It also improves the efficiency of downstream applications or analyses that rely on the processed data.
#
# Let's take a look to our sample raw data!

# %%
# load the fetched videos data and categories dictionary from json files
with open(file_path, 'r') as f:
    videos_list = json.load(f)

# %%
example_video = videos_list[0]
example_video
# Out:
# {'videoId': '2bopnQpPwgI',
#  'trendingAt': '2024-03-19T05:28:06Z',
#  'title': 'Manchester United 2-2 (4-3 aet) Liverpool | FA Cup 23/24 Match Highlights',
#  'publishedAt': '2024-03-17T18:49:27Z',
#  'channelTitle': 'beIN SPORTS Indonesia',
#  'description': 'Tonton liga-liga terbaik hanya di beIN SPORTS CONNECT: https://bein.onelink.me/bApY/beinYT \n\nSimak berita dan update menarik seputar liga terbaik dan beIN Sports Indonesia di semua sosial media:\n\nFacebook: https://www.facebook.com/beinsportsindonesia/\nTwitter: https://twitter.com/beinsportsid\nInstagram: https://www.instagram.com/beinsports.id/\nYouTube: https://www.youtube.com/c/beINSPORTSID',
#  'categoryId': '17',
#  'defaultAudioLanguage': None,
#  'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/default.jpg',
#    'width': 120,
#    'height': 90},
#   'medium': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/mqdefault.jpg',
#    'width': 320,
#    'height': 180},
#   'high': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/hqdefault.jpg',
#    'width': 480,
#    'height': 360},
#   'standard': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/sddefault.jpg',
#    'width': 640,
#    'height': 480},
#   'maxres': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/maxresdefault.jpg',
#    'width': 1280,
#    'height': 720}},
#  'viewCount': '1817393',
#  'likeCount': '26262',
#  'commentCount': '3733',
#  'duration': 'PT11M51S'}

# %% [markdown]
# We can do it by converting duration to seconds, mapping category identifiers to their names, parsing thumbnail URLs, and converting string representations of numerical values to integers.

# %% [markdown]
# ## Converting Duration to Seconds

# %% [markdown]
# We need to convert ISO 8601 duration to seconds after fetching YouTube data because ISO 8601 duration represents the duration of a video in a standardized format, including hours, minutes, and seconds.

# %%
example_video.get('duration', '')
# Out:
# 'PT11M51S'

# %% [markdown]
# We can achieve the conversion by using the `isodate.parse_duration()` function. This function parses the duration string into a duration object, from which we can extract the total duration in seconds using the `.total_seconds()` method.

# %%
import isodate

# convert ISO 8601 duration to seconds
isodate.parse_duration(example_video.get('duration', '')).total_seconds()
# Out:
# 711.0

# %% [markdown]
# > **Insight:** The example video's duration is 711 seconds.

# %% [markdown]
#  By converting it to seconds, we can easily perform calculations, comparisons, and manipulations on video durations, allowing for more efficient data processing and analysis.

# %% [markdown]
# ## Convert `categoryId` to Category based on Categories Dictionary
#
# YouTube videos data often includes a `categoryId` attribute representing the category of the video.
#
# However, these IDs are not intuitive for users to understand. Therefore, by converting `categoryId` to a more descriptive category based on a predefined dictionary, we can provide users with clearer and more meaningful information about the content of the videos. This enhances user experience and makes the data more accessible and understandable.

# %% [markdown]
# **Note**: Later, use `"/opt/airflow/dags/..."` for docker purpose

# %%
with open('dags/categories.json', 'r') as f:
    categories = json.load(f)

categories
# Out:
# {'1': 'Film & Animation',
#  '2': 'Autos & Vehicles',
#  '10': 'Music',
#  '15': 'Pets & Animals',
#  '17': 'Sports',
#  '18': 'Short Movies',
#  '19': 'Travel & Events',
#  '20': 'Gaming',
#  '21': 'Videoblogging',
#  '22': 'People & Blogs',
#  '23': 'Comedy',
#  '24': 'Entertainment',
#  '25': 'News & Politics',
#  '26': 'Howto & Style',
#  '27': 'Education',
#  '28': 'Science & Technology',
#  '30': 'Movies',
#  '31': 'Anime/Animation',
#  '32': 'Action/Adventure',
#  '33': 'Classics',
#  '34': 'Comedy',
#  '35': 'Documentary',
#  '36': 'Drama',
#  '37': 'Family',
#  '38': 'Foreign',
#  '39': 'Horror',
#  '40': 'Sci-Fi/Fantasy',
#  '41': 'Thriller',
#  '42': 'Shorts',
#  '43': 'Shows',
#  '44': 'Trailers'}

# %%
example_video.get('categoryId', '')
# Out:
# '17'

# %%
complete_infos
# Out:
# {'snippet': ['title',
#   'publishedAt',
#   'channelTitle',
#   'description',
#   'categoryId',
#   'defaultAudioLanguage',
#   'thumbnails'],
#  'statistics': ['viewCount', 'likeCount', 'commentCount'],
#  'contentDetails': ['duration']}

# %% [markdown]
# ## convert categoryId to category based on categories dictionary

# %%
example_video.get('categoryId', '')
# Out:
# '17'

# %% [markdown]
# We can achieve the conversion by utilizing a predefined dictionary named `categories`.
#
# By accessing this dictionary with the `categoryId` retrieved from each video, we can obtain the corresponding category.

# %%
# convert categoryId to category
categories.get(example_video.get('categoryId', ''))
# Out:
# 'Sports'

# %% [markdown]
# This process ensures that each video's category is represented in a more user-friendly and understandable format.

# %% [markdown]
# ## Parse the Thumbnail `url`

# %% [markdown]
# Parsing the thumbnail URL is important to extract a single URL that represents the thumbnail image of the video in a standardized format.

# %% [markdown]
# Before parsing, the thumbnail data is structured into a dictionary with different sizes of thumbnails (default, medium, high, standard, maxres) each containing a URL along with its corresponding width and height.

# %%
example_video['thumbnails']
# Out:
# {'default': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/default.jpg',
#   'width': 120,
#   'height': 90},
#  'medium': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/mqdefault.jpg',
#   'width': 320,
#   'height': 180},
#  'high': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/hqdefault.jpg',
#   'width': 480,
#   'height': 360},
#  'standard': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/sddefault.jpg',
#   'width': 640,
#   'height': 480},
#  'maxres': {'url': 'https://i.ytimg.com/vi/2bopnQpPwgI/maxresdefault.jpg',
#   'width': 1280,
#   'height': 720}}

# %% [markdown]
# It is enough for us, to retrieve the URL of the standard thumbnail image only.

# %%
# parse the thumbnail url
example_video.get('thumbnails', {}).get('standard', {}).get('url')
# Out:
# 'https://i.ytimg.com/vi/2bopnQpPwgI/sddefault.jpg'

# %% [markdown]
#  After parsing, we extract the URL of the standard thumbnail ('sddefault') which typically represents a higher quality image suitable for displaying in various contexts.
#
#  This simplified URL format is more convenient for storage, sharing, and usage in applications compared to the original structured thumbnail data.

# %% [markdown]
# ## Convert Statistical Columns to Integer from String

# %% [markdown]
# Converting 'viewCount', 'likeCount', and 'commentCount' from string to integer is essential for proper data handling and analysis. By converting these values to integers, we can perform mathematical operations, comparisons, and statistical analysis accurately.

# %%
example_video['viewCount']
# Out:
# '1817393'

# %% [markdown]
# We accomplish the conversion by utilizing the int() function, which converts the string representation of 'viewCount' (and similarly 'likeCount' and 'commentCount') to an integer format.
#
# This ensures that these values are represented as numerical data, enabling us to perform mathematical operations and analysis accurately.

# %%
int(example_video.get('viewCount', 0))
# Out:
# 1817393

# %% [markdown]
# > **Insight:** Total views from example video is 1,809,813 views

# %% [markdown]
# Additionally, providing a default value of 0 ensures graceful handling in case the 'viewCount' attribute is missing or contains invalid data.
#
# This conversion allows us to effectively analyze the popularity, engagement, and interactions of YouTube videos based on their view counts, like counts, and comment counts.

# %% [markdown]
# ## Preprocess Each Video in the List

# %% [markdown]
# Combining all the preprocessing functions into a single loop allows for efficient processing of each video in the video list. Instead of manually applying each function to every video, looping through the list enables automated application of all necessary preprocessing steps.

# %%
for video in videos_list:
    # convert categoryId to category based on categories dictionary
    video['category'] = categories.get(video.get('categoryId', ''))
    del video['categoryId']

    # convert ISO 8601 duration to seconds
    video['duration'] = isodate.parse_duration(video.get('duration', '')).total_seconds()
    del video['duration']

    # parse the thumbnail url
    video['thumbnailUrl'] = video.get('thumbnails', {}).get('standard', {}).get('url')
    del video['thumbnails']
    
    # convert viewCount, likeCount, and commentCount to integer
    video['viewCount'] = int(video.get('viewCount', 0))
    video['likeCount'] = int(video.get('likeCount', 0))
    video['commentCount'] = int(video.get('commentCount', 0))

# %% [markdown]
# This approach enhances processing speed and scalability, especially when dealing with a large number of videos, such as the 200 videos typically present in trending YouTube data. By streamlining the preprocessing process, it ensures consistency, accuracy, and effectiveness in preparing the data for further analysis or usage.

# %% [markdown]
# ## Store Postprocessed Data into a JSON File

# %% [markdown]
# After preprocessing, the next step is to store the postprocessed data into a JSON format. This allows for easy storage, sharing, and retrieval of the processed data, ensuring that it remains accessible for future analysis or usage.

# %%
processed_file_path = 'dags/tmp_file_processed.json'

# %% [markdown]
# **Note**: Later, use `"/opt/airflow/dags/..."` for docker purpose

# %%
# save the processed videos data to a new file
with open(processed_file_path, "w") as f:
    json.dump(videos_list, f)

# %% [markdown]
# # Make Custom Function for All Processes

# %% [markdown]
# ## Make Fetching Data Function

# %% [markdown]
# Create a single function that combines all the fetching steps for YouTube video data into one streamlined process.

# %%
def fetch_trending_videos(region_code: str, file_path: str):
    """Fetches trending videos from YouTube for a specific region.

    Args:
        region_code: A string representing the ISO 3166-1 alpha-2 country code for the desired region.
        target_file_path: A string representing the path to the file to be written.
    """
    
    # load API key from .env file
    load_dotenv("/opt/airflow/dags/.env")
    api_key = os.environ.get("YOUTUBE_API_KEY")

    # create YouTube API client
    youtube = build("youtube", "v3", developerKey=api_key)

    complete_infos = {
        'snippet':['title', 'publishedAt', 'channelTitle',
                'description', 'categoryId', 'defaultAudioLanguage', 'thumbnails'],
        'statistics':['viewCount', 'likeCount', 'commentCount'],
        'contentDetails':['duration']
    }

    # fetch videos until max_results is reached or there are no more results
    videos_list = []
    # initialize the token
    next_page_token = ""

    while next_page_token is not None:
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            chart="mostPopular",
            regionCode=region_code,
            maxResults=50,
            pageToken=next_page_token # add pageToken to inform the API
        )
        response = request.execute()
        videos = response.get("items", [])

        time_now = datetime.now(timezone.utc).strftime('%Y-%m-%dT%H:%M:%SZ')
        for video in videos:
            video_details = {'videoId': video["id"], 'trendingAt': time_now}
            
            for key, value in complete_infos.items():
                for info in value:
                    video_details[info] = video.get(key, {}).get(info)
                        
            videos_list.append(video_details)

        # store the next page to fetch (token)
        next_page_token = response.get("nextPageToken", None)

    with open(file_path, "w") as f:
        json.dump(videos_list, f)
    
    print('Done fetched the data.')

# %%
fetch_trending_videos(region_code='ID', file_path='dags/tmp_file.json')
# Out:
# Done fetched the data.

# %% [markdown]
# **Note**: Later, use `"/opt/airflow/dags/..."` for docker purpose

# %% [markdown]
# This process can be named as `fetch_trending_videos` as it encapsulates the functionality of fetching trending videos from YouTube for a specific region and storing them in a JSON file

# %% [markdown]
# ## Make Data Preprocessing Function

# %% [markdown]
# Create a single function that combines all the preprocessing steps for YouTube video data into one streamlined process.

# %%
def data_processing(source_file_path: str, target_file_path: str):
    """Processes the raw data fetched from YouTube.
    
    Args:
        source_file_path: A string representing the path to the file to be processed.
        target_file_path: A string representing the path to the file to be written.
    """
    # Load the fetched videos data from the json file
    with open(source_file_path, 'r') as f:
        videos_list = json.load(f)
    
    # Load the categories dictionary from the json file
    with open('dags/categories.json', 'r') as f:
        categories = json.load(f)
    
    # process each video in the list
    for video in videos_list:
        # convert categoryId to category based on categories dictionary
        video['category'] = categories.get(video.get('categoryId', ''))
        del video['categoryId']

        # convert ISO 8601 duration to seconds
        video['duration'] = isodate.parse_duration(video.get('duration', '')).total_seconds()
        del video['duration']

        # parse the thumbnail url
        video['thumbnailUrl'] = video.get('thumbnails', {}).get('standard', {}).get('url')
        del video['thumbnails']
        
        # convert viewCount, likeCount, and commentCount to integer
        video['viewCount'] = int(video.get('viewCount', 0))
        video['likeCount'] = int(video.get('likeCount', 0))
        video['commentCount'] = int(video.get('commentCount', 0))

    # save the processed videos data to a new file
    with open(target_file_path, "w") as f:
        json.dump(videos_list, f)

    print('Done preprocessed data.')

# %%
data_processing('dags/tmp_file.json', 'dags/tmp_file_processed.json')
# Out:
# Done preprocessed data.

# %% [markdown]
# **Note**: Later, use `"/opt/airflow/dags/..."` for docker purpose

# %% [markdown]
# The process described here can be named "data_processing". It involves several steps, including converting categoryId to category based on a predefined dictionary, converting ISO 8601 duration to seconds, parsing the thumbnail URL, and converting viewCount, likeCount, and commentCount to integers.

# %% [markdown]
# ## Why is Important to Make All Processes a Function
#
# It's important to make this process a function for several reasons:
# 1. **Reusability**: By encapsulating these preprocessing steps into a function, we can easily reuse it across different parts of the codebase or in other projects. This promotes code reuse and reduces redundancy.
#
# 2. **Modularity**: The function creates a clear separation of concerns by encapsulating the preprocessing logic. This makes the code easier to understand, maintain, and debug.
#
# 3. **Abstraction**: The function abstracts away the implementation details of the preprocessing steps, allowing users to focus on the high-level logic without getting bogged down in the specifics.
#
# 4. **Testability**: By making the preprocessing logic a function, it becomes easier to write unit tests to ensure the correctness of the processing steps.
#
# Relating it to the use case of scheduling with Apache Airflow, making this preprocessing logic a function enables us to easily integrate it into an Airflow DAG (Directed Acyclic Graph). We can create an Airflow operator that calls this function to preprocess the data before performing further tasks in the pipeline. This promotes automation, scalability, and maintainability of the data processing workflow within Airflow.

# %% [markdown]
# # Conclusion
#
# In summary, we've successfully completed the fetch and preprocess data steps, enabling us to retrieve trending YouTube videos for a specific region, process the data to extract relevant information, and store it in a JSON format. By encapsulating these processes within functions and ensuring modularity and reusability, we've established a robust foundation for automating our data pipeline.
#
# Moving forward, our next steps involve integrating these functions into a Directed Acyclic Graph (DAG) using Apache Airflow. This will allow us to automate the entire process, scheduling it to run at regular intervals to ensure we always have up-to-date data. Additionally, we can implement error handling, logging, and monitoring within Airflow to ensure the reliability and resilience of our data pipeline.
#
# Overall, this integration with Airflow will enhance the scalability, efficiency, and maintainability of our data acquisition workflow, enabling us to derive valuable insights from trending YouTube data with ease.
